# %% [markdown]
# <div style="background:#E9FFF6; color:#440404; padding:8px; border-radius: 4px; text-align: center; font-weight: 500;">IFN619 - Data Analytics for Strategic Decision Makers (2024_sem1)</div>

# %% [markdown]
# # IFN619 :: B1-DataStructures - tutorial exercises

# %%
# import libraries
import pandas as pd
import numpy as np
import json
import requests

# %% [markdown]
# ## Task 1: Brisbane Ferry Terminals
# Purpose: save a long string as a `csv` file and read the `csv` file as a `pandas` `DataFrame`
#
# Data are modified from https://www.data.brisbane.qld.gov.au/data/dataset/ferry-terminals.
#
#
# **Step 1**: Save the `long_str` below into a `csv` file named `brisbane_ferry_terminals.csv` under the `data/` folder.
#
# >Hint: to save a file instead of read a file, you can change the argument of `'r'` to `'w'` in the `open()` function.
#
# >`'r'` = 'read', `'w'` = 'write'

# %%
# Note: use triple quotes like ''' or """ to create a multi-line string in Python
long_str = '''DESCRIPTION,STREETNAME,ADJ_PROPERTY_ADDRESS,SUBURB,STATUS,STATUS_DATE,SERVICE_TYPE,ACCESSIBILITY,PARKING,NEARBY_BUS_SERVICES
Dockside ferry terminal,Ferry St,44 FERRY ST,KANGAROO POINT,INACTIVE,2021/06/04 00:00:00+00,CityHopper,,,
Eagle Street Pier ferry terminal,Eagle St,32 MACROSSAN ST,BRISBANE CITY,INACTIVE,2022/02/27 00:00:00+00,CityFerry & CityHopper,,,Yes
Milton ferry terminal,Coronation Dr,299 CORONATION DR,MILTON,ACTIVE,2022/12/01 00:00:00+00,CityCat,Disabled Access,,
QUT Gardens Point ferry terminal,Gardens Point Rd,59 GARDENS POINT RD,BRISBANE CITY,ACTIVE,2022/12/01 00:00:00+00,CityCat,Disabled Access,,
Mowbray Park ferry terminal,Park Av,31 PARK AVE,EAST BRISBANE,ACTIVE,2021/06/04 00:00:00+00,CityCat,Disabled Access,Yes - limited,Yes
Sydney Street ferry terminal,Sydney St,112 OXLADE DR,NEW FARM,ACTIVE,2022/12/01 00:00:00+00,"CityCat, CityHopper",Disabled Access,,Yes
South Bank 2 ferry terminal,Clem Jones Promanade,153 STANLEY ST,SOUTH BRISBANE,ACTIVE,2021/06/04 00:00:00+00,CityCat & CityHopper,Assisted Mobility Impaired Access,,Yes
Bulimba ferry terminal,Oxford St,2 OXFORD ST,BULIMBA,ACTIVE,2021/06/04 00:00:00+00,"CityCat, Cross River Ferry",Disabled Access,,Yes
Riverside ferry terminal,Eagle St,32 MACROSSAN ST,BRISBANE CITY,ACTIVE,2021/06/04 00:00:00+00,"CityCat, CityHopper, Cross River Ferry",Disabled Access,,Yes
Regatta ferry terminal,Coronation Dr,566 CORONATION DR,TOOWONG,INACTIVE,2022/02/27 00:00:00+00,CityCat,Disabled Access,,Yes
Holman Street ferry terminal,Holman St,126 HOLMAN ST,KANGAROO POINT,ACTIVE,2022/12/01 00:00:00+00,"CityHopper, Cross River Ferry",,,
Teneriffe ferry terminal,Commercial Rd,17 SKYRING TCE,TENERIFFE,ACTIVE,2021/06/04 00:00:00+00,"CityCat, Cross River Ferry",Disabled Access,,Yes
Apollo Road ferry terminal,Apollo St,3 BYRON ST,BULIMBA,ACTIVE,2021/06/04 00:00:00+00,CityCat,Assisted Mobility Impaired Access,Yes - on-street,Yes
Guyatt Park ferry terminal,Macquarie St,46 HIRON ST,ST LUCIA,ACTIVE,2021/06/04 00:00:00+00,CityCat,Assisted Mobility Impaired Access,Yes - limited,Yes
South Bank 1 ferry terminal,Clem Jones Promanade,153 STANLEY ST,SOUTH BRISBANE,ACTIVE,2021/06/04 00:00:00+00,CityFerry & CityHopper,Assisted Mobility Impaired Access,,Yes
North Quay ferry terminal,Queens Wharf Rd,15 QUEENS WHARF RD,BRISBANE CITY,INACTIVE,2022/02/27 00:00:00+00,CityCat & CityHopper,Disabled Access,,Yes
New Farm Park ferry terminal,Brunswick St,1042 BRUNSWICK ST,NEW FARM,ACTIVE,2021/06/04 00:00:00+00,CityCat,Disabled Access,Yes - limited on-street,Yes
Bretts Wharf ferry terminal,Kingsford Smith Dr,449 KINGSFORD SMITH DR,HAMILTON,ACTIVE,2021/06/04 00:00:00+00,CityCat,Disabled Access,,Yes
Maritime Museum ferry terminal,Lower River Tce,77 LOWER RIVER TCE,KANGAROO POINT,ACTIVE,2022/12/01 00:00:00+00,CityHopper,Disabled Access,,
West End ferry terminal,Hoogley St,55 HOOGLEY ST,WEST END,ACTIVE,2022/04/11 00:00:00+00,CityCat,Disabled Access,,Yes
Northshore Hamilton ferry terminal,Macarthur Avenue,305 MACARTHUR AVE,HAMILTON,ACTIVE,2021/06/04 00:00:00+00,CityCat,Disabled Access,,
UQ St Lucia ferry terminal,Sir William Macgregor Dr,342 CARMODY RD,ST LUCIA,ACTIVE,2022/12/01 00:00:00+00,CityCat,Disabled Access,,Yes
South Bank 3 ferry terminal,Clem Jones Promanade,445 STANLEY ST,SOUTH BRISBANE,INACTIVE,2021/06/04 00:00:00+00,CityHopper,,,Yes
Hawthorne ferry terminal,Gordon St,14 GORDON ST,HAWTHORNE,ACTIVE,2022/05/20 00:00:00+00,CityCat,Disabled Access,Yes - limited on-street,Yes
Howard Smith Wharves ferry terminal,,,,ACTIVE,2021/12/20 00:00:00+00,CityHopper,,,'''
# View the string
long_str
# Out:
# 'DESCRIPTION,STREETNAME,ADJ_PROPERTY_ADDRESS,SUBURB,STATUS,STATUS_DATE,SERVICE_TYPE,ACCESSIBILITY,PARKING,NEARBY_BUS_SERVICES\nDockside ferry terminal,Ferry St,44 FERRY ST,KANGAROO POINT,INACTIVE,2021/06/04 00:00:00+00,CityHopper,,,\nEagle Street Pier ferry terminal,Eagle St,32 MACROSSAN ST,BRISBANE CITY,INACTIVE,2022/02/27 00:00:00+00,CityFerry & CityHopper,,,Yes\nMilton ferry terminal,Coronation Dr,299 CORONATION DR,MILTON,ACTIVE,2022/12/01 00:00:00+00,CityCat,Disabled Access,,\nQUT Gardens Point ferry terminal,Gardens Point Rd,59 GARDENS POINT RD,BRISBANE CITY,ACTIVE,2022/12/01 00:00:00+00,CityCat,Disabled Access,,\nMowbray Park ferry terminal,Park Av,31 PARK AVE,EAST BRISBANE,ACTIVE,2021/06/04 00:00:00+00,CityCat,Disabled Access,Yes - limited,Yes\nSydney Street ferry terminal,Sydney St,112 OXLADE DR,NEW FARM,ACTIVE,2022/12/01 00:00:00+00,"CityCat, CityHopper",Disabled Access,,Yes\nSouth Bank 2 ferry terminal,Clem Jones Promanade,153 STANLEY ST,SOUTH BRISBANE,ACTIVE,2021/06/04 00:00:00+00,CityCat & CityHopper,Assisted Mobility Impaired Access,,Yes\nBulimba ferry terminal,Oxford St,2 OXFORD ST,BULIMBA,ACTIVE,2021/06/04 00:00:00+00,"CityCat, Cross River Ferry",Disabled Access,,Yes\nRiverside ferry terminal,Eagle St,32 MACROSSAN ST,BRISBANE CITY,ACTIVE,2021/06/04 00:00:00+00,"CityCat, CityHopper, Cross River Ferry",Disabled Access,,Yes\nRegatta ferry terminal,Coronation Dr,566 CORONATION DR,TOOWONG,INACTIVE,2022/02/27 00:00:00+00,CityCat,Disabled Access,,Yes\nHolman Street ferry terminal,Holman St,126 HOLMAN ST,KANGAROO POINT,ACTIVE,2022/12/01 00:00:00+00,"CityHopper, Cross River Ferry",,,\nTeneriffe ferry terminal,Commercial Rd,17 SKYRING TCE,TENERIFFE,ACTIVE,2021/06/04 00:00:00+00,"CityCat, Cross River Ferry",Disabled Access,,Yes\nApollo Road ferry terminal,Apollo St,3 BYRON ST,BULIMBA,ACTIVE,2021/06/04 00:00:00+00,CityCat,Assisted Mobility Impaired Access,Yes - on-street,Yes\nGuyatt Park ferry terminal,Macquarie St,46 HIRON ST,ST LUCIA,ACTIVE,2021/06/04 00:00:00+00,CityCat,Assisted Mobility Impaired Access,Yes - limited,Yes\nSouth Bank 1 ferry terminal,Clem Jones Promanade,153 STANLEY ST,SOUTH BRISBANE,ACTIVE,2021/06/04 00:00:00+00,CityFerry & CityHopper,Assisted Mobility Impaired Access,,Yes\nNorth Quay ferry terminal,Queens Wharf Rd,15 QUEENS WHARF RD,BRISBANE CITY,INACTIVE,2022/02/27 00:00:00+00,CityCat & CityHopper,Disabled Access,,Yes\nNew Farm Park ferry terminal,Brunswick St,1042 BRUNSWICK ST,NEW FARM,ACTIVE,2021/06/04 00:00:00+00,CityCat,Disabled Access,Yes - limited on-street,Yes\nBretts Wharf ferry terminal,Kingsford Smith Dr,449 KINGSFORD SMITH DR,HAMILTON,ACTIVE,2021/06/04 00:00:00+00,CityCat,Disabled Access,,Yes\nMaritime Museum ferry terminal,Lower River Tce,77 LOWER RIVER TCE,KANGAROO POINT,ACTIVE,2022/12/01 00:00:00+00,CityHopper,Disabled Access,,\nWest End ferry terminal,Hoogley St,55 HOOGLEY ST,WEST END,ACTIVE,2022/04/11 00:00:00+00,CityCat,Disabled Access,,Yes\nNorthshore Hamilton ferry terminal,Macarthur Avenue,305 MACARTHUR AVE,HAMILTON,ACTIVE,2021/06/04 00:00:00+00,CityCat,Disabled Access,,\nUQ St Lucia ferry terminal,Sir William Macgregor Dr,342 CARMODY RD,ST LUCIA,ACTIVE,2022/12/01 00:00:00+00,CityCat,Disabled Access,,Yes\nSouth Bank 3 ferry terminal,Clem Jones Promanade,445 STANLEY ST,SOUTH BRISBANE,INACTIVE,2021/06/04 00:00:00+00,CityHopper,,,Yes\nHawthorne ferry terminal,Gordon St,14 GORDON ST,HAWTHORNE,ACTIVE,2022/05/20 00:00:00+00,CityCat,Disabled Access,Yes - limited on-street,Yes\nHoward Smith Wharves ferry terminal,,,,ACTIVE,2021/12/20 00:00:00+00,CityHopper,,,'

# %%
# write the string to a csv file named 'brisbane_ferry_terminals.csv' under 'data/'
with open('data/brisbane_ferry_terminals.csv', 'w') as file:
    file.write(long_str)

# %% [markdown]
# **Step 2**: Read the `csv` file you just saved as a DataFrame.

# %%
df = pd.read_csv('data/brisbane_ferry_terminals.csv')
df
# Out:
#                             DESCRIPTION                STREETNAME  \
# 0               Dockside ferry terminal                  Ferry St
# 1      Eagle Street Pier ferry terminal                  Eagle St
# 2                 Milton ferry terminal             Coronation Dr
# 3      QUT Gardens Point ferry terminal          Gardens Point Rd
# 4           Mowbray Park ferry terminal                   Park Av
# 5          Sydney Street ferry terminal                 Sydney St
# 6           South Bank 2 ferry terminal      Clem Jones Promanade
# 7                Bulimba ferry terminal                 Oxford St
# 8              Riverside ferry terminal                  Eagle St
# 9                Regatta ferry terminal             Coronation Dr
# 10         Holman Street ferry terminal                 Holman St
# 11             Teneriffe ferry terminal             Commercial Rd
# 12           Apollo Road ferry terminal                 Apollo St
# 13           Guyatt Park ferry terminal              Macquarie St
# 14          South Bank 1 ferry terminal      Clem Jones Promanade
# 15            North Quay ferry terminal           Queens Wharf Rd
# 16         New Farm Park ferry terminal              Brunswick St
# 17          Bretts Wharf ferry terminal        Kingsford Smith Dr
# 18       Maritime Museum ferry terminal           Lower River Tce
# 19              West End ferry terminal                Hoogley St
# 20   Northshore Hamilton ferry terminal          Macarthur Avenue
# 21           UQ St Lucia ferry terminal  Sir William Macgregor Dr
# 22          South Bank 3 ferry terminal      Clem Jones Promanade
# 23             Hawthorne ferry terminal                 Gordon St
# 24  Howard Smith Wharves ferry terminal                       NaN
#
#       ADJ_PROPERTY_ADDRESS          SUBURB    STATUS             STATUS_DATE  \
# 0              44 FERRY ST  KANGAROO POINT  INACTIVE  2021/06/04 00:00:00+00
# 1          32 MACROSSAN ST   BRISBANE CITY  INACTIVE  2022/02/27 00:00:00+00
# 2        299 CORONATION DR          MILTON    ACTIVE  2022/12/01 00:00:00+00
# 3      59 GARDENS POINT RD   BRISBANE CITY    ACTIVE  2022/12/01 00:00:00+00
# 4              31 PARK AVE   EAST BRISBANE    ACTIVE  2021/06/04 00:00:00+00
# 5            112 OXLADE DR        NEW FARM    ACTIVE  2022/12/01 00:00:00+00
# 6           153 STANLEY ST  SOUTH BRISBANE    ACTIVE  2021/06/04 00:00:00+00
# 7              2 OXFORD ST         BULIMBA    ACTIVE  2021/06/04 00:00:00+00
# 8          32 MACROSSAN ST   BRISBANE CITY    ACTIVE  2021/06/04 00:00:00+00
# 9        566 CORONATION DR         TOOWONG  INACTIVE  2022/02/27 00:00:00+00
# 10           126 HOLMAN ST  KANGAROO POINT    ACTIVE  2022/12/01 00:00:00+00
# 11          17 SKYRING TCE       TENERIFFE    ACTIVE  2021/06/04 00:00:00+00
# 12              3 BYRON ST         BULIMBA    ACTIVE  2021/06/04 00:00:00+00
# 13             46 HIRON ST        ST LUCIA    ACTIVE  2021/06/04 00:00:00+00
# 14          153 STANLEY ST  SOUTH BRISBANE    ACTIVE  2021/06/04 00:00:00+00
# 15      15 QUEENS WHARF RD   BRISBANE CITY  INACTIVE  2022/02/27 00:00:00+00
# 16       1042 BRUNSWICK ST        NEW FARM    ACTIVE  2021/06/04 00:00:00+00
# 17  449 KINGSFORD SMITH DR        HAMILTON    ACTIVE  2021/06/04 00:00:00+00
# 18      77 LOWER RIVER TCE  KANGAROO POINT    ACTIVE  2022/12/01 00:00:00+00
# 19           55 HOOGLEY ST        WEST END    ACTIVE  2022/04/11 00:00:00+00
# 20       305 MACARTHUR AVE        HAMILTON    ACTIVE  2021/06/04 00:00:00+00
# 21          342 CARMODY RD        ST LUCIA    ACTIVE  2022/12/01 00:00:00+00
# 22          445 STANLEY ST  SOUTH BRISBANE  INACTIVE  2021/06/04 00:00:00+00
# 23            14 GORDON ST       HAWTHORNE    ACTIVE  2022/05/20 00:00:00+00
# 24                     NaN             NaN    ACTIVE  2021/12/20 00:00:00+00
#
#                               SERVICE_TYPE                      ACCESSIBILITY  \
# 0                               CityHopper                                NaN
# 1                   CityFerry & CityHopper                                NaN
# 2                                  CityCat                    Disabled Access
# 3                                  CityCat                    Disabled Access
# 4                                  CityCat                    Disabled Access
# 5                      CityCat, CityHopper                    Disabled Access
# 6                     CityCat & CityHopper  Assisted Mobility Impaired Access
# 7               CityCat, Cross River Ferry                    Disabled Access
# 8   CityCat, CityHopper, Cross River Ferry                    Disabled Access
# 9                                  CityCat                    Disabled Access
# 10           CityHopper, Cross River Ferry                                NaN
# 11              CityCat, Cross River Ferry                    Disabled Access
# 12                                 CityCat  Assisted Mobility Impaired Access
# 13                                 CityCat  Assisted Mobility Impaired Access
# 14                  CityFerry & CityHopper  Assisted Mobility Impaired Access
# 15                    CityCat & CityHopper                    Disabled Access
# 16                                 CityCat                    Disabled Access
# 17                                 CityCat                    Disabled Access
# 18                              CityHopper                    Disabled Access
# 19                                 CityCat                    Disabled Access
# 20                                 CityCat                    Disabled Access
# 21                                 CityCat                    Disabled Access
# 22                              CityHopper                                NaN
# 23                                 CityCat                    Disabled Access
# 24                              CityHopper                                NaN
#
#                     PARKING NEARBY_BUS_SERVICES
# 0                       NaN                 NaN
# 1                       NaN                 Yes
# 2                       NaN                 NaN
# 3                       NaN                 NaN
# 4             Yes - limited                 Yes
# 5                       NaN                 Yes
# 6                       NaN                 Yes
# 7                       NaN                 Yes
# 8                       NaN                 Yes
# 9                       NaN                 Yes
# 10                      NaN                 NaN
# 11                      NaN                 Yes
# 12          Yes - on-street                 Yes
# 13            Yes - limited                 Yes
# 14                      NaN                 Yes
# 15                      NaN                 Yes
# 16  Yes - limited on-street                 Yes
# 17                      NaN                 Yes
# 18                      NaN                 NaN
# 19                      NaN                 Yes
# 20                      NaN                 NaN
# 21                      NaN                 Yes
# 22                      NaN                 Yes
# 23  Yes - limited on-street                 Yes
# 24                      NaN                 NaN

# %% [markdown]
# **Question 1**:
#
# 1. How many ferry terminals have Assisted Mobility Impaired Access and Disabled Access, respectively?
# 2. Provide a list of ferry terminals have disabled access or assisted mobility impaired access.

# %%
# number of terminals with accessibility
df.groupby('ACCESSIBILITY').size()

# alternative solution
# df['ACCESSIBILITY'].value_counts()
# Out:
# ACCESSIBILITY
# Assisted Mobility Impaired Access     4
# Disabled Access                      16
# dtype: int64

# %%
# Dataframe include ferry terminals with disabled access or assited mobility impaired access

df_disabled = df[(df['ACCESSIBILITY'] == 'Disabled Access') | (df['ACCESSIBILITY'] == 'Assisted Mobility Impaired Access')]
# df_disabled = df[df['ACCESSIBILITY'].isna() == False]  # alternative solution
df_disabled
# Out:
#                            DESCRIPTION                STREETNAME  \
# 2                Milton ferry terminal             Coronation Dr
# 3     QUT Gardens Point ferry terminal          Gardens Point Rd
# 4          Mowbray Park ferry terminal                   Park Av
# 5         Sydney Street ferry terminal                 Sydney St
# 6          South Bank 2 ferry terminal      Clem Jones Promanade
# 7               Bulimba ferry terminal                 Oxford St
# 8             Riverside ferry terminal                  Eagle St
# 9               Regatta ferry terminal             Coronation Dr
# 11            Teneriffe ferry terminal             Commercial Rd
# 12          Apollo Road ferry terminal                 Apollo St
# 13          Guyatt Park ferry terminal              Macquarie St
# 14         South Bank 1 ferry terminal      Clem Jones Promanade
# 15           North Quay ferry terminal           Queens Wharf Rd
# 16        New Farm Park ferry terminal              Brunswick St
# 17         Bretts Wharf ferry terminal        Kingsford Smith Dr
# 18      Maritime Museum ferry terminal           Lower River Tce
# 19             West End ferry terminal                Hoogley St
# 20  Northshore Hamilton ferry terminal          Macarthur Avenue
# 21          UQ St Lucia ferry terminal  Sir William Macgregor Dr
# 23            Hawthorne ferry terminal                 Gordon St
#
#       ADJ_PROPERTY_ADDRESS          SUBURB    STATUS             STATUS_DATE  \
# 2        299 CORONATION DR          MILTON    ACTIVE  2022/12/01 00:00:00+00
# 3      59 GARDENS POINT RD   BRISBANE CITY    ACTIVE  2022/12/01 00:00:00+00
# 4              31 PARK AVE   EAST BRISBANE    ACTIVE  2021/06/04 00:00:00+00
# 5            112 OXLADE DR        NEW FARM    ACTIVE  2022/12/01 00:00:00+00
# 6           153 STANLEY ST  SOUTH BRISBANE    ACTIVE  2021/06/04 00:00:00+00
# 7              2 OXFORD ST         BULIMBA    ACTIVE  2021/06/04 00:00:00+00
# 8          32 MACROSSAN ST   BRISBANE CITY    ACTIVE  2021/06/04 00:00:00+00
# 9        566 CORONATION DR         TOOWONG  INACTIVE  2022/02/27 00:00:00+00
# 11          17 SKYRING TCE       TENERIFFE    ACTIVE  2021/06/04 00:00:00+00
# 12              3 BYRON ST         BULIMBA    ACTIVE  2021/06/04 00:00:00+00
# 13             46 HIRON ST        ST LUCIA    ACTIVE  2021/06/04 00:00:00+00
# 14          153 STANLEY ST  SOUTH BRISBANE    ACTIVE  2021/06/04 00:00:00+00
# 15      15 QUEENS WHARF RD   BRISBANE CITY  INACTIVE  2022/02/27 00:00:00+00
# 16       1042 BRUNSWICK ST        NEW FARM    ACTIVE  2021/06/04 00:00:00+00
# 17  449 KINGSFORD SMITH DR        HAMILTON    ACTIVE  2021/06/04 00:00:00+00
# 18      77 LOWER RIVER TCE  KANGAROO POINT    ACTIVE  2022/12/01 00:00:00+00
# 19           55 HOOGLEY ST        WEST END    ACTIVE  2022/04/11 00:00:00+00
# 20       305 MACARTHUR AVE        HAMILTON    ACTIVE  2021/06/04 00:00:00+00
# 21          342 CARMODY RD        ST LUCIA    ACTIVE  2022/12/01 00:00:00+00
# 23            14 GORDON ST       HAWTHORNE    ACTIVE  2022/05/20 00:00:00+00
#
#                               SERVICE_TYPE                      ACCESSIBILITY  \
# 2                                  CityCat                    Disabled Access
# 3                                  CityCat                    Disabled Access
# 4                                  CityCat                    Disabled Access
# 5                      CityCat, CityHopper                    Disabled Access
# 6                     CityCat & CityHopper  Assisted Mobility Impaired Access
# 7               CityCat, Cross River Ferry                    Disabled Access
# 8   CityCat, CityHopper, Cross River Ferry                    Disabled Access
# 9                                  CityCat                    Disabled Access
# 11              CityCat, Cross River Ferry                    Disabled Access
# 12                                 CityCat  Assisted Mobility Impaired Access
# 13                                 CityCat  Assisted Mobility Impaired Access
# 14                  CityFerry & CityHopper  Assisted Mobility Impaired Access
# 15                    CityCat & CityHopper                    Disabled Access
# 16                                 CityCat                    Disabled Access
# 17                                 CityCat                    Disabled Access
# 18                              CityHopper                    Disabled Access
# 19                                 CityCat                    Disabled Access
# 20                                 CityCat                    Disabled Access
# 21                                 CityCat                    Disabled Access
# 23                                 CityCat                    Disabled Access
#
#                     PARKING NEARBY_BUS_SERVICES
# 2                       NaN                 NaN
# 3                       NaN                 NaN
# 4             Yes - limited                 Yes
# 5                       NaN                 Yes
# 6                       NaN                 Yes
# 7                       NaN                 Yes
# 8                       NaN                 Yes
# 9                       NaN                 Yes
# 11                      NaN                 Yes
# 12          Yes - on-street                 Yes
# 13            Yes - limited                 Yes
# 14                      NaN                 Yes
# 15                      NaN                 Yes
# 16  Yes - limited on-street                 Yes
# 17                      NaN                 Yes
# 18                      NaN                 NaN
# 19                      NaN                 Yes
# 20                      NaN                 NaN
# 21                      NaN                 Yes
# 23  Yes - limited on-street                 Yes

# %%
# Save the names of ferry terminals as a list
disabled_list = df_disabled['DESCRIPTION'].to_list()
# Display the list 
disabled_list
# Out:
# ['Milton ferry terminal',
#  'QUT Gardens Point ferry terminal',
#  'Mowbray Park ferry terminal',
#  'Sydney Street ferry terminal',
#  'South Bank 2 ferry terminal',
#  'Bulimba ferry terminal',
#  'Riverside ferry terminal',
#  'Regatta ferry terminal',
#  'Teneriffe ferry terminal',
#  'Apollo Road ferry terminal',
#  'Guyatt Park ferry terminal',
#  'South Bank 1 ferry terminal',
#  'North Quay ferry terminal',
#  'New Farm Park ferry terminal',
#  'Bretts Wharf ferry terminal',
#  'Maritime Museum ferry terminal',
#  'West End ferry terminal',
#  'Northshore Hamilton ferry terminal',
#  'UQ St Lucia ferry terminal',
#  'Hawthorne ferry terminal']

# %% [markdown]
# **Question 2**: Which **CityCat** terminals are currently **INACTIVE**?

# %%
df[(df['STATUS']=='INACTIVE') & (df['SERVICE_TYPE'].str.contains('CityCat'))]
# Out:
#                   DESCRIPTION       STREETNAME ADJ_PROPERTY_ADDRESS  \
# 9      Regatta ferry terminal    Coronation Dr    566 CORONATION DR
# 15  North Quay ferry terminal  Queens Wharf Rd   15 QUEENS WHARF RD
#
#            SUBURB    STATUS             STATUS_DATE          SERVICE_TYPE  \
# 9         TOOWONG  INACTIVE  2022/02/27 00:00:00+00               CityCat
# 15  BRISBANE CITY  INACTIVE  2022/02/27 00:00:00+00  CityCat & CityHopper
#
#       ACCESSIBILITY PARKING NEARBY_BUS_SERVICES
# 9   Disabled Access     NaN                 Yes
# 15  Disabled Access     NaN                 Yes

# %% [markdown]
# ---
# ## Task 2 (open-ended)
# What other questions you want to find out about the Brisbane Ferry services? Use the Data Analytics Cycle approach on this dataset.
#
# ### Question
# [write your question here]

# %% [markdown]
# ### Analysis

# %%
# Your code here

# %% [markdown]
# ### Visualisation

# %%
# Your code here

# %% [markdown]
# ### Insights
# [write your insights here]

# %% [markdown]
# ---
# ## Task 3: How many different species of kingfishers in Queensland?
#
# Purpose: read a `json` file from a website; save a `json` file; navigate through a `json` file.

# %% [markdown]
# The url below is a subset of the Queensland wildlife database with information of family of "birds" in Queensland.
#
# Data source: https://www.data.qld.gov.au/dataset/qld-wildlife-data-api/resource/c318621a-6adf-4e2c-aa35-c4e23b660ac7.

# %%
bird_url = 'http://apps.des.qld.gov.au/species/?op=getfamilynames&kingdom=animals&class=aves'

# Request the content from the web server
response = requests.get(bird_url)

# Preview the content
response.content
# Out:
# b'{"Family":[{"KingdomName":"Animalia","KingdomCommonName":"animals","ClassName":"Aves","ClassCommonName":"birds","FamilyName":"Acanthizidae","FamilyCommonName":"thornbills and gerygones","FamilyRank":"980650","SpeciesUrl":"http:\\/\\/apps.des.qld.gov.au\\/species\\/?op=getspecies&family=acanthizidae"},{"KingdomName":"Animalia","KingdomCommonName":"animals","ClassName":"Aves","ClassCommonName":"birds","FamilyName":"Accipitridae","FamilyCommonName":"eagles, kites, goshawks","FamilyRank":"980300","SpeciesUrl":"http:\\/\\/apps.des.qld.gov.au\\/species\\/?op=getspecies&family=accipitridae"},{"KingdomName":"Animalia","KingdomCommonName":"animals","ClassName":"Aves","ClassCommonName":"birds","FamilyName":"Acrocephalidae","FamilyCommonName":"reed-warblers","FamilyRank":"980860","SpeciesUrl":"http:\\/\\/apps.des.qld.gov.au\\/species\\/?op=getspecies&family=acrocephalidae"},{"KingdomName":"Animalia","KingdomCommonName":"animals","ClassName":"Aves","ClassCommonName":"birds","FamilyName":"Aegothelidae","FamilyCommonName":"owlet-nightjars","FamilyRank":"980150","SpeciesUrl":"http:\\/\\/apps.des.qld.gov.au\\/species\\/?op=getspecies&family=aegothelidae"},{"KingdomName":"Animalia","KingdomCommonName":"animals","ClassName":"Aves","ClassCommonName":"birds","FamilyName":"Alaudidae","FamilyCommonName":"larks","FamilyRank":"980840","SpeciesUrl":"http:\\/\\/apps.des.qld.gov.au\\/species\\/?op=getspecies&family=alaudidae"},{"KingdomName":"Animalia","KingdomCommonName":"animals","ClassName":"Aves","ClassCommonName":"birds","FamilyName":"Alcedinidae","FamilyCommonName":"kingfishers","FamilyRank":"980540","SpeciesUrl":"http:\\/\\/apps.des.qld.gov.au\\/species\\/?op=getspecies&family=alcedinidae"},{"KingdomName":"Animalia","KingdomCommonName":"animals","ClassName":"Aves","ClassCommonName":"birds","FamilyName":"Anatidae","FamilyCommonName":"ducks, geese and swans","FamilyRank":"980070","SpeciesUrl":"http:\\/\\/apps.des.qld.gov.au\\/species\\/?op=getspecies&family=anatidae"},{"KingdomName":"Animalia","KingdomCommonName":"animals","ClassName":"Aves","ClassCommonName":"birds","FamilyName":"Anhingidae","FamilyCommonName":"darter","FamilyRank":"980240","SpeciesUrl":"http:\\/\\/apps.des.qld.gov.au\\/species\\/?op=getspecies&family=anhingidae"},{"KingdomName":"Animalia","KingdomCommonName":"animals","ClassName":"Aves","ClassCommonName":"birds","FamilyName":"Anseranatidae","FamilyCommonName":"magpie goose","FamilyRank":"980060","SpeciesUrl":"http:\\/\\/apps.des.qld.gov.au\\/species\\/?op=getspecies&family=anseranatidae"},{"KingdomName":"Animalia","KingdomCommonName":"animals","ClassName":"Aves","ClassCommonName":"birds","FamilyName":"Apodidae","FamilyCommonName":"swifts and swiftlets","FamilyRank":"980160","SpeciesUrl":"http:\\/\\/apps.des.qld.gov.au\\/species\\/?op=getspecies&family=apodidae"},{"KingdomName":"Animalia","KingdomCommonName":"animals","ClassName":"Aves","ClassCommonName":"birds","FamilyName":"Ardeidae","FamilyCommonName":"herons, egrets and bitterns","FamilyRank":"980280","SpeciesUrl":"http:\\/\\/apps.des.qld.gov.au\\/species\\/?op=getspecies&family=ardeidae"},{"KingdomName":"Animalia","KingdomCommonName":"animals","ClassName":"Aves","ClassCommonName":"birds","FamilyName":"Artamidae","FamilyCommonName":"woodswallows, currawongs, butcherbirds and magpie","FamilyRank":"980750","SpeciesUrl":"http:\\/\\/apps.des.qld.gov.au\\/species\\/?op=getspecies&family=artamidae"},{"KingdomName":"Animalia","KingdomCommonName":"animals","ClassName":"Aves","ClassCommonName":"birds","FamilyName":"Atrichornithidae","FamilyCommonName":"scrub-birds","FamilyRank":"980600","SpeciesUrl":"http:\\/\\/apps.des.qld.gov.au\\/species\\/?op=getspecies&family=atrichornithidae"},{"KingdomName":"Animalia","KingdomCommonName":"animals","ClassName":"Aves","ClassCommonName":"birds","FamilyName":"Burhinidae","FamilyCommonName":"stone-curlews","FamilyRank":"980360","SpeciesUrl":"http:\\/\\/apps.des.qld.gov.au\\/species\\/?op=getspecies&family=burhinidae"},{"KingdomName":"Animalia","Kin ...

# %%
# Get the data as json from the response
bird_family_json = response.json()
# Preview the data
bird_family_json
# Out:
# {'Family': [{'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Acanthizidae',
#    'FamilyCommonName': 'thornbills and gerygones',
#    'FamilyRank': '980650',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=acanthizidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Accipitridae',
#    'FamilyCommonName': 'eagles, kites, goshawks',
#    'FamilyRank': '980300',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=accipitridae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Acrocephalidae',
#    'FamilyCommonName': 'reed-warblers',
#    'FamilyRank': '980860',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=acrocephalidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Aegothelidae',
#    'FamilyCommonName': 'owlet-nightjars',
#    'FamilyRank': '980150',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=aegothelidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Alaudidae',
#    'FamilyCommonName': 'larks',
#    'FamilyRank': '980840',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=alaudidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Alcedinidae',
#    'FamilyCommonName': 'kingfishers',
#    'FamilyRank': '980540',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=alcedinidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Anatidae',
#    'FamilyCommonName': 'ducks, geese and swans',
#    'FamilyRank': '980070',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=anatidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Anhingidae',
#    'FamilyCommonName': 'darter',
#    'FamilyRank': '980240',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=anhingidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Anseranatidae',
#    'FamilyCommonName': 'magpie goose',
#    'FamilyRank': '980060',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=anseranatidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Apodidae',
#    'FamilyCommonName': 'swifts and swiftlets',
#    'FamilyRank': '980160',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=apodidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Ardeidae',
#    'FamilyCommonName': 'herons, egrets and bitterns',
#    'FamilyRank': '980280',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=ardeidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Artamidae',
#    'FamilyCommonName': 'woodswallows, currawongs, butcherbirds and magpie',
#    'FamilyRank': '980750',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=artamidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Atrichornithidae',
#    'FamilyCommonName': 'scrub-birds',
#    'FamilyRank': '980600',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=atrichornithidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Burhinidae',
#    'FamilyCommonName': 'stone-curlews',
#    'FamilyRank': '980360',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=burhinidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Cacatuidae',
#    'FamilyCommonName': 'cockatoos and corellas',
#    'FamilyRank': '980490',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=cacatuidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Campephagidae',
#    'FamilyCommonName': 'cuckoo-shrikes and trillers',
#    'FamilyRank': '980720',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=campephagidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Caprimulgidae',
#    'FamilyCommonName': 'nightjars',
#    'FamilyRank': '980140',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=caprimulgidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Casuariidae',
#    'FamilyCommonName': 'emus and cassowaries',
#    'FamilyRank': '980010',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=casuariidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Charadriidae',
#    'FamilyCommonName': 'plovers, dotterel and lapwings',
#    'FamilyRank': '980390',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=charadriidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Ciconiidae',
#    'FamilyCommonName': 'storks',
#    'FamilyRank': '980270',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=ciconiidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Cinclosomatidae',
#    'FamilyCommonName': 'quail-thrushes',
#    'FamilyRank': '980700',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=cinclosomatidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Cisticolidae',
#    'FamilyCommonName': 'cisticolas',
#    'FamilyRank': '980850',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=cisticolidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Climacteridae',
#    'FamilyCommonName': 'treecreepers',
#    'FamilyRank': '980610',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=climacteridae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Columbidae',
#    'FamilyCommonName': 'pigeons and doves',
#    'FamilyRank': '980110',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=columbidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Coraciidae',
#    'FamilyCommonName': 'rollers',
#    'FamilyRank': '980570',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=coraciidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Corcoracidae',
#    'FamilyCommonName': 'chough and apostlebird',
#    'FamilyRank': '980810',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=corcoracidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Corvidae',
#    'FamilyCommonName': 'crows and ravens',
#    'FamilyRank': '980790',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=corvidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Cuculidae',
#    'FamilyCommonName': 'cuckoos',
#    'FamilyRank': '980510',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=cuculidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Dasyornithidae',
#    'FamilyCommonName': 'bristlebirds',
#    'FamilyRank': '980640',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=dasyornithidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Dicaeidae',
#    'FamilyCommonName': 'flowerpeckers',
#    'FamilyRank': '980950',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=dicaeidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Dicruridae',
#    'FamilyCommonName': 'drongos',
#    'FamilyRank': '980760',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=dicruridae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Diomedeidae',
#    'FamilyCommonName': 'albatrosses',
#    'FamilyRank': '980190',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=diomedeidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Emberizidae',
#    'FamilyCommonName': 'buntings',
#    'FamilyRank': '981000',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=emberizidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Estrildidae',
#    'FamilyCommonName': 'weaver finches',
#    'FamilyRank': '980960',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=estrildidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Eurostopodidae',
#    'FamilyCommonName': 'eared nightjars',
#    'FamilyRank': '980130',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=eurostopodidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Falconidae',
#    'FamilyCommonName': 'falcons',
#    'FamilyRank': '980310',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=falconidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Falcunculidae',
#    'FamilyCommonName': 'shriketits',
#    'FamilyRank': '980730',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=falcunculidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Fregatidae',
#    'FamilyCommonName': 'frigatebirds',
#    'FamilyRank': '980220',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=fregatidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Fringillidae',
#    'FamilyCommonName': 'old world finches',
#    'FamilyRank': '980990',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=fringillidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Glareolidae',
#    'FamilyCommonName': 'pratincoles',
#    'FamilyRank': '980450',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=glareolidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Gruidae',
#    'FamilyCommonName': 'cranes',
#    'FamilyRank': '980320',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=gruidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Haematopodidae',
#    'FamilyCommonName': 'oystercatchers',
#    'FamilyRank': '980370',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=haematopodidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Halcyonidae',
#    'FamilyCommonName': 'kookaburras and kingfishers',
#    'FamilyRank': '980550',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=halcyonidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Hirundinidae',
#    'FamilyCommonName': 'swallows and martins',
#    'FamilyRank': '980900',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=hirundinidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Hydrobatidae',
#    'FamilyCommonName': 'northern storm-petrels',
#    'FamilyRank': '980170',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=hydrobatidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Jacanidae',
#    'FamilyCommonName': 'jacanas',
#    'FamilyRank': '980410',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=jacanidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Laridae',
#    'FamilyCommonName': 'gulls, terns and noddies',
#    'FamilyRank': '980470',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=laridae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Locustellidae',
#    'FamilyCommonName': 'grassbirds',
#    'FamilyRank': '980870',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=locustellidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Machaerirhynchidae',
#    'FamilyCommonName': 'boatbills',
#    'FamilyRank': '980800',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=machaerirhynchidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Maluridae',
#    'FamilyCommonName': 'fairy-wrens, emu-wrens and grasswrens',
#    'FamilyRank': '980630',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=maluridae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Megaluridae',
#    'FamilyCommonName': 'Megaluridae',
#    'FamilyRank': '980870',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=megaluridae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Megapodiidae',
#    'FamilyCommonName': 'megapodes',
#    'FamilyRank': '980020',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=megapodiidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Meliphagidae',
#    'FamilyCommonName': 'honeyeaters and chats',
#    'FamilyRank': '980670',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=meliphagidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Menuridae',
#    'FamilyCommonName': 'lyrebirds',
#    'FamilyRank': '980590',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=menuridae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Meropidae',
#    'FamilyCommonName': 'bee-eaters',
#    'FamilyRank': '980560',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=meropidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Monarchidae',
#    'FamilyCommonName': 'monarch and flycatchers',
#    'FamilyRank': '980800',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=monarchidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Motacillidae',
#    'FamilyCommonName': 'pipits and wagtails',
#    'FamilyRank': '980980',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=motacillidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Muscicapidae',
#    'FamilyCommonName': 'old world flycatchers',
#    'FamilyRank': '980920',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=muscicapidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Nectariniidae',
#    'FamilyCommonName': 'sunbirds',
#    'FamilyRank': '980950',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=nectariniidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Neosittidae',
#    'FamilyCommonName': 'sittellas',
#    'FamilyRank': '980710',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=neosittidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Numididae',
#    'FamilyCommonName': 'guineafowl',
#    'FamilyRank': '980030',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=numididae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Oceanitidae',
#    'FamilyCommonName': 'southern storm-petrels',
#    'FamilyRank': '980180',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=oceanitidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Oreoicidae',
#    'FamilyCommonName': 'australo-papuan bellbirds',
#    'FamilyRank': '980730',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=oreoicidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Oriolidae',
#    'FamilyCommonName': 'orioles and figbirds',
#    'FamilyRank': '980740',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=oriolidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Orthonychidae',
#    'FamilyCommonName': 'logrunners',
#    'FamilyRank': '980690',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=orthonychidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Otididae',
#    'FamilyCommonName': 'bustards',
#    'FamilyRank': '980340',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=otididae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Pachycephalidae',
#    'FamilyCommonName': 'whistlers, shrike-thrushes and allies',
#    'FamilyRank': '980730',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=pachycephalidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Pandionidae',
#    'FamilyCommonName': 'osprey',
#    'FamilyRank': '980300',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=pandionidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Paradisaeidae',
#    'FamilyCommonName': 'Birds of Paradise',
#    'FamilyRank': '980820',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=paradisaeidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Pardalotidae',
#    'FamilyCommonName': 'pardalotes',
#    'FamilyRank': '980660',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=pardalotidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Passeridae',
#    'FamilyCommonName': 'weaver finches',
#    'FamilyRank': '980970',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=passeridae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Pedionomidae',
#    'FamilyCommonName': 'Plains-wanderer',
#    'FamilyRank': '980400',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=pedionomidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Pelecanidae',
#    'FamilyCommonName': 'pelican',
#    'FamilyRank': '980260',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=pelecanidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Petroicidae',
#    'FamilyCommonName': 'australian robins',
#    'FamilyRank': '980830',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=petroicidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Phaethontidae',
#    'FamilyCommonName': 'Tropicbirds',
#    'FamilyRank': '980080',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=phaethontidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Phalacrocoracidae',
#    'FamilyCommonName': 'cormorants and shags',
#    'FamilyRank': '980250',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=phalacrocoracidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Phasianidae',
#    'FamilyCommonName': 'pheasants and quail',
#    'FamilyRank': '980050',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=phasianidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Pittidae',
#    'FamilyCommonName': 'Pittas',
#    'FamilyRank': '980580',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=pittidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Podargidae',
#    'FamilyCommonName': 'Frogmouths',
#    'FamilyRank': '980120',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=podargidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Podicipedidae',
#    'FamilyCommonName': 'Grebes',
#    'FamilyRank': '980090',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=podicipedidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Pomatostomidae',
#    'FamilyCommonName': 'australian babblers',
#    'FamilyRank': '980680',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=pomatostomidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Procellariidae',
#    'FamilyCommonName': 'Petrels and Shearwaters',
#    'FamilyRank': '980200',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=procellariidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Psittacidae',
#    'FamilyCommonName': 'Parrots',
#    'FamilyRank': '980500',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=psittacidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Psittaculidae',
#    'FamilyCommonName': 'parrots, lorikeets and rosellas',
#    'FamilyRank': '980500',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=psittaculidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Psophodidae',
#    'FamilyCommonName': 'whipbirds and wedgebills',
#    'FamilyRank': '980700',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=psophodidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Ptilonorhynchidae',
#    'FamilyCommonName': 'bowerbirds and catbirds',
#    'FamilyRank': '980620',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=ptilonorhynchidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Pycnonotidae',
#    'FamilyCommonName': 'Bulbuls',
#    'FamilyRank': '980910',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=pycnonotidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Rallidae',
#    'FamilyCommonName': 'crakes, rails and swamphens',
#    'FamilyRank': '980330',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=rallidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Recurvirostridae',
#    'FamilyCommonName': 'Stilts and Avocets',
#    'FamilyRank': '980380',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=recurvirostridae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Rhipiduridae',
#    'FamilyCommonName': 'fantails',
#    'FamilyRank': '980770',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=rhipiduridae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Rostratulidae',
#    'FamilyCommonName': 'painted snipe',
#    'FamilyRank': '980420',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=rostratulidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Scolopacidae',
#    'FamilyCommonName': 'sandpipers, snipes and allies',
#    'FamilyRank': '980430',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=scolopacidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Spheniscidae',
#    'FamilyCommonName': 'Penguins',
#    'FamilyRank': '980210',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=spheniscidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Stercorariidae',
#    'FamilyCommonName': 'skuas and jaegers',
#    'FamilyRank': '980460',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=stercorariidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Strigidae',
#    'FamilyCommonName': 'hawk-owls',
#    'FamilyRank': '980520',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=strigidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Struthionidae',
#    'FamilyCommonName': 'Ostriches',
#    'FamilyRank': '980000',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=struthionidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Sturnidae',
#    'FamilyCommonName': 'starlings',
#    'FamilyRank': '980940',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=sturnidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Sulidae',
#    'FamilyCommonName': 'Gannets and Boobies',
#    'FamilyRank': '980230',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=sulidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Threskiornithidae',
#    'FamilyCommonName': 'ibis and spoonbills',
#    'FamilyRank': '980290',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=threskiornithidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Timaliidae',
#    'FamilyCommonName': 'Timaliidae',
#    'FamilyRank': '980880',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=timaliidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Turdidae',
#    'FamilyCommonName': 'thrushes',
#    'FamilyRank': '980930',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=turdidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Turnicidae',
#    'FamilyCommonName': 'button-quail',
#    'FamilyRank': '980440',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=turnicidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Tytonidae',
#    'FamilyCommonName': 'masked owls',
#    'FamilyRank': '980530',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=tytonidae'},
#   {'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Zosteropidae',
#    'FamilyCommonName': 'white-eyes and yuhinias',
#    'FamilyRank': '980880',
#    'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=zosteropidae'}]}

# %% [markdown]
# You will notice that it seems all the contents are under one key named `'Family'`, and the value is stored as a list.
#
# **Question 1**: display the **6th** item from the list, and save the information in a new `json` file named `qld_kingfishers_family.json` under the `data/` folder.

# %%
bird_family_json['Family']
# Out:
# [{'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Acanthizidae',
#   'FamilyCommonName': 'thornbills and gerygones',
#   'FamilyRank': '980650',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=acanthizidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Accipitridae',
#   'FamilyCommonName': 'eagles, kites, goshawks',
#   'FamilyRank': '980300',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=accipitridae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Acrocephalidae',
#   'FamilyCommonName': 'reed-warblers',
#   'FamilyRank': '980860',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=acrocephalidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Aegothelidae',
#   'FamilyCommonName': 'owlet-nightjars',
#   'FamilyRank': '980150',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=aegothelidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Alaudidae',
#   'FamilyCommonName': 'larks',
#   'FamilyRank': '980840',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=alaudidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Alcedinidae',
#   'FamilyCommonName': 'kingfishers',
#   'FamilyRank': '980540',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=alcedinidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Anatidae',
#   'FamilyCommonName': 'ducks, geese and swans',
#   'FamilyRank': '980070',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=anatidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Anhingidae',
#   'FamilyCommonName': 'darter',
#   'FamilyRank': '980240',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=anhingidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Anseranatidae',
#   'FamilyCommonName': 'magpie goose',
#   'FamilyRank': '980060',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=anseranatidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Apodidae',
#   'FamilyCommonName': 'swifts and swiftlets',
#   'FamilyRank': '980160',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=apodidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Ardeidae',
#   'FamilyCommonName': 'herons, egrets and bitterns',
#   'FamilyRank': '980280',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=ardeidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Artamidae',
#   'FamilyCommonName': 'woodswallows, currawongs, butcherbirds and magpie',
#   'FamilyRank': '980750',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=artamidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Atrichornithidae',
#   'FamilyCommonName': 'scrub-birds',
#   'FamilyRank': '980600',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=atrichornithidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Burhinidae',
#   'FamilyCommonName': 'stone-curlews',
#   'FamilyRank': '980360',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=burhinidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Cacatuidae',
#   'FamilyCommonName': 'cockatoos and corellas',
#   'FamilyRank': '980490',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=cacatuidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Campephagidae',
#   'FamilyCommonName': 'cuckoo-shrikes and trillers',
#   'FamilyRank': '980720',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=campephagidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Caprimulgidae',
#   'FamilyCommonName': 'nightjars',
#   'FamilyRank': '980140',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=caprimulgidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Casuariidae',
#   'FamilyCommonName': 'emus and cassowaries',
#   'FamilyRank': '980010',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=casuariidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Charadriidae',
#   'FamilyCommonName': 'plovers, dotterel and lapwings',
#   'FamilyRank': '980390',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=charadriidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Ciconiidae',
#   'FamilyCommonName': 'storks',
#   'FamilyRank': '980270',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=ciconiidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Cinclosomatidae',
#   'FamilyCommonName': 'quail-thrushes',
#   'FamilyRank': '980700',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=cinclosomatidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Cisticolidae',
#   'FamilyCommonName': 'cisticolas',
#   'FamilyRank': '980850',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=cisticolidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Climacteridae',
#   'FamilyCommonName': 'treecreepers',
#   'FamilyRank': '980610',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=climacteridae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Columbidae',
#   'FamilyCommonName': 'pigeons and doves',
#   'FamilyRank': '980110',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=columbidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Coraciidae',
#   'FamilyCommonName': 'rollers',
#   'FamilyRank': '980570',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=coraciidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Corcoracidae',
#   'FamilyCommonName': 'chough and apostlebird',
#   'FamilyRank': '980810',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=corcoracidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Corvidae',
#   'FamilyCommonName': 'crows and ravens',
#   'FamilyRank': '980790',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=corvidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Cuculidae',
#   'FamilyCommonName': 'cuckoos',
#   'FamilyRank': '980510',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=cuculidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Dasyornithidae',
#   'FamilyCommonName': 'bristlebirds',
#   'FamilyRank': '980640',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=dasyornithidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Dicaeidae',
#   'FamilyCommonName': 'flowerpeckers',
#   'FamilyRank': '980950',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=dicaeidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Dicruridae',
#   'FamilyCommonName': 'drongos',
#   'FamilyRank': '980760',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=dicruridae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Diomedeidae',
#   'FamilyCommonName': 'albatrosses',
#   'FamilyRank': '980190',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=diomedeidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Emberizidae',
#   'FamilyCommonName': 'buntings',
#   'FamilyRank': '981000',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=emberizidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Estrildidae',
#   'FamilyCommonName': 'weaver finches',
#   'FamilyRank': '980960',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=estrildidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Eurostopodidae',
#   'FamilyCommonName': 'eared nightjars',
#   'FamilyRank': '980130',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=eurostopodidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Falconidae',
#   'FamilyCommonName': 'falcons',
#   'FamilyRank': '980310',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=falconidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Falcunculidae',
#   'FamilyCommonName': 'shriketits',
#   'FamilyRank': '980730',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=falcunculidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Fregatidae',
#   'FamilyCommonName': 'frigatebirds',
#   'FamilyRank': '980220',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=fregatidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Fringillidae',
#   'FamilyCommonName': 'old world finches',
#   'FamilyRank': '980990',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=fringillidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Glareolidae',
#   'FamilyCommonName': 'pratincoles',
#   'FamilyRank': '980450',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=glareolidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Gruidae',
#   'FamilyCommonName': 'cranes',
#   'FamilyRank': '980320',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=gruidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Haematopodidae',
#   'FamilyCommonName': 'oystercatchers',
#   'FamilyRank': '980370',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=haematopodidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Halcyonidae',
#   'FamilyCommonName': 'kookaburras and kingfishers',
#   'FamilyRank': '980550',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=halcyonidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Hirundinidae',
#   'FamilyCommonName': 'swallows and martins',
#   'FamilyRank': '980900',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=hirundinidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Hydrobatidae',
#   'FamilyCommonName': 'northern storm-petrels',
#   'FamilyRank': '980170',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=hydrobatidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Jacanidae',
#   'FamilyCommonName': 'jacanas',
#   'FamilyRank': '980410',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=jacanidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Laridae',
#   'FamilyCommonName': 'gulls, terns and noddies',
#   'FamilyRank': '980470',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=laridae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Locustellidae',
#   'FamilyCommonName': 'grassbirds',
#   'FamilyRank': '980870',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=locustellidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Machaerirhynchidae',
#   'FamilyCommonName': 'boatbills',
#   'FamilyRank': '980800',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=machaerirhynchidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Maluridae',
#   'FamilyCommonName': 'fairy-wrens, emu-wrens and grasswrens',
#   'FamilyRank': '980630',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=maluridae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Megaluridae',
#   'FamilyCommonName': 'Megaluridae',
#   'FamilyRank': '980870',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=megaluridae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Megapodiidae',
#   'FamilyCommonName': 'megapodes',
#   'FamilyRank': '980020',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=megapodiidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Meliphagidae',
#   'FamilyCommonName': 'honeyeaters and chats',
#   'FamilyRank': '980670',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=meliphagidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Menuridae',
#   'FamilyCommonName': 'lyrebirds',
#   'FamilyRank': '980590',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=menuridae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Meropidae',
#   'FamilyCommonName': 'bee-eaters',
#   'FamilyRank': '980560',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=meropidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Monarchidae',
#   'FamilyCommonName': 'monarch and flycatchers',
#   'FamilyRank': '980800',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=monarchidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Motacillidae',
#   'FamilyCommonName': 'pipits and wagtails',
#   'FamilyRank': '980980',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=motacillidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Muscicapidae',
#   'FamilyCommonName': 'old world flycatchers',
#   'FamilyRank': '980920',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=muscicapidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Nectariniidae',
#   'FamilyCommonName': 'sunbirds',
#   'FamilyRank': '980950',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=nectariniidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Neosittidae',
#   'FamilyCommonName': 'sittellas',
#   'FamilyRank': '980710',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=neosittidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Numididae',
#   'FamilyCommonName': 'guineafowl',
#   'FamilyRank': '980030',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=numididae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Oceanitidae',
#   'FamilyCommonName': 'southern storm-petrels',
#   'FamilyRank': '980180',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=oceanitidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Oreoicidae',
#   'FamilyCommonName': 'australo-papuan bellbirds',
#   'FamilyRank': '980730',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=oreoicidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Oriolidae',
#   'FamilyCommonName': 'orioles and figbirds',
#   'FamilyRank': '980740',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=oriolidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Orthonychidae',
#   'FamilyCommonName': 'logrunners',
#   'FamilyRank': '980690',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=orthonychidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Otididae',
#   'FamilyCommonName': 'bustards',
#   'FamilyRank': '980340',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=otididae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Pachycephalidae',
#   'FamilyCommonName': 'whistlers, shrike-thrushes and allies',
#   'FamilyRank': '980730',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=pachycephalidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Pandionidae',
#   'FamilyCommonName': 'osprey',
#   'FamilyRank': '980300',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=pandionidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Paradisaeidae',
#   'FamilyCommonName': 'Birds of Paradise',
#   'FamilyRank': '980820',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=paradisaeidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Pardalotidae',
#   'FamilyCommonName': 'pardalotes',
#   'FamilyRank': '980660',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=pardalotidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Passeridae',
#   'FamilyCommonName': 'weaver finches',
#   'FamilyRank': '980970',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=passeridae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Pedionomidae',
#   'FamilyCommonName': 'Plains-wanderer',
#   'FamilyRank': '980400',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=pedionomidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Pelecanidae',
#   'FamilyCommonName': 'pelican',
#   'FamilyRank': '980260',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=pelecanidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Petroicidae',
#   'FamilyCommonName': 'australian robins',
#   'FamilyRank': '980830',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=petroicidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Phaethontidae',
#   'FamilyCommonName': 'Tropicbirds',
#   'FamilyRank': '980080',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=phaethontidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Phalacrocoracidae',
#   'FamilyCommonName': 'cormorants and shags',
#   'FamilyRank': '980250',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=phalacrocoracidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Phasianidae',
#   'FamilyCommonName': 'pheasants and quail',
#   'FamilyRank': '980050',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=phasianidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Pittidae',
#   'FamilyCommonName': 'Pittas',
#   'FamilyRank': '980580',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=pittidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Podargidae',
#   'FamilyCommonName': 'Frogmouths',
#   'FamilyRank': '980120',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=podargidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Podicipedidae',
#   'FamilyCommonName': 'Grebes',
#   'FamilyRank': '980090',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=podicipedidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Pomatostomidae',
#   'FamilyCommonName': 'australian babblers',
#   'FamilyRank': '980680',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=pomatostomidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Procellariidae',
#   'FamilyCommonName': 'Petrels and Shearwaters',
#   'FamilyRank': '980200',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=procellariidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Psittacidae',
#   'FamilyCommonName': 'Parrots',
#   'FamilyRank': '980500',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=psittacidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Psittaculidae',
#   'FamilyCommonName': 'parrots, lorikeets and rosellas',
#   'FamilyRank': '980500',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=psittaculidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Psophodidae',
#   'FamilyCommonName': 'whipbirds and wedgebills',
#   'FamilyRank': '980700',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=psophodidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Ptilonorhynchidae',
#   'FamilyCommonName': 'bowerbirds and catbirds',
#   'FamilyRank': '980620',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=ptilonorhynchidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Pycnonotidae',
#   'FamilyCommonName': 'Bulbuls',
#   'FamilyRank': '980910',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=pycnonotidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Rallidae',
#   'FamilyCommonName': 'crakes, rails and swamphens',
#   'FamilyRank': '980330',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=rallidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Recurvirostridae',
#   'FamilyCommonName': 'Stilts and Avocets',
#   'FamilyRank': '980380',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=recurvirostridae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Rhipiduridae',
#   'FamilyCommonName': 'fantails',
#   'FamilyRank': '980770',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=rhipiduridae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Rostratulidae',
#   'FamilyCommonName': 'painted snipe',
#   'FamilyRank': '980420',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=rostratulidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Scolopacidae',
#   'FamilyCommonName': 'sandpipers, snipes and allies',
#   'FamilyRank': '980430',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=scolopacidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Spheniscidae',
#   'FamilyCommonName': 'Penguins',
#   'FamilyRank': '980210',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=spheniscidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Stercorariidae',
#   'FamilyCommonName': 'skuas and jaegers',
#   'FamilyRank': '980460',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=stercorariidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Strigidae',
#   'FamilyCommonName': 'hawk-owls',
#   'FamilyRank': '980520',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=strigidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Struthionidae',
#   'FamilyCommonName': 'Ostriches',
#   'FamilyRank': '980000',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=struthionidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Sturnidae',
#   'FamilyCommonName': 'starlings',
#   'FamilyRank': '980940',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=sturnidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Sulidae',
#   'FamilyCommonName': 'Gannets and Boobies',
#   'FamilyRank': '980230',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=sulidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Threskiornithidae',
#   'FamilyCommonName': 'ibis and spoonbills',
#   'FamilyRank': '980290',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=threskiornithidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Timaliidae',
#   'FamilyCommonName': 'Timaliidae',
#   'FamilyRank': '980880',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=timaliidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Turdidae',
#   'FamilyCommonName': 'thrushes',
#   'FamilyRank': '980930',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=turdidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Turnicidae',
#   'FamilyCommonName': 'button-quail',
#   'FamilyRank': '980440',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=turnicidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Tytonidae',
#   'FamilyCommonName': 'masked owls',
#   'FamilyRank': '980530',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=tytonidae'},
#  {'KingdomName': 'Animalia',
#   'KingdomCommonName': 'animals',
#   'ClassName': 'Aves',
#   'ClassCommonName': 'birds',
#   'FamilyName': 'Zosteropidae',
#   'FamilyCommonName': 'white-eyes and yuhinias',
#   'FamilyRank': '980880',
#   'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=zosteropidae'}]

# %%
# Display the 6th item
qld_kf_family = bird_family_json['Family'][5]
qld_kf_family
# Out:
# {'KingdomName': 'Animalia',
#  'KingdomCommonName': 'animals',
#  'ClassName': 'Aves',
#  'ClassCommonName': 'birds',
#  'FamilyName': 'Alcedinidae',
#  'FamilyCommonName': 'kingfishers',
#  'FamilyRank': '980540',
#  'SpeciesUrl': 'http://apps.des.qld.gov.au/species/?op=getspecies&family=alcedinidae'}

# %%
# Save the above information to a json file

# Dump the dict into a json string
qld_kf_json = json.dumps(qld_kf_family)
# Write the json string to a file 
file_name = 'json_kingfishers_family.json'
with open(f"data/{file_name}","w") as fp:
    fp.write(qld_kf_json)

# %% [markdown]
# You may noticed that there is a `SpeciesUrl` in the above json file. This url includes all the species of the kingfisher family.
# Read the content from the `SpeciesUrl` and answer the following questions:
# 1. How many species of kingfishers in Queensland?
# 2. What are the species names of kingfishers in Queensland?

# %%
# Extract the url
kingfishers_url = qld_kf_family['SpeciesUrl']
kingfishers_url
# Out:
# 'http://apps.des.qld.gov.au/species/?op=getspecies&family=alcedinidae'

# %%
# Extract the information from the url above, save the data as json
response_kf = requests.get(kingfishers_url)
kf_json = response_kf.json()
kf_json
# Out:
# {'Species': [{'TaxonID': 1778,
#    'ScientificName': 'Alcedo sp.',
#    'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Alcedinidae',
#    'FamilyCommonName': 'kingfishers',
#    'FamilyRank': 980540,
#    'IsSuperseded': False,
#    'ConservationStatus': {'ConservationSignificant': False},
#    'Endemicity': 'NATIVE',
#    'PestStatus': 'Nil',
#    'SpeciesEnvironment': 'Terrestrial',
#    'SpeciesProfileUrl': 'http://apps.des.qld.gov.au/species/?op=getspeciesinformation&taxonid=1778'},
#   {'TaxonID': 1776,
#    'ScientificName': 'Ceyx azureus',
#    'AcceptedCommonName': 'azure kingfisher',
#    'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Alcedinidae',
#    'FamilyCommonName': 'kingfishers',
#    'FamilyRank': 980540,
#    'IsSuperseded': False,
#    'ConservationStatus': {'NCAStatus': 'Least concern',
#     'NCAStatusCode': 'C',
#     'ConservationSignificant': False},
#    'Endemicity': 'NATIVE',
#    'WetlandStatus': 'Wetland Indicator Species',
#    'Synonyms': ['Alcedo azurea', 'Ceyx azurea'],
#    'PestStatus': 'Nil',
#    'SpeciesEnvironment': 'Aquatic & Terrestrial',
#    'SpeciesProfileUrl': 'http://apps.des.qld.gov.au/species/?op=getspeciesinformation&taxonid=1776'},
#   {'TaxonID': 1777,
#    'ScientificName': 'Ceyx pusillus',
#    'AcceptedCommonName': 'little kingfisher',
#    'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Alcedinidae',
#    'FamilyCommonName': 'kingfishers',
#    'FamilyRank': 980540,
#    'IsSuperseded': False,
#    'ConservationStatus': {'NCAStatus': 'Least concern',
#     'NCAStatusCode': 'C',
#     'ConservationSignificant': False},
#    'Endemicity': 'NATIVE',
#    'WetlandStatus': 'Wetland Indicator Species',
#    'Synonyms': ['Alcedo pusilla', 'Ceyx pusilla'],
#    'PestStatus': 'Nil',
#    'SpeciesEnvironment': 'Aquatic & Terrestrial',
#    'SpeciesProfileUrl': 'http://apps.des.qld.gov.au/species/?op=getspeciesinformation&taxonid=1777'},
#   {'TaxonID': 1766,
#    'ScientificName': 'Dacelo leachii',
#    'AcceptedCommonName': 'blue-winged kookaburra',
#    'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Alcedinidae',
#    'FamilyCommonName': 'kingfishers',
#    'FamilyRank': 980540,
#    'IsSuperseded': False,
#    'ConservationStatus': {'NCAStatus': 'Least concern',
#     'NCAStatusCode': 'C',
#     'ConservationSignificant': False},
#    'Endemicity': 'NATIVE',
#    'PestStatus': 'Nil',
#    'SpeciesEnvironment': 'Terrestrial',
#    'SpeciesProfileUrl': 'http://apps.des.qld.gov.au/species/?op=getspeciesinformation&taxonid=1766'},
#   {'TaxonID': 1767,
#    'ScientificName': 'Dacelo novaeguineae',
#    'AcceptedCommonName': 'laughing kookaburra',
#    'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Alcedinidae',
#    'FamilyCommonName': 'kingfishers',
#    'FamilyRank': 980540,
#    'IsSuperseded': False,
#    'ConservationStatus': {'NCAStatus': 'Least concern',
#     'NCAStatusCode': 'C',
#     'ConservationSignificant': False},
#    'Endemicity': 'NATIVE',
#    'PestStatus': 'Nil',
#    'SpeciesEnvironment': 'Terrestrial',
#    'SpeciesProfileUrl': 'http://apps.des.qld.gov.au/species/?op=getspeciesinformation&taxonid=1767'},
#   {'TaxonID': 1769,
#    'ScientificName': 'Syma torotoro',
#    'AcceptedCommonName': 'yellow-billed kingfisher',
#    'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Alcedinidae',
#    'FamilyCommonName': 'kingfishers',
#    'FamilyRank': 980540,
#    'IsSuperseded': False,
#    'ConservationStatus': {'NCAStatus': 'Least concern',
#     'NCAStatusCode': 'C',
#     'ConservationSignificant': False},
#    'Endemicity': 'NATIVE',
#    'PestStatus': 'Nil',
#    'SpeciesEnvironment': 'Terrestrial',
#    'SpeciesProfileUrl': 'http://apps.des.qld.gov.au/species/?op=getspeciesinformation&taxonid=1769'},
#   {'TaxonID': 33859,
#    'ScientificName': 'Tanysiptera hydrocharis',
#    'AcceptedCommonName': 'little paradise kingfisher',
#    'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Alcedinidae',
#    'FamilyCommonName': 'kingfishers',
#    'FamilyRank': 980540,
#    'IsSuperseded': False,
#    'ConservationStatus': {'NCAStatus': 'Least concern',
#     'NCAStatusCode': 'C',
#     'ConservationSignificant': False},
#    'Endemicity': 'NATIVE',
#    'PestStatus': 'Nil',
#    'SpeciesEnvironment': 'Terrestrial',
#    'SpeciesProfileUrl': 'http://apps.des.qld.gov.au/species/?op=getspeciesinformation&taxonid=33859'},
#   {'TaxonID': 1758,
#    'ScientificName': 'Tanysiptera sylvia',
#    'AcceptedCommonName': 'buff-breasted paradise-kingfisher',
#    'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Alcedinidae',
#    'FamilyCommonName': 'kingfishers',
#    'FamilyRank': 980540,
#    'IsSuperseded': False,
#    'ConservationStatus': {'NCAStatus': 'Least concern',
#     'NCAStatusCode': 'C',
#     'ConservationSignificant': False},
#    'Endemicity': 'NATIVE',
#    'PestStatus': 'Nil',
#    'SpeciesEnvironment': 'Terrestrial',
#    'SpeciesProfileUrl': 'http://apps.des.qld.gov.au/species/?op=getspeciesinformation&taxonid=1758'},
#   {'TaxonID': 1760,
#    'ScientificName': 'Todiramphus macleayii',
#    'AcceptedCommonName': 'forest kingfisher',
#    'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Alcedinidae',
#    'FamilyCommonName': 'kingfishers',
#    'FamilyRank': 980540,
#    'IsSuperseded': False,
#    'ConservationStatus': {'NCAStatus': 'Least concern',
#     'NCAStatusCode': 'C',
#     'ConservationSignificant': False},
#    'Endemicity': 'NATIVE',
#    'PestStatus': 'Nil',
#    'SpeciesEnvironment': 'Terrestrial',
#    'SpeciesProfileUrl': 'http://apps.des.qld.gov.au/species/?op=getspeciesinformation&taxonid=1760'},
#   {'TaxonID': 1761,
#    'ScientificName': 'Todiramphus pyrrhopygius',
#    'AcceptedCommonName': 'red-backed kingfisher',
#    'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Alcedinidae',
#    'FamilyCommonName': 'kingfishers',
#    'FamilyRank': 980540,
#    'IsSuperseded': False,
#    'ConservationStatus': {'NCAStatus': 'Least concern',
#     'NCAStatusCode': 'C',
#     'ConservationSignificant': False},
#    'Endemicity': 'NATIVE',
#    'Synonyms': ['Todiramphus pyrrhopygia'],
#    'PestStatus': 'Nil',
#    'SpeciesEnvironment': 'Terrestrial',
#    'SpeciesProfileUrl': 'http://apps.des.qld.gov.au/species/?op=getspeciesinformation&taxonid=1761'},
#   {'TaxonID': 1762,
#    'ScientificName': 'Todiramphus sanctus',
#    'AcceptedCommonName': 'sacred kingfisher',
#    'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Alcedinidae',
#    'FamilyCommonName': 'kingfishers',
#    'FamilyRank': 980540,
#    'IsSuperseded': False,
#    'ConservationStatus': {'NCAStatus': 'Least concern',
#     'NCAStatusCode': 'C',
#     'ConservationSignificant': False},
#    'Endemicity': 'NATIVE',
#    'PestStatus': 'Nil',
#    'SpeciesEnvironment': 'Terrestrial',
#    'SpeciesProfileUrl': 'http://apps.des.qld.gov.au/species/?op=getspeciesinformation&taxonid=1762'},
#   {'TaxonID': 1759,
#    'ScientificName': 'Todiramphus sordidus',
#    'AcceptedCommonName': 'Torresian kingfisher',
#    'KingdomName': 'Animalia',
#    'KingdomCommonName': 'animals',
#    'ClassName': 'Aves',
#    'ClassCommonName': 'birds',
#    'FamilyName': 'Alcedinidae',
#    'FamilyCommonName': 'kingfishers',
#    'FamilyRank': 980540,
#    'IsSuperseded': False,
#    'ConservationStatus': {'NCAStatus': 'Least concern',
#     'NCAStatusCode': 'C',
#     'ConservationSignificant': False},
#    'Endemicity': 'NATIVE',
#    'WetlandStatus': 'Wetland Indicator Species',
#    'TypeReference': 'Gould, J. (1842). Characters of two new species of Australian Halcyonidae. Proc. Zool. Soc. Lond. 1842, 72.',
#    'Synonyms': ['Todiramphus chloris',
#     'Todiramphus sordidus sordidus',
#     'Todiramphus sordidus colcloughi',
#     'Todiramphus chloris sordidus',
#     'Todiramphus chloris colcloughi',
#     'Sauropatis sordida colcloughi',
#     'Sauropatis chloris hyperpontia',
#     'Halcyon sordidus cooktowni',
#     'Halcyon sordidus',
#     'Halcyon chloris sordida'],
#    'PestStatus': 'Nil',
#    'SpeciesEnvironment': 'Terrestrial',
#    'SpeciesProfileUrl': 'http://apps.des.qld.gov.au/species/?op=getspeciesinformation&taxonid=1759'}]}

# %% [markdown]
# **Question 1**: How many species of kingfishers in Queensland?
# >Hint: You can use `len([list])` to calculate how many items in a list.

# %%
# How many species of kingfishers in Queensland?
len(kf_json['Species'])
# Out:
# 12

# %% [markdown]
# **Question 2**: What are the species names of kingfishers in Queensland?
# >Hint: You need to use a for loop to extract the names

# %%
# What are the species names of kingfishers in Queensland?
for item in kf_json['Species']:
    print(item['ScientificName'])
# Out:
# Alcedo sp.
# Ceyx azureus
# Ceyx pusillus
# Dacelo leachii
# Dacelo novaeguineae
# Syma torotoro
# Tanysiptera hydrocharis
# Tanysiptera sylvia
# Todiramphus macleayii
# Todiramphus pyrrhopygius
# Todiramphus sanctus
# Todiramphus sordidus

# %% [markdown]
# ---
# ## Task 4 (open-ended)
# Go back to the bird family json file and find another species that you are interested, and look for more information from the chosen species.
# You can also check other kingdoms, classes or families from the [Queensland wildlife data API](https://www.data.qld.gov.au/dataset/qld-wildlife-data-api/resource/c318621a-6adf-4e2c-aa35-c4e23b660ac7).

# %% [markdown]
# ---
# ## Task 5: What are the popular tv shows on reddit?

# %%
# Define strings for our endpoint URL and header parameters

subreddit = "television"
url = f"https://www.reddit.com/r/{subreddit}/hot.json"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

# Question: what data type is "headers"?

# %%
# Send GET request
response = requests.get(url, headers=headers)

# %%
## Inspect the data structure

# %%
# Inspect what data was returned. What type of data is this? Is it easy to see what the structure is?
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Using a tool to look at the structure

# %% [markdown]
# Use the json viewer tool at http://jsonviewer.stack.hu/ to get a view of the structure of the returned data
#
# You will need to copy and paste the entire response

# %% [markdown]
# ### Save the response and look at structure in Jupyter
#
# 1. Use the examples in the studio session to show you how to save the json data as a json file
# 2. Open the json file in the Jupyter JSON editor - how does the structure look compared with the jsonviewer above

# %%
# Get the json from the response
reddit_json = response.json()
reddit_json

# Dump the json as a string
reddit_pop_shows = json.dumps(reddit_json)
reddit_pop_shows

# Save the string to a file
file_name = 'json_reddit_shows.json'
with open(f"data/{file_name}","w") as fp:
    fp.write(reddit_pop_shows)

# %% [markdown]
# ### Getting your required data out of the response

# %%
# Extract post data from response
post_data = response.json()['data']['children']

# %% [markdown]
# ### Loop through the data

# %%
# Print post titles
for post in post_data:
    print(post['data']['title'])
# Out:
# What are you watching and what do you recommend? (Week of February 23, 2024)
# Richard Lewis Dead: Beloved Comic, 'Curb Your Enthusiasm' Actor Was 76
# Larry David Pays Tribute to Richard Lewis: ‘Like a Brother to Me … the Funniest Person and Also the Sweetest’
# Meghan and Harry’s $100 Million Netflix Deal Is a Hollywood Miss - According to multiple insiders, the Sussexes have worn out their welcome in Hollywood with an iron-fisted desire for control, combined with a lack of experience.
# Hulu and Disney+ are losing subscribers as the streaming industry struggles to turn a profit
# ‘The Rings of Power’ Showrunners Sign New Amazon Deal, Begin Early Work on Season 3
# David Dastmalchian Joins Alexander Skarsgård In Apple Sci-Fi Series ‘Murderbot’
# Costar age gaps hurt Hollywood — Fire Country’s Diane Farr urges for age parity between onscreen couples
# ‘Hacks’ Adds Helen Hunt, Christina Hendricks, Christopher Lloyd &amp; More To Third Season
# I watched all the episodes of Baywatch, and here are my thoughts on it.
# Nick Offerman, Betty Gilpin Join Matthew Macfadyen and Michael Shannon in Netflix’s President Garfield Assassination Series ‘Death by Lightning’
# Apple Greenlights New Sci-Fi Drama Series ‘Neuromancer’ Based On William Gibson Novel
# 'Elsbeth' Wants to Be the Next 'Columbo.' It Nearly Succeeds.
# 'NCIS' Tony &amp; Ziva Spinoff Series, NCIS: Europe, Ordered By Paramount+
# Carrie Preston Delights in CBS’ Enchanting ‘Good Wife’ Spinoff ‘Elsbeth’: TV Review
# Guy Ritchie to Direct 'Ray Donovan' Spin-Off 'The Donovans'
# The new show Shogun looks to be an absolute masterpiece
# ‘Hagen’: First Look At German Epic Fantasy Drama
# I'm absolutely over the mentally ill savant trope
# They're filming an episode of S.W.A.T. in my apartment complex. The amount of resources are insane, can't imagine something like Dune or Game of Thrones and how big those sets are.
# Paramount Global Q4 Sees Sharp Downturn in Movies and 15% TV Ad Decline, as Streaming Losses Narrow
# Taylor Sheridan’s ‘Tulsa King,’ Starring Sylvester Stallone, to Air on CBS
# Eugene Levy Joins ‘Only Murders In The Building’ Season 4
# Remembering Richard Lewis: All-time favorite interaction with Jon Stewart on the Daily Show (the unrated web-part of the show)...
# PLEASE watch Tokyo Vice! Don't let corporate idiots cancel it.
# Netflix Top 10: ‘Avatar: The Last Airbender’ Opens in First Place With 21.2 Million Views, Up 15% From ‘One Piece’ Live-Action Debut

# %% [markdown]
# ### Load what we have extracted into a dataframe

# %%
import pandas as pd

# Turn the for loop we used above into a "list comprehension" to create a list we can load into a dataframe

df = pd.DataFrame(post['data']['title'] for post in post_data)

# %%
# Take a look at our dataframe
df
# Out:
#                                                     0
# 0   What are you watching and what do you recommen...
# 1   Richard Lewis Dead: Beloved Comic, 'Curb Your ...
# 2   Larry David Pays Tribute to Richard Lewis: ‘Li...
# 3   Meghan and Harry’s $100 Million Netflix Deal I...
# 4   Hulu and Disney+ are losing subscribers as the...
# 5   ‘The Rings of Power’ Showrunners Sign New Amaz...
# 6   David Dastmalchian Joins Alexander Skarsgård I...
# 7   Costar age gaps hurt Hollywood — Fire Country’...
# 8   ‘Hacks’ Adds Helen Hunt, Christina Hendricks, ...
# 9   I watched all the episodes of Baywatch, and he...
# 10  Nick Offerman, Betty Gilpin Join Matthew Macfa...
# 11  Apple Greenlights New Sci-Fi Drama Series ‘Neu...
# 12  'Elsbeth' Wants to Be the Next 'Columbo.' It N...
# 13  'NCIS' Tony &amp; Ziva Spinoff Series, NCIS: E...
# 14  Carrie Preston Delights in CBS’ Enchanting ‘Go...
# 15  Guy Ritchie to Direct 'Ray Donovan' Spin-Off '...
# 16  The new show Shogun looks to be an absolute ma...
# 17   ‘Hagen’: First Look At German Epic Fantasy Drama
# 18  I'm absolutely over the mentally ill savant trope
# 19  They're filming an episode of S.W.A.T. in my a...
# 20  Paramount Global Q4 Sees Sharp Downturn in Mov...
# 21  Taylor Sheridan’s ‘Tulsa King,’ Starring Sylve...
# 22  Eugene Levy Joins ‘Only Murders In The Buildin...
# 23  Remembering Richard Lewis: All-time favorite i...
# 24  PLEASE watch Tokyo Vice! Don't let corporate i...
# 25  Netflix Top 10: ‘Avatar: The Last Airbender’ O...

# %% [markdown]
# ### Do something with the data

# %%
# Print out only those rows that contain a certain string such as "Last of Us"

???
