# %% [markdown]
# <div style="background:#E9FFF6; color:#440404; padding:8px; border-radius: 4px; text-align: center; font-weight: 500;">IFN619 - Data Analytics for Strategic Decision Makers (2023_sem1)</div>

# %% [markdown]
# # IFN619 :: C1-UnstructuredAnalytics
#
# For this session, the focus will be on analysis of unstructured text. However, the thinking required is similar to approaches to analysing images, video, sound and other unstructured data. Primarily, the analysis is based on the notion that there are useful patterns in the unstructured data which can be obtained mathematically. By converting the data to a mathematical structure, various algorithms can be applied to the structure with the aim of identifying patterns.
#
# In the case of the `topic modelling` approaches below, many of the techniques are *probabilistic* - that is they mathematically identify the *likelihood* that a feature might be important. Thus, they are never 100% accurate, and their use needs to be mediated by a more pragmatic *useful or not* approach, rather than *right or wrong*.

# %%
# Import the necessary libraries
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF
import pandas as pd
import json
import random

# %% [markdown]
# ### Accessing the data via The Guardian API
#
# See the `Accessing_the_Guardian_API.ipynb` notebook file for details on getting the data. **Note:** This approach may be used for additional data for Assignment 2.
#
# ### Read in pre-saved data
#
# To save time, we're loading in pre-saved data that was fetched using the Guardian API.

# %%
# Load the data - articles from The Guardian about the war in Ukraine
file_path = "data/"
file_name = "ukraine_articles.json"

with open(f"{file_path}{file_name}",'r', encoding='utf-8') as fp:
    articles = json.load(fp)

print(f"Loaded {len(articles)} articles from {file_name}")
# Out:
# Loaded 202 articles from ukraine_articles.json

# %% [markdown]
# Each dictionary entry includes the *title [date]* as `key` and the *body text* from the article as `value`.

# %%
article1 = list(articles.items())[0]
print("Key:",article1[0])
print("Value:",article1[1][:300],"...") # Just show first 300 characters
# Out:
# Key: Russia-Ukraine war live: Ukraine ‘buying time’ in Bakhmut – as it happened [2023-03-12T18:26:12Z]
# Value:   6.26pm GMT       Good evening, we are closing this blog now. You can see all our Ukraine coverage here       6.06pm GMT    A summary of today's developments     Ukraine and Russia both claimed that hundreds of enemy troops had been killed in the previous 24 hours in the fight for Bakhmut, with Kyi ...

# %% [markdown]
# So the values gives us a list of documents that we can analyse.

# %%
# Get a list of documents
documents = list(articles.values())

# View first 400 characters of the 1st document
documents[0][:400]
# Out:
# "  6.26pm GMT       Good evening, we are closing this blog now. You can see all our Ukraine coverage here       6.06pm GMT    A summary of today's developments     Ukraine and Russia both claimed that hundreds of enemy troops had been killed in the previous 24 hours in the fight for Bakhmut, with Kyiv fending off attacks and a small river that bisects the town now marking the new frontline. Serhiy "

# %% [markdown]
# ### Term Count
#
# **Finding important terms by the frequency of their occurance**
#
# Using `CountVectorizer` create a `vector` for each document where the dimensionality of the vector is the `vocabulary` (all terms in the collection), and the value of each component is the number of times that the `term` occurs in the document.
#
# All of these analyses, approach the document as a [Bag of Words](https://en.wikipedia.org/wiki/Bag-of-words_model) model. In this approach, the order of the words don't matter. A popular approach that takes into account order is [Word embedding](https://en.wikipedia.org/wiki/Word_embedding). This session does not explore word embedding.

# %%
# Only count terms that in maximum of 75% of documents, and a minimum of 2 documents. 
# Count a maximum of 10000 terms, and remove common english stop words
count_vectorizer = CountVectorizer(max_df=0.75,min_df=2,max_features=10000,stop_words="english")
count_dt_matrix = count_vectorizer.fit_transform(articles.values())

# %%
# Take a look at the vector for the first document
doc001_vector = count_dt_matrix.toarray()[0]
doc001_vector
# Out:
# array([4, 0, 0, ..., 0, 0, 0])

# %%
# Get the 1000 terms identified during the vectorization process
feature_names = count_vectorizer.get_feature_names_out()
feature_names
# Out:
# array(['000', '000km', '00am', ..., 'подоляк', 'сhildren', 'та'],
#       dtype=object)

# %%
# Look at how the counts match up to the terms (for the 1st doc)
doc001_term_counts = list(zip(feature_names,doc001_vector))
doc001_term_counts
# Out:
# [('000', 4),
#  ('000km', 0),
#  ('00am', 0),
#  ('00pm', 1),
#  ('01am', 0),
#  ('01pm', 0),
#  ('020', 0),
#  ('02am', 0),
#  ('02pm', 0),
#  ('03am', 1),
#  ('03pm', 1),
#  ('04am', 1),
#  ('04pm', 0),
#  ('05am', 0),
#  ('05pm', 1),
#  ('06am', 0),
#  ('06pm', 2),
#  ('07am', 0),
#  ('07pm', 0),
#  ('08am', 0),
#  ('08pm', 1),
#  ('09am', 1),
#  ('09pm', 0),
#  ('10', 8),
#  ('100', 1),
#  ('1000', 0),
#  ('100bn', 0),
#  ('100m', 0),
#  ('101', 0),
#  ('106', 0),
#  ('10am', 0),
#  ('10bn', 0),
#  ('10m', 0),
#  ('10pm', 0),
#  ('10th', 0),
#  ('11', 11),
#  ('110', 0),
#  ('110m', 0),
#  ('114', 0),
#  ('115bn', 0),
#  ('116', 0),
#  ('11am', 1),
#  ('11pm', 0),
#  ('11th', 0),
#  ('12', 6),
#  ('120', 1),
#  ('122', 0),
#  ('123', 0),
#  ('125mm', 0),
#  ('129', 0),
#  ('12am', 0),
#  ('12pm', 0),
#  ('13', 1),
#  ('130', 0),
#  ('131', 0),
#  ('136', 0),
#  ('13am', 1),
#  ('13pm', 0),
#  ('14', 0),
#  ('140', 0),
#  ('141', 0),
#  ('147', 0),
#  ('14am', 1),
#  ('14bn', 0),
#  ('14pm', 1),
#  ('14th', 0),
#  ('15', 3),
#  ('150', 1),
#  ('150bn', 0),
#  ('150m', 2),
#  ('152', 1),
#  ('155', 0),
#  ('155mm', 0),
#  ('15am', 0),
#  ('15bn', 0),
#  ('15pm', 0),
#  ('15th', 0),
#  ('16', 0),
#  ('164', 0),
#  ('167', 0),
#  ('16am', 1),
#  ('16pm', 0),
#  ('16s', 0),
#  ('17', 1),
#  ('177', 0),
#  ('17am', 1),
#  ('17pm', 0),
#  ('18', 5),
#  ('180', 0),
#  ('180m', 2),
#  ('182', 0),
#  ('184', 0),
#  ('18am', 1),
#  ('18pm', 1),
#  ('19', 0),
#  ('1954', 0),
#  ('1960s', 0),
#  ('1967', 0),
#  ('1970s', 0),
#  ('1976', 0),
#  ('1980', 0),
#  ('1980s', 0),
#  ('1982', 0),
#  ('1990s', 0),
#  ('1991', 0),
#  ('1992', 0),
#  ('1996', 0),
#  ('1999', 0),
#  ('19am', 0),
#  ('19pm', 1),
#  ('1bn', 0),
#  ('1m', 0),
#  ('1pm', 0),
#  ('1st', 0),
#  ('1tn', 0),
#  ('20', 0),
#  ('200', 0),
#  ('2000', 0),
#  ('2001', 0),
#  ('2003', 0),
#  ('2004', 0),
#  ('2005', 0),
#  ('2006', 0),
#  ('2007', 0),
#  ('2008', 0),
#  ('2009', 0),
#  ('200m', 0),
#  ('2010', 0),
#  ('2011', 0),
#  ('2012', 0),
#  ('2013', 0),
#  ('2014', 0),
#  ('2015', 0),
#  ('2016', 0),
#  ('2017', 0),
#  ('2018', 0),
#  ('2019', 0),
#  ('2020', 0),
#  ('2020s', 0),
#  ('2021', 2),
#  ('2022', 4),
#  ('2023', 6),
#  ('2023find', 0),
#  ('2024', 0),
#  ('2025', 0),
#  ('2026', 0),
#  ('2027', 0),
#  ('2030', 0),
#  ('2030s', 0),
#  ('2032', 0),
#  ('2035', 0),
#  ('2040s', 0),
#  ('205', 0),
#  ('2050', 0),
#  ('2050s', 0),
#  ('20am', 0),
#  ('20bn', 0),
#  ('20km', 0),
#  ('20pm', 1),
#  ('20s', 0),
#  ('20th', 0),
#  ('21', 1),
#  ('210', 3),
#  ('215', 0),
#  ('21am', 1),
#  ('21pm', 1),
#  ('22', 0),
#  ('220', 1),
#  ('221', 4),
#  ('225', 0),
#  ('22am', 0),
#  ('22pm', 0),
#  ('23', 0),
#  ('235', 0),
#  ('23am', 0),
#  ('23pm', 0),
#  ('24', 5),
#  ('24am', 0),
#  ('24pm', 0),
#  ('24th', 0),
#  ('25', 0),
#  ('250', 0),
#  ('250m', 1),
#  ('25am', 0),
#  ('25bp', 0),
#  ('25m', 0),
#  ('25pm', 0),
#  ('26', 0),
#  ('268bn', 0),
#  ('26am', 0),
#  ('26m', 0),
#  ('26pm', 1),
#  ('27', 0),
#  ('275', 0),
#  ('27am', 0),
#  ('27pm', 0),
#  ('28', 0),
#  ('28am', 0),
#  ('28pm', 1),
#  ('29', 0),
#  ('298', 0),
#  ('29am', 0),
#  ('29pm', 0),
#  ('29s', 0),
#  ('2a4', 0),
#  ('2bn', 0),
#  ('2gb', 0),
#  ('2km', 0),
#  ('2m', 0),
#  ('2s', 0),
#  ('30', 3),
#  ('300', 6),
#  ('300km', 0),
#  ('308', 0),
#  ('30am', 3),
#  ('30bn', 0),
#  ('30pm', 0),
#  ('30s', 0),
#  ('30th', 0),
#  ('31', 0),
#  ('31am', 2),
#  ('31bn', 0),
#  ('31pm', 0),
#  ('31st', 0),
#  ('32', 0),
#  ('325', 0),
#  ('32am', 1),
#  ('32m', 0),
#  ('32pm', 0),
#  ('33', 0),
#  ('330', 0),
#  ('333', 0),
#  ('333m', 0),
#  ('33am', 0),
#  ('33pm', 0),
#  ('34', 0),
#  ('34am', 0),
#  ('34pm', 0),
#  ('35', 3),
#  ('350', 0),
#  ('350m', 0),
#  ('35am', 0),
#  ('35pm', 0),
#  ('36', 0),
#  ('360bn', 0),
#  ('368', 0),
#  ('368bn', 0),
#  ('36am', 1),
#  ('36pm', 1),
#  ('36th', 0),
#  ('37', 0),
#  ('37am', 1),
#  ('37pm', 1),
#  ('38', 0),
#  ('38am', 1),
#  ('38c', 0),
#  ('38pm', 2),
#  ('39', 3),
#  ('39am', 1),
#  ('39pm', 1),
#  ('3aw', 0),
#  ('3bn', 0),
#  ('3m', 0),
#  ('3pm', 0),
#  ('3rd', 0),
#  ('40', 5),
#  ('400', 0),
#  ('400m', 0),
#  ('40am', 0),
#  ('40c', 0),
#  ('40pm', 0),
#  ('41', 0),
#  ('418', 0),
#  ('41am', 0),
#  ('41pm', 0),
#  ('42', 1),
#  ('42am', 0),
#  ('42pm', 0),
#  ('43', 0),
#  ('43am', 0),
#  ('43pm', 2),
#  ('44', 0),
#  ('440', 0),
#  ('44am', 0),
#  ('44pm', 1),
#  ('45', 0),
#  ('45am', 0),
#  ('45pm', 0),
#  ('46', 1),
#  ('46am', 0),
#  ('46pm', 0),
#  ('47', 0),
#  ('470', 0),
#  ('47am', 1),
#  ('47pm', 2),
#  ('48', 3),
#  ('48am', 0),
#  ('48pm', 0),
#  ('49', 0),
#  ('49am', 0),
#  ('49pm', 1),
#  ('4am', 0),
#  ('4bn', 0),
#  ('4chan', 0),
#  ('4m', 0),
#  ('4pm', 0),
#  ('50', 0),
#  ('500', 3),
#  ('500m', 0),
#  ('50am', 0),
#  ('50bn', 0),
#  ('50pm', 0),
#  ('50th', 0),
#  ('51', 0),
#  ('51am', 0),
#  ('51pm', 1),
#  ('52', 0),
#  ('520m', 0),
#  ('52am', 1),
#  ('52pm', 1),
#  ('53', 0),
#  ('53am', 1),
#  ('53pm', 0),
#  ('54', 1),
#  ('54am', 0),
#  ('54pm', 0),
#  ('55', 0),
#  ('55am', 0),
#  ('55pm', 0),
#  ('56', 1),
#  ('560', 0),
#  ('56am', 1),
#  ('56pm', 2),
#  ('57', 0),
#  ('57am', 1),
#  ('57bn', 0),
#  ('57pm', 0),
#  ('58', 0),
#  ('58am', 0),
#  ('58pm', 0),
#  ('59', 0),
#  ('59am', 0),
#  ('59pm', 0),
#  ('5am', 0),
#  ('5bn', 0),
#  ('5c', 0),
#  ('5m', 0),
#  ('5pm', 0),
#  ('60', 1),
#  ('600', 0),
#  ('600m', 0),
#  ('603', 0),
#  ('60s', 0),
#  ('61', 0),
#  ('62', 0),
#  ('62s', 0),
#  ('63', 0),
#  ('64', 0),
#  ('65', 0),
#  ('65bn', 0),
#  ('65ft', 0),
#  ('66', 1),
#  ('67', 0),
#  ('68', 1),
#  ('680', 0),
#  ('69', 0),
#  ('6bn', 0),
#  ('6m', 0),
#  ('6pm', 0),
#  ('70', 1),
#  ('700', 0),
#  ('70s', 0),
#  ('71', 0),
#  ('72', 0),
#  ('730', 0),
#  ('74', 0),
#  ('75', 1),
#  ('750', 0),
#  ('76', 0),
#  ('77', 0),
#  ('78', 0),
#  ('7am', 0),
#  ('7bn', 0),
#  ('7m', 0),
#  ('80', 0),
#  ('800', 0),
#  ('80s', 0),
#  ('80th', 0),
#  ('81', 0),
#  ('82', 0),
#  ('83', 0),
#  ('85', 1),
#  ('86', 0),
#  ('88', 1),
#  ('880', 0),
#  ('88m', 0),
#  ('89', 0),
#  ('8am', 0),
#  ('8bn', 0),
#  ('8kg', 0),
#  ('8m', 0),
#  ('8pm', 0),
#  ('90', 1),
#  ('900', 0),
#  ('90bn', 0),
#  ('91', 0),
#  ('92', 4),
#  ('93', 0),
#  ('93rd', 0),
#  ('94', 0),
#  ('948', 0),
#  ('95', 0),
#  ('96', 0),
#  ('97', 0),
#  ('98', 0),
#  ('99', 0),
#  ('9am', 1),
#  ('9bn', 0),
#  ('9m', 0),
#  ('9pm', 0),
#  ('aap', 0),
#  ('aaron', 0),
#  ('abandon', 0),
#  ('abandoned', 0),
#  ('abandoning', 0),
#  ('abate', 0),
#  ('abatement', 0),
#  ('abbas', 0),
#  ('abbot', 0),
#  ('abbott', 0),
#  ('abc', 0),
#  ('abcnews', 0),
#  ('abdalkin', 0),
#  ('abdel', 0),
#  ('abducted', 0),
#  ('abducting', 0),
#  ('abduction', 0),
#  ('abhorrent', 0),
#  ('ability', 1),
#  ('abkhazia', 0),
#  ('able', 3),
#  ('abnormally', 0),
#  ('aboard', 0),
#  ('abolish', 0),
#  ('abolished', 0),
#  ('aboriginal', 0),
#  ('aborted', 0),
#  ('abortion', 0),
#  ('abramovich', 0),
#  ('abrams', 0),
#  ('abroad', 0),
#  ('abs', 0),
#  ('absence', 0),
#  ('absent', 0),
#  ('absentee', 0),
#  ('absentia', 0),
#  ('absolut', 0),
#  ('absolute', 0),
#  ('absolutely', 0),
#  ('absstats', 0),
#  ('abstaining', 0),
#  ('absurd', 0),
#  ('absurdity', 0),
#  ('abu', 0),
#  ('abuse', 0),
#  ('abused', 0),
#  ('abuses', 0),
#  ('abusing', 0),
#  ('academic', 0),
#  ('academics', 0),
#  ('academy', 0),
#  ('accc', 0),
#  ('accelerate', 0),
#  ('accelerated', 0),
#  ('accelerating', 0),
#  ('accept', 0),
#  ('acceptable', 1),
#  ('acceptance', 0),
#  ('accepted', 0),
#  ('accepting', 0),
#  ('accepts', 0),
#  ('access', 0),
#  ('accessed', 0),
#  ('accessible', 0),
#  ('accessing', 0),
#  ('accession', 0),
#  ('accident', 0),
#  ('accidentally', 0),
#  ('accidents', 0),
#  ('accommodate', 0),
#  ('accommodating', 0),
#  ('accommodation', 0),
#  ('accompanied', 0),
#  ('accompany', 0),
#  ('accompanying', 0),
#  ('accomplice', 0),
#  ('accord', 0),
#  ('accordance', 0),
#  ('accordingly', 0),
#  ('account', 0),
#  ('accountability', 0),
#  ('accountable', 0),
#  ('accounted', 0),
#  ('accounts', 0),
#  ('accuracy', 0),
#  ('accurate', 0),
#  ('accus', 0),
#  ('accusation', 0),
#  ('accusations', 0),
#  ('accuse', 0),
#  ('accused', 0),
#  ('accuses', 0),
#  ('accusing', 0),
#  ('acf', 0),
#  ('achieve', 0),
#  ('achieved', 0),
#  ('achievement', 0),
#  ('achievements', 0),
#  ('achieving', 0),
#  ('acknowledge', 0),
#  ('acknowledged', 1),
#  ('acknowledgement', 0),
#  ('acknowledges', 0),
#  ('acknowledgment', 0),
#  ('acoss', 0),
#  ('acquire', 0),
#  ('acquired', 0),
#  ('acquiring', 0),
#  ('acquisition', 0),
#  ('act', 1),
#  ('acted', 0),
#  ('acting', 0),
#  ('action', 2),
#  ('actions', 0),
#  ('activated', 0),
#  ('active', 0),
#  ('actively', 0),
#  ('activist', 0),
#  ('activists', 0),
#  ('activities', 0),
#  ('activity', 0),
#  ('actor', 0),
#  ('actors', 1),
#  ('acts', 0),
#  ('actu', 0),
#  ('actual', 0),
#  ('actually', 0),
#  ('acu', 0),
#  ('acute', 0),
#  ('ad', 0),
#  ('adam', 0),
#  ('adams', 0),
#  ('adapt', 0),
#  ('adaptable', 0),
#  ('add', 0),
#  ('added', 2),
#  ('addiction', 0),
#  ('addicts', 0),
#  ('adding', 1),
#  ('addition', 0),
#  ('additional', 0),
#  ('additionally', 0),
#  ('address', 5),
#  ('addressed', 1),
#  ('addresses', 0),
#  ('addressing', 0),
#  ('adds', 0),
#  ('adelaide', 0),
#  ('adequacy', 0),
#  ('adequate', 0),
#  ('adequately', 0),
#  ('adf', 0),
#  ('adhere', 0),
#  ('adjacent', 0),
#  ('adjunct', 0),
#  ('adjust', 0),
#  ('adjusted', 0),
#  ('adjustment', 0),
#  ('adm', 0),
#  ('administration', 1),
#  ('administrative', 0),
#  ('administrator', 0),
#  ('admiral', 0),
#  ('admire', 0),
#  ('admission', 0),
#  ('admit', 0),
#  ('admits', 0),
#  ('admitted', 0),
#  ('admitting', 0),
#  ('adopt', 0),
#  ('adopted', 0),
#  ('adopting', 0),
#  ('adoption', 0),
#  ('adoptions', 0),
#  ('ads', 0),
#  ('adult', 0),
#  ('adults', 0),
#  ('advance', 2),
#  ('advanced', 1),
#  ('advancement', 0),
#  ('advances', 4),
#  ('advancing', 0),
#  ('advantage', 0),
#  ('advantages', 0),
#  ('adversaries', 0),
#  ('adversary', 0),
#  ('adverse', 0),
#  ('advertisements', 0),
#  ('advertising', 0),
#  ('advice', 0),
#  ('advise', 0),
#  ('advised', 0),
#  ('adviser', 0),
#  ('advisers', 0),
#  ('advising', 0),
#  ('advisor', 0),
#  ('advisory', 0),
#  ('advocacy', 0),
#  ('advocate', 0),
#  ('advocated', 0),
#  ('advocates', 0),
#  ('advocating', 0),
#  ('aec', 0),
#  ('aedt', 0),
#  ('aemo', 0),
#  ('aerial', 0),
#  ('aerospace', 0),
#  ('aest', 0),
#  ('affairs', 0),
#  ('affect', 0),
#  ('affected', 0),
#  ('affecting', 1),
#  ('affects', 0),
#  ('affiliated', 0),
#  ('affirm', 0),
#  ('affirming', 0),
#  ('afford', 1),
#  ('affordability', 0),
#  ('affordable', 0),
#  ('afghan', 0),
#  ('afghanistan', 0),
#  ('afl', 0),
#  ('afp', 3),
#  ('afr', 0),
#  ('afraid', 0),
#  ('africa', 0),
#  ('african', 0),
#  ('aftermath', 0),
#  ('afternoon', 0),
#  ('ag', 0),
#  ('age', 0),
#  ('aged', 0),
#  ('ageing', 0),
#  ('agence', 0),
#  ('agencies', 0),
#  ('agency', 2),
#  ('agenda', 0),
#  ('agent', 3),
#  ('agents', 0),
#  ('aggravated', 0),
#  ('aggression', 1),
#  ('aggressive', 0),
#  ('aggressor', 0),
#  ('aggressors', 0),
#  ('agitator', 0),
#  ('agl', 0),
#  ('agm', 0),
#  ('ago', 0),
#  ('agrarian', 0),
#  ('agree', 1),
#  ('agreed', 1),
#  ('agreeing', 0),
#  ('agreement', 0),
#  ('agreements', 0),
#  ('agrees', 0),
#  ('agricultural', 1),
#  ('agriculture', 0),
#  ('ahead', 0),
#  ('ahmed', 0),
#  ('ahmedabad', 0),
#  ('ai', 0),
#  ('aid', 0),
#  ('aide', 0),
#  ('aiding', 0),
#  ('ailment', 0),
#  ('aim', 2),
#  ('aimed', 1),
#  ('aiming', 0),
#  ('aims', 0),
#  ('air', 5),
#  ('airbase', 0),
#  ('airborne', 0),
#  ('aircraft', 3),
#  ('aired', 0),
#  ('airfares', 0),
#  ('airfield', 0),
#  ('airlifted', 0),
#  ('airline', 0),
#  ('airlines', 0),
#  ('airman', 0),
#  ('airport', 0),
#  ('airshow', 0),
#  ('airspace', 0),
#  ('airstrike', 0),
#  ('airstrikes', 1),
#  ('akar', 4),
#  ('akhmedov', 0),
#  ('aksyonov', 0),
#  ('al', 0),
#  ('alan', 0),
#  ('alarm', 0),
#  ('alarming', 0),
#  ('alas', 0),
#  ('albanese', 0),
#  ('albeit', 0),
#  ('albert', 0),
#  ('albina', 0),
#  ('albomp', 0),
#  ('albury', 0),
#  ('alcohol', 0),
#  ('alcoholic', 0),
#  ('aleksandar', 0),
#  ('alekseyevna', 0),
#  ('alert', 0),
#  ('alerts', 0),
#  ('ales', 0),
#  ('alessio', 0),
#  ('alex', 0),
#  ('alexander', 2),
#  ('alexei', 0),
#  ('alexey', 0),
#  ('alice', 0),
#  ('align', 0),
#  ('aligned', 3),
#  ('aligning', 0),
#  ('alignment', 0),
#  ('alina', 0),
#  ('alisher', 0),
#  ('alison', 0),
#  ('alition', 0),
#  ('alive', 0),
#  ('allan', 0),
#  ('allay', 0),
#  ('allegation', 0),
#  ('allegations', 0),
#  ('allege', 0),
#  ('alleged', 0),
#  ('allegedly', 0),
#  ('alleges', 0),
#  ('alleging', 0),
#  ('allegra', 0),
#  ('alliance', 0),
#  ('alliances', 0),
#  ('allied', 0),
#  ('allies', 2),
#  ('allocate', 0),
#  ('allocated', 0),
#  ('allocation', 0),
#  ('allow', 1),
#  ('allowance', 0),
#  ('allowed', 0),
#  ('allowing', 4),
#  ('allows', 0),
#  ('ally', 1),
#  ('alongside', 0),
#  ('alter', 0),
#  ('alteration', 0),
#  ('altered', 0),
#  ('alternative', 0),
#  ('alternatives', 0),
#  ('altitude', 0),
#  ('aluminium', 7),
#  ('aly', 0),
#  ('amanda', 0),
#  ('amass', 0),
#  ('amazing', 0),
#  ('amazon', 0),
#  ('ambassador', 0),
#  ('ambassadors', 0),
#  ('ambition', 0),
#  ('ambitions', 0),
#  ('ambitious', 0),
#  ('ambulance', 0),
#  ('amend', 0),
#  ('amended', 0),
#  ('amendment', 0),
#  ('amendments', 0),
#  ('america', 0),
#  ('american', 0),
#  ('americans', 0),
#  ('americas', 0),
#  ('amid', 2),
#  ('amidst', 0),
#  ('ammunition', 10),
#  ('amounted', 1),
#  ('amounts', 0),
#  ('amp', 3),
#  ('amy', 0),
#  ('amyremeikis', 0),
#  ('anadolu', 1),
#  ('analysed', 0),
#  ('analyses', 0),
#  ('analysis', 0),
#  ('analyst', 0),
#  ('analysts', 0),
#  ('anand', 0),
#  ('ananda', 0),
#  ('anastasia', 0),
#  ('anatolii', 0),
#  ('anatoliy', 0),
#  ('anatoly', 0),
#  ('anchor', 0),
#  ('ancient', 0),
#  ('andersen', 0),
#  ('anderson', 0),
#  ('andrei', 0),
#  ('andrew', 1),
#  ('andrews', 0),
#  ('andriivka', 0),
#  ('andriy', 0),
#  ('andriyyermak', 0),
#  ('android', 0),
#  ('andromeda', 0),
#  ('andrzej', 0),
#  ('andy', 0),
#  ('angel', 0),
#  ('angels', 0),
#  ('anger', 0),
#  ('angered', 0),
#  ('angie', 0),
#  ('angles', 0),
#  ('anglo', 0),
#  ('angry', 0),
#  ('angus', 0),
#  ('anika', 0),
#  ('animal', 0),
#  ('animals', 0),
#  ('anita', 0),
#  ('ankara', 0),
#  ('anna', 0),
#  ('annalena', 0),
#  ('annastacia', 0),
#  ('anne', 0),
#  ('annex', 0),
#  ('annexation', 0),
#  ('annexed', 0),
#  ('anniken', 0),
#  ('anniversary', 0),
#  ('announce', 0),
#  ('announced', 2),
#  ('announcement', 0),
#  ('announcements', 0),
#  ('announces', 0),
#  ('announcing', 0),
#  ('annual', 1),
#  ('annually', 0),
#  ('anonymity', 0),
#  ('anonymous', 0),
#  ('answer', 1),
#  ('answered', 0),
#  ('answering', 0),
#  ('answers', 0),
#  ('antarctic', 0),
#  ('anthems', 0),
#  ('anthony', 0),
#  ('anti', 2),
#  ('antic', 0),
#  ('anticipated', 0),
#  ('anticipates', 0),
#  ('anticipation', 0),
#  ('antipoverty', 0),
#  ('antisemitic', 0),
#  ('antisemitism', 0),
#  ('anton', 0),
#  ('antonio', 1),
#  ('antonov', 0),
#  ('antony', 0),
#  ('antoun', 0),
#  ('antónio', 0),
#  ('anu', 0),
#  ('anxiety', 0),
#  ('anybody', 0),
#  ('anytime', 0),
#  ('anz', 0),
#  ('ao', 0),
#  ('ap', 2),
#  ('apart', 0),
#  ('apartment', 0),
#  ('apga', 0),
#  ('apocalypse', 0),
#  ('apologies', 0),
#  ('apologise', 0),
#  ('apologised', 0),
#  ('apologises', 0),
#  ('apology', 0),
#  ('app', 0),
#  ('appalled', 0),
#  ('appalling', 0),
#  ('apparent', 0),
#  ('apparently', 1),
#  ('appeal', 1),
#  ('appealed', 0),
#  ('appealing', 0),
#  ('appeals', 0),
#  ('appear', 0),
#  ('appearance', 0),
#  ('appearances', 0),
#  ('appeared', 0),
#  ('appearing', 0),
#  ('appears', 0),
#  ('appetite', 0),
#  ('applause', 0),
#  ('applicants', 0),
#  ('application', 0),
#  ('applications', 0),
#  ('applied', 0),
#  ('applies', 0),
#  ('apply', 0),
#  ('applying', 0),
#  ('appointed', 0),
#  ('appointment', 0),
#  ('appointments', 0),
#  ('appreciate', 0),
#  ('appreciated', 0),
#  ('appreciation', 0),
#  ('apprentices', 0),
#  ('approach', 1),
#  ('approached', 0),
#  ('approaches', 0),
#  ('approaching', 1),
#  ('appropriate', 0),
#  ('appropriately', 0),
#  ('approval', 0),
#  ('approvals', 0),
#  ('approve', 0),
#  ('approved', 0),
#  ('approves', 0),
#  ('approving', 0),
#  ('approximately', 0),
#  ('apps', 0),
#  ('april', 0),
#  ('arab', 0),
#  ('arabia', 1),
#  ('arbitrary', 0),
#  ('arbitration', 0),
#  ('archaeologist', 0),
#  ('archbishop', 1),
#  ('archer', 0),
#  ('archibald', 0),
#  ('architecture', 0),
#  ('arctic', 0),
#  ('ardern', 0),
#  ('area', 1),
#  ('areas', 3),
#  ('aren', 0),
#  ('arena', 0),
#  ('argentina', 0),
#  ('arguably', 0),
#  ('argue', 0),
#  ('argued', 0),
#  ('argues', 0),
#  ('arguing', 0),
#  ('argument', 0),
#  ('arguments', 0),
#  ('aris', 1),
#  ('arising', 0),
#  ('arizona', 0),
#  ('arm', 0),
#  ('armata', 0),
#  ('armed', 5),
#  ('arming', 0),
#  ('armour', 0),
#  ('armoured', 2),
#  ('arms', 3),
#  ('army', 2),
#  ('arnhem', 0),
#  ('arrangement', 0),
#  ('arrangements', 0),
#  ('arrest', 0),
#  ('arrested', 1),
#  ('arrests', 0),
#  ('arrival', 0),
#  ('arrivals', 0),
#  ('arrive', 0),
#  ('arrived', 0),
#  ('arrives', 0),
#  ('arriving', 0),
#  ('arsenal', 0),
#  ('art', 0),
#  ('arthur', 0),
#  ('article', 0),
#  ('articles', 0),
#  ('artificial', 0),
#  ('artillery', 2),
#  ('artist', 0),
#  ('artists', 0),
#  ('arts', 0),
#  ('artyom', 0),
#  ('asean', 0),
#  ('ash', 0),
#  ...]

# %%
# Take a look at the vocabulary which shows the total counts for whole collection
count_vectorizer.vocabulary_
# Out:
# {'26pm': 191,
#  'gmt': 4069,
#  'good': 4083,
#  'evening': 3369,
#  'closing': 1943,
#  'blog': 1381,
#  'coverage': 2370,
#  '06pm': 16,
#  'summary': 8695,
#  'today': 9079,
#  'developments': 2757,
#  'claimed': 1894,
#  'hundreds': 4499,
#  'enemy': 3240,
#  'troops': 9229,
#  'killed': 5062,
#  'previous': 6847,
#  '24': 176,
#  'hours': 4472,
#  'fight': 3677,
#  'bakhmut': 1171,
#  'kyiv': 5138,
#  'attacks': 1067,
#  'small': 8284,
#  'river': 7727,
#  'town': 9126,
#  'marking': 5578,
#  'frontline': 3920,
#  'serhiy': 8049,
#  'cherevatyi': 1833,
#  'ukrainian': 9303,
#  'military': 5764,
#  'spokesperson': 8419,
#  '221': 168,
#  'pro': 6891,
#  'moscow': 5884,
#  '300': 211,
#  'wounded': 9881,
#  'defence': 2603,
#  'ministry': 5787,
#  '210': 162,
#  'soldiers': 8312,
#  'broader': 1528,
#  'donetsk': 2958,
#  'repelled': 7508,
#  '92': 406,
#  'assaults': 1020,
#  'areas': 953,
#  'past': 6453,
#  'day': 2527,
#  'general': 4007,
#  'staff': 8460,
#  'armed': 969,
#  'forces': 3820,
#  'institute': 4749,
#  'study': 8624,
#  'did': 2767,
#  'make': 5509,
#  'advances': 600,
#  'saturday': 7897,
#  'turkish': 9264,
#  'hulusi': 4492,
#  'akar': 705,
#  'believed': 1279,
#  'deal': 2537,
#  'allowing': 761,
#  'grain': 4117,
#  'exported': 3490,
#  'black': 1357,
#  'sea': 7960,
#  'extended': 3509,
#  '18': 87,
#  'march': 5548,
#  'deadline': 2533,
#  'foreign': 3829,
#  'representatives': 7528,
#  'taken': 8842,
#  'negotiations': 6020,
#  'extending': 3510,
#  'national': 5977,
#  'police': 6672,
#  'reported': 7518,
#  'launched': 5204,
#  '48': 295,
#  'civilians': 1891,
#  'oblast': 6146,
#  '15': 66,
#  'cities': 1881,
#  'towns': 9127,
#  'including': 4629,
#  'kostyantynivka': 5113,
#  'avdiivka': 1120,
#  'come': 2013,
#  'attack': 1064,
#  'shelling': 8127,
#  'kherson': 5052,
#  'southern': 8352,
#  'president': 6822,
#  'volodymyr': 9606,
#  'zelenskiy': 9976,
#  'denouncing': 2668,
#  'called': 1620,
#  'brutal': 1545,
#  'terrorist': 8969,
#  'units': 9385,
#  '40': 265,
#  'missiles': 5808,
#  'hit': 4402,
#  'north': 6087,
#  'eastern': 3075,
#  'city': 1886,
#  'kharkiv': 5051,
#  'beginning': 1260,
#  'nightly': 6057,
#  'address': 562,
#  'moldovan': 5845,
#  'claim': 1893,
#  'foiled': 3797,
#  'plot': 6650,
#  'backed': 1153,
#  'groups': 4175,
#  'trained': 9154,
#  'cause': 1723,
#  'mass': 5593,
#  'unrest': 9416,
#  'protest': 7009,
#  'agent': 657,
#  'citizens': 1884,
#  'promised': 6960,
#  '10': 23,
#  '000': 0,
#  'create': 2389,
#  'disorder': 2860,
#  'destabilise': 2724,
#  'moldova': 5844,
#  'head': 4299,
#  'force': 3818,
#  'told': 9081,
#  'conference': 2138,
#  'urged': 9453,
#  'germany': 4036,
#  'interview': 4814,
#  'published': 7051,
#  'sunday': 8703,
#  'speed': 8393,
#  'supplies': 8720,
#  'ammunition': 793,
#  'start': 8487,
#  'training': 9155,
#  'pilots': 6604,
#  'western': 9750,
#  'fighter': 3678,
#  'jets': 4937,
#  'dmytro': 2916,
#  'kuleba': 5131,
#  'bild': 1331,
#  'sonntag': 8330,
#  'newspaper': 6045,
#  'shortages': 8165,
#  'number': 6129,
#  'problem': 6895,
#  'attempt': 1068,
#  'repel': 7507,
#  'invasion': 4829,
#  'switzerland': 8808,
#  'scrapping': 7955,
#  'outdated': 6316,
#  'surface': 8738,
#  'air': 689,
#  'used': 9463,
#  'shoot': 8157,
#  'low': 5442,
#  'flying': 3788,
#  'targets': 8868,
#  'swiss': 8804,
#  'zeitung': 9973,
#  'prime': 6860,
#  'denys': 2672,
#  'shmyhal': 8149,
#  'thanked': 8983,
#  'canada': 1640,
#  'decision': 2569,
#  'ban': 1184,
#  'imports': 4599,
#  'aluminium': 771,
#  'steel': 8517,
#  'products': 6924,
#  'countries': 2352,
#  'maria': 5561,
#  'zakharova': 9961,
#  'reportedly': 7519,
#  'infighting': 4684,
#  'kremlin': 5125,
#  'inner': 4718,
#  'circle': 1871,
#  'effect': 3105,
#  'control': 2264,
#  'information': 4700,
#  'space': 8359,
#  'patriarch': 6464,
#  'kirill': 5080,
#  'orthodox': 6302,
#  'church': 1867,
#  'asked': 1007,
#  'pope': 6702,
#  'francis': 3883,
#  'religious': 7441,
#  'leaders': 5229,
#  'persuade': 6550,
#  'stop': 8553,
#  'crackdown': 2380,
#  'historically': 4400,
#  'aligned': 733,
#  'wing': 9801,
#  'britons': 1519,
#  'think': 8999,
#  'housing': 4477,
#  'refugees': 7361,
#  'thing': 8997,
#  'shows': 8182,
#  'took': 9094,
#  'ukrainians': 9304,
#  'fleeing': 3760,
#  'positive': 6731,
#  'experience': 3459,
#  'hosting': 4464,
#  'public': 7046,
#  'uk': 9302,
#  'continue': 2244,
#  'zones': 9989,
#  'updated': 9432,
#  '21pm': 165,
#  '49pm': 300,
#  'thousands': 9017,
#  'gathered': 3989,
#  'capital': 1661,
#  'chișinău': 1847,
#  'organised': 6287,
#  'party': 6440,
#  'demonstrators': 2660,
#  'criticised': 2424,
#  'european': 3355,
#  'rise': 7713,
#  'cost': 2326,
#  'living': 5375,
#  'reduced': 7327,
#  'gas': 3985,
#  'bills': 1338,
#  'risen': 7714,
#  'fold': 3799,
#  'million': 5769,
#  'energy': 3242,
#  'crisis': 2416,
#  'neighbouring': 6024,
#  'contributed': 2259,
#  '30': 210,
#  'inflation': 4687,
#  'economic': 3083,
#  'help': 4346,
#  'struggling': 8616,
#  'live': 5371,
#  '70': 369,
#  'ivan': 4902,
#  '85': 391,
#  'pension': 6510,
#  'equivalent': 3308,
#  '100': 24,
#  'month': 5863,
#  'afford': 636,
#  'buy': 1599,
#  'eat': 3077,
#  'little': 5369,
#  'bread': 1485,
#  'electricity': 3138,
#  'cheaper': 1819,
#  'democracy': 2650,
#  'rich': 7689,
#  'related': 7416,
#  'protesters': 7012,
#  'gather': 3988,
#  'amid': 791,
#  'fears': 3628,
#  'orchestrated': 6277,
#  'violence': 9566,
#  '56pm': 332,
#  '14pm': 64,
#  'seven': 8079,
#  'detained': 2735,
#  '54': 323,
#  'arrested': 979,
#  'bomb': 1415,
#  'threats': 9023,
#  'registered': 7385,
#  'series': 8050,
#  'held': 4340,
#  'eu': 3349,
#  'group': 4173,
#  'movement': 5910,
#  'friendly': 3910,
#  'holds': 4416,
#  'seats': 7972,
#  'legislature': 5264,
#  'led': 5249,
#  'sanctioned': 7884,
#  'oligarch': 6223,
#  'sky': 8256,
#  '47pm': 294,
#  'tweeted': 9278,
#  'holding': 4414,
#  'talks': 8850,
#  'czech': 2488,
#  'counterpart': 2347,
#  'petr': 6561,
#  'pavel': 6479,
#  'congratulated': 2162,
#  'officially': 6196,
#  'taking': 8845,
#  'office': 6191,
#  'outlined': 6322,
#  'situation': 8242,
#  'amp': 796,
#  'security': 7991,
#  'needs': 6012,
#  'discussed': 2846,
#  'integration': 4765,
#  'agreed': 670,
#  'cooperate': 2290,
#  'support': 8723,
#  'crucial': 2446,
#  'fighting': 3680,
#  'rf': 7683,
#  '39': 257,
#  'aggression': 660,
#  'mdash': 5635,
#  'володимир': 9994,
#  'зеленський': 9995,
#  'zelenskyyua': 9978,
#  '12': 44,
#  '2023': 141,
#  '38pm': 256,
#  '20pm': 158,
#  '66': 361,
#  'injured': 4712,
#  'recent': 7281,
#  'outside': 6334,
#  'destroyed': 2728,
#  'home': 4426,
#  'photograph': 6577,
#  'alexander': 728,
#  'ermochenko': 3314,
#  'reuters': 7656,
#  '36pm': 248,
#  '19pm': 109,
#  'tanks': 8860,
#  'armoured': 972,
#  'vehicles': 9509,
#  'display': 2864,
#  'near': 5999,
#  'st': 8450,
#  'michael': 5741,
#  'cathedral': 1716,
#  'andrew': 816,
#  'ap': 885,
#  '18pm': 93,
#  'volunteer': 9610,
#  'army': 974,
#  'drive': 3006,
#  'vehicle': 9508,
#  'sergey': 8046,
#  'afp': 642,
#  'getty': 4041,
#  'images': 4562,
#  '37pm': 252,
#  '44pm': 284,
#  'key': 5044,
#  'events': 3371,
#  'believes': 1281,
#  'current': 2469,
#  'came': 1625,
#  'prohibits': 6948,
#  'purchase': 7071,
#  'arms': 973,
#  'exporting': 3493,
#  'permission': 6532,
#  '05pm': 14,
#  'independent': 4650,
#  'attacked': 1065,
#  'region': 7381,
#  'aircraft': 692,
#  'grad': 4108,
#  'multiple': 5927,
#  'rocket': 7745,
#  'launchers': 5205,
#  'artillery': 993,
#  'mortars': 5879,
#  'report': 7517,
#  'governor': 4101,
#  'pavlo': 6481,
#  'kyrylenko': 5143,
#  'daily': 2491,
#  'briefing': 1504,
#  'fiercest': 3673,
#  'continues': 2246,
#  'rage': 7154,
#  'embattled': 3167,
#  'slowly': 8282,
#  'makes': 5512,
#  'progress': 6939,
#  'capture': 1669,
#  'ruined': 7814,
#  'recorded': 7308,
#  'settlements': 8076,
#  'chasiv': 1815,
#  'yar': 9914,
#  '08pm': 20,
#  '39pm': 259,
#  'berset': 1308,
#  'defended': 2609,
#  'controversial': 2269,
#  'transferring': 9168,
#  'saying': 7913,
#  'weapons': 9713,
#  'wars': 9682,
#  'member': 5688,
#  'followed': 3803,
#  'bloc': 1373,
#  'lead': 5227,
#  'sanctions': 7885,
#  'targeting': 8867,
#  'far': 3593,
#  'shown': 8181,
#  'flexibility': 3765,
#  'neutrality': 6038,
#  'despite': 2723,
#  'pressure': 6830,
#  'allies': 754,
#  'continued': 2245,
#  'block': 1374,
#  'hold': 4411,
#  'weaponry': 9712,
#  'date': 2517,
#  'requests': 7542,
#  'spain': 8361,
#  'denmark': 2666,
#  'rejected': 7412,
#  'act': 529,
#  'bars': 1211,
#  'export': 3489,
#  'recipient': 7286,
#  'international': 4803,
#  'conflict': 2151,
#  'policy': 6675,
#  'based': 1213,
#  'commitment': 2039,
#  'peace': 6490,
#  'humanitarian': 4494,
#  'law': 5213,
#  'mediation': 5663,
#  'possible': 6736,
#  'role': 7755,
#  'seat': 7971,
#  'committee': 2043,
#  'red': 7324,
#  'cross': 2436,
#  'geneva': 4020,
#  'conventions': 2276,
#  'united': 9383,
#  'nations': 5982,
#  'headquarters': 4305,
#  'reflected': 7348,
#  'laws': 5218,
#  'relating': 7418,
#  'protection': 7005,
#  'human': 4493,
#  'rights': 7704,
#  'sound': 8342,
#  'important': 4596,
#  'warning': 9672,
#  'extremely': 3531,
#  'dangerous': 2501,
#  'throw': 9026,
#  'fundamental': 3945,
#  'principles': 6868,
#  'concerned': 2111,
#  'warfare': 9663,
#  'dna': 2918,
#  'stressing': 8591,
#  'nation': 5976,
#  'aimed': 686,
#  'present': 6814,
#  'contribute': 2258,
#  'needed': 6010,
#  'end': 3224,
#  'sooner': 8332,
#  'better': 1313,
#  'initiatives': 4710,
#  'way': 9700,
#  'parliament': 6417,
#  'rules': 7819,
#  'transferred': 9167,
#  'stressed': 8590,
#  'position': 6728,
#  'clear': 1917,
#  'personal': 6543,
#  'process': 6905,
#  'final': 3693,
#  'debates': 2547,
#  'probable': 6892,
#  'referendum': 7339,
#  'direct': 2802,
#  'likely': 5329,
#  'months': 5865,
#  '52pm': 319,
#  'federal': 3637,
#  'procurement': 6913,
#  'short': 8163,
#  'range': 7190,
#  'anti': 865,
#  'missile': 5807,
#  'systems': 8826,
#  'dismantled': 2857,
#  'originally': 6296,
#  'developed': 2753,
#  'british': 1518,
#  'capable': 1658,
#  'shooting': 8158,
#  'highly': 4379,
#  'disposal': 2867,
#  'caused': 1724,
#  'backlash': 1158,
#  'politicians': 6681,
#  'send': 8018,
#  'directly': 2806,
#  'indirectly': 4669,
#  'refused': 7365,
#  'let': 5282,
#  'transfer': 9166,
#  'guns': 4212,
#  'february': 3635,
#  '51pm': 315,
#  '28pm': 198,
#  'conduct': 2135,
#  'operations': 6250,
#  'direction': 2804,
#  '220': 167,
#  'servicemen': 8063,
#  'infantry': 4682,
#  'howitzer': 4480,
#  'quoted': 7135,
#  'able': 440,
#  'independently': 4651,
#  'verify': 9520,
#  'claims': 1896,
#  'sides': 8194,
#  'say': 7912,
#  'inflicted': 4690,
#  'significant': 8208,
#  'losses': 5432,
#  'exact': 3387,
#  'numbers': 6130,
#  'difficult': 2780,
#  '500': 307,
#  'hour': 4471,
#  'period': 6528,
#  'wagner': 9639,
#  'mercenaries': 5710,
#  'captured': 1670,
#  'territory': 8965,
#  'outskirts': 6335,
#  'south': 8349,
#  'failed': 3566,
#  'encircle': 3214,
#  'completely': 2084,
#  'says': 7914,
#  'capturing': 1671,
#  'punch': 7061,
#  'hole': 4417,
#  'defences': 2605,
#  'step': 8523,
#  'seizing': 8004,
#  'donbas': 2957,
#  'industrial': 4675,
#  'major': 5507,
#  'target': 8865,
#  '43pm': 280,
#  'ability': 438,
#  'finance': 3699,
#  'steps': 8529,
#  'victory': 9540,
#  'grateful': 4131,
#  'banning': 1193,
#  'hope': 4443,
#  'similar': 8219,
#  'decisions': 2570,
#  'machine': 5479,
#  'announced': 849,
#  'friday': 3908,
#  'aim': 685,
#  'denying': 2671,
#  'revenues': 7664,
#  'fund': 3944,
#  'worth': 9877,
#  '180m': 89,
#  '150m': 69,
#  '2021': 139,
#  'latest': 5195,
#  'data': 2515,
#  'partners': 6436,
#  'central': 1752,
#  'bank': 1187,
#  'capped': 1664,
#  'price': 6850,
#  'oil': 6206,
#  'deputy': 2700,
#  'chrystia': 1864,
#  'freeland': 3895,
#  'statement': 8495,
#  'ensuring': 3271,
#  'putin': 7090,
#  'pay': 6482,
#  'selling': 8011,
#  'coordination': 2296,
#  'action': 532,
#  'states': 8497,
#  '03pm': 10,
#  '11': 35,
#  '56am': 331,
#  'saudi': 7898,
#  'arabia': 942,
#  'giant': 4043,
#  'record': 7307,
#  'annual': 854,
#  'net': 6031,
#  'profit': 6932,
#  '2022': 140,
#  '46': 288,
#  'higher': 4373,
#  'prices': 6851,
#  'increased': 4639,
#  'volumes': 9608,
#  'sold': 8310,
#  'improved': 4608,
#  'margins': 5560,
#  'refined': 7344,
#  'profits': 6933,
#  'triple': 9225,
#  'follow': 3802,
#  'reports': 7523,
#  'peers': 6500,
#  'shell': 8125,
#  'chevron': 1835,
#  'posted': 6740,
#  'geopolitical': 4026,
#  'worries': 9869,
#  'sliding': 8266,
#  'weaker': 9706,
#  'demand': 2642,
#  'china': 1843,
#  'global': 4064,
#  '00pm': 3,
#  '31am': 220,
#  'detailed': 2732,
#  'polling': 6686,
#  'common': 2048,
#  'civil': 1889,
#  'society': 8304,
#  'organisation': 6284,
#  '88': 393,
#  'compared': 2063,
#  '68': 363,
#  'believe': 1278,
#  'fact': 3554,
#  '150': 67,
#  '17': 83,
#  'bad': 1163,
#  'findings': 3706,
#  'controversy': 2270,
#  'rishi': 7716,
#  'sunak': 8702,
#  'deporting': 2692,
#  'flee': 3759,
#  'channel': 1796,
#  'boats': 1400,
#  'prompting': 6971,
#  'outrage': 6328,
#  'campaigners': 1632,
#  'refugee': 7360,
#  'agency': 655,
#  'read': 7235,
#  '36am': 247,
#  '14am': 62,
#  'subject': 8635,
#  'especially': 3329,
#  'participation': 6429,
#  'round': 7785,
#  '13': 52,
#  'delegation': 2629,
#  'trade': 9141,
#  'official': 6195,
#  '38am': 254,
#  '11am': 41,
#  'initiative': 4709,
#  'brokered': 1533,
#  'turkey': 9263,
#  'july': 4985,
#  'intended': 4769,
#  'prevent': 6840,
#  'food': 3809,
#  'blockaded': 1376,
#  'safely': 7860,
#  'ports': 6720,
#  '120': 45,
#  'days': 2528,
#  'november': 6112,
#  'renew': 7478,
#  'objects': 6145,
#  'signalled': 8200,
#  'agree': 669,
#  'extension': 3512,
#  'restrictions': 7618,
#  'affecting': 631,
#  'exports': 3494,
#  'lifted': 5322,
#  'previously': 6848,
#  'working': 9859,
#  'hard': 4264,
#  'extend': 3508,
#  'separate': 8034,
#  'saw': 7911,
#  'approaching': 929,
#  'positively': 6732,
#  'conclude': 2119,
#  'state': 8493,
#  'owned': 6355,
#  'anadolu': 799,
#  'opinion': 6254,
#  'duration': 3042,
#  'west': 9749,
#  'explicitly': 3477,
#  'targeted': 8866,
#  'agricultural': 675,
#  'payments': 6486,
#  'logistics': 5410,
#  'insurance': 4761,
#  'industries': 4677,
#  'barrier': 1206,
#  'fertilisers': 3663,
#  'complained': 2079,
#  'going': 4075,
#  'wealthy': 9710,
#  '30am': 214,
#  'speaking': 8373,
#  'forum': 3858,
#  'practical': 6762,
#  'technological': 8911,
#  'aspects': 1011,
#  'modern': 5836,
#  'realities': 7251,
#  'mentioned': 5705,
#  'elites': 3155,
#  'approach': 926,
#  'establishing': 3337,
#  'soviet': 8357,
#  'bureau': 1575,
#  'assessment': 1026,
#  'isw': 4895,
#  'added': 555,
#  'noteworthy': 6099,
#  'supports': 8729,
#  'longstanding': 5417,
#  'assessments': 1027,
#  'deteriorating': 2741,
#  'regime': 7378,
#  'members': 5689,
#  'largely': 5184,
#  'variety': 9497,
#  'actors': 542,
#  'apparently': 899,
#  'unable': 9314,
#  'decisive': 2571,
#  'regain': 7368,
#  'unclear': 9327,
#  'senior': 8021,
#  'openly': 6239,
#  'acknowledged': 520,
#  'problems': 6897,
#  'setting': 8071,
#  'nationalist': 5978,
#  'expectations': 3445,
#  'regarding': 7372,
#  'capabilities': 1656,
#  'unified': 9371,
#  'narrative': 5968,
#  'possibly': 6737,
#  '52am': 318,
#  '03am': 9,
#  'confirmed': 2148,
#  'criticalthreats': 2422,
#  'https': 4484,
#  'pic': 6586,
#  'twitter': 9282,
#  'com': 2008,
#  'thestudyofwar': 8995,
#  'main': 5497,
#  'cherevaty': 1832,
#  'grouping': 4174,
#  'lost': 5433,
#  'casualties': 1708,
#  'included': 4627,
#  'seeing': 7994,
#  'heavy': 4329,
#  'assault': 1018,
#  'relies': 7439,
#  'heavily': 4328,
#  'private': 6882,
#  'company': 2061,
#  'opened': 6237,
#  'recruitment': 7321,
#  'centres': 1756,
#  '42': 275,
#  '21am': 164,
#  'northeastern': 6089,
#  'half': 4231,
#  'struck': 8610,
#  'adding': 558,
#  'resulting': 7623,
#  'ruins': 7815,
#  'debris': 2552,
#  'holes': 4418,
#  'ground': 4170,
#  'amounted': 794,
#  'self': 8009,
#  'portrait': 6716,
#  'engineers': 3253,
#  'restore': 7610,
#  'power': 6756,
#  'customers': 2474,
#  'thursday': 9034,
#  'restored': 7611,
#  '90': 402,
#  'officials': 6197,
#  'transport': 9182,
#  'depends': 2680,
#  'fully': 3937,
#  'operational': 6248,
#  'efforts': 3114,
#  'kupiansk': 5132,
#  'located': 5395,
#  'east': 3073,
#  'regional': 7382,
#  'liberated': 5302,
#  'occupation': 6164,
#  'september': 8040,
#  'subjected': 8636,
#  'close': 1938,
#  'proximity': 7039,
#  'border': 1435,
#  '53am': 321,
#  '57am': 334,
#  'morning': 5874,
#  'concentrating': 2107,
#  'conducting': 2137,
#  'offensives': 6186,
#  'lyman': 5471,
#  'zaporizhzhia': 9966,
#  'airstrikes': 704,
#  '56': 329,
#  'resulted': 7622,
#  'civilian': 1890,
#  'carried': 1687,
#  'strikes': 8599,
#  'temporary': 8942,
#  'bases': 1218,
#  'depot': 2695,
#  'electronic': 3140,
#  'stations': 8503,
#  'warns': 9674,
#  'high': 4372,
#  'threat': 9018,
#  '09am': 21,
#  '32am': 226,
#  'ordered': 6279,
#  'uoc': 9429,
#  'leave': 5244,
#  'monastery': 5853,
#  'complex': 2087,
#  'collaborating': 1981,
#  'organisations': 6285,
#  'effort': 3113,
#  'forced': 3819,
#  'closure': 1944,
#  'violation': 9564,
#  'millions': 5770,
#  'believers': 1280,
#  'website': 9721,
#  'strongly': 8609,
#  'ties': 9043,
#  'victim': 9535,
#  'political': 6678,
#  'hunt': 4505,
#  'october': 6177,
#  'service': 8060,
#  'regularly': 7390,
#  'searches': 7966,
#  'imposed': 4601,
#  'financial': 3701,
#  'backers': 1154,
#  'criminal': 2413,
#  'cases': 1697,
#  'dozens': 2981,
#  'appeal': 900,
#  'addressed': 563,
#  'archbishop': 946,
#  'canterbury': 1654,
#  'justin': 4999,
#  'welby': 9736,
#  'egypt': 3119,
#  'secretary': 7979,
#  'antonio': 874,
#  'guterres': 4214,
#  'chief': 1837,
#  'volker': 9602,
#  '39am': 258,
#  '17am': 85,
#  'impact': 4574,
#  'dramatically': 2991,
#  'regions': 7383,
#  'intelligence': 4767,
#  'update': 9431,
#  'proportion': 6983,
#  'size': 8246,
#  'population': 6708,
#  'richest': 7692,
#  'petersburg': 6559,
#  'left': 5253,
#  'relatively': 7424,
#  'true': 9239,
#  'families': 3586,
#  'elite': 3154,
#  '21': 161,
#  'photographed': 6578,
#  'making': 5514,
#  'rows': 7798,
#  'audience': 1088,
#  'speech': 8390,
#  'known': 5097,
#  'children': 1842,
#  'serving': 8065,
#  'deaths': 2544,
#  'running': 7824,
#  'percentage': 6517,
#  'rate': 7207,
#  'times': 9058,
#  'places': 6615,
#  'minorities': 5790,
#  'biggest': 1327,
#  '75': 376,
#  'minority': 5791,
#  'populations': 6709,
#  'mod': 5828,
#  'seeks': 7998,
#  'deficit': 2616,
#  'combat': 2009,
#  'personnel': 6546,
#  'influential': 4695,
#  'elements': 3144,
#  'remain': 7448,
#  'consideration': 2191,
#  'illegal': 4554,
#  'unprovoked': 9412,
#  'continuing': 2247,
#  'map': 5546,
#  'use': 9462,
#  'language': 5180,
#  'standwithukraine': 8483,
#  'defencehq': 2604,
#  '37am': 251,
#  '47am': 293,
#  'defending': 2612,
#  'withdrew': 9824,
#  'change': 1792,
#  'offensive': 6185,
#  'suffer': 8671,
#  'fate': 3614,
#  'long': 5414,
#  'declined': 2579,
#  'specific': 8382,
#  'answer': 858,
#  'house': 4473,
#  'trying': 9248,
#  'kill': 5061,
#  'experts': 3466,
#  'questioned': 7119,
#  'sense': 8022,
#  'commander': 2020,
#  'oleksandr': 6217,
#  'helped': 4347,
#  'win': 9791,
#  'preparation': 6801,
#  'coming': 2018,
#  ...}

# %% [markdown]
# #### Display matrix in dataframe
#
# Take the term count matrix and display in a dataframe to make visible the structure

# %%
# Create a new dataframe with the matrix - use titles for the index and terms for the columns
count_df = pd.DataFrame(count_dt_matrix.toarray(), index=articles.keys(), columns=feature_names)
count_df
# Out:
#                                                     000  000km  00am  00pm  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...    4      0     0     1
# Russia-Ukraine war – as it happened: Ukraine to...    3      0     0     0
# Russia-Ukraine war: Zelenskiy and UK prime mini...    0      0     2     4
# Russia-Ukraine war live: Putin visits Mariupol ...    3      0     0     0
# Russia-Ukraine war: Russia nearly shot down Bri...   12      0     1     0
# ...                                                 ...    ...   ...   ...
# BoM shifts to El Niño watch after La Niña offic...   13      0     3     2
# PM reportedly issued invitation to visit Beijin...    2      0     1     0
# Myer to close flagship Brisbane store – as it h...   19      0     2     0
# Voice referendum question and constitutional am...    6      0     2     1
# Thorpe votes with Coalition on Indigenous land ...    7      0     4     0
#
#                                                     01am  01pm  020  02am  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...     0     0    0     0
# Russia-Ukraine war – as it happened: Ukraine to...     0     0    2     0
# Russia-Ukraine war: Zelenskiy and UK prime mini...     0     2    0     0
# Russia-Ukraine war live: Putin visits Mariupol ...     0     2    0     0
# Russia-Ukraine war: Russia nearly shot down Bri...     0     1    0     0
# ...                                                  ...   ...  ...   ...
# BoM shifts to El Niño watch after La Niña offic...     1     4    0     1
# PM reportedly issued invitation to visit Beijin...     2     0    0     4
# Myer to close flagship Brisbane store – as it h...     1     0    0     3
# Voice referendum question and constitutional am...     4     1    0     2
# Thorpe votes with Coalition on Indigenous land ...     3     0    0     2
#
#                                                     02pm  03am  ...  zoom  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...     0     1  ...     0
# Russia-Ukraine war – as it happened: Ukraine to...     1     1  ...     0
# Russia-Ukraine war: Zelenskiy and UK prime mini...     0     1  ...     0
# Russia-Ukraine war live: Putin visits Mariupol ...     1     0  ...     0
# Russia-Ukraine war: Russia nearly shot down Bri...     1     0  ...     0
# ...                                                  ...   ...  ...   ...
# BoM shifts to El Niño watch after La Niña offic...     7     2  ...     0
# PM reportedly issued invitation to visit Beijin...     0     3  ...     0
# Myer to close flagship Brisbane store – as it h...     1     2  ...     0
# Voice referendum question and constitutional am...     0     4  ...     0
# Thorpe votes with Coalition on Indigenous land ...     1     1  ...     0
#
#                                                     zoopark  zuma  çavuşoğlu  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...        0     0          0
# Russia-Ukraine war – as it happened: Ukraine to...        0     0          0
# Russia-Ukraine war: Zelenskiy and UK prime mini...        0     0          0
# Russia-Ukraine war live: Putin visits Mariupol ...        0     1          0
# Russia-Ukraine war: Russia nearly shot down Bri...        0     0          0
# ...                                                     ...   ...        ...
# BoM shifts to El Niño watch after La Niña offic...        0     0          0
# PM reportedly issued invitation to visit Beijin...        0     0          0
# Myer to close flagship Brisbane store – as it h...        0     0          0
# Voice referendum question and constitutional am...        0     0          0
# Thorpe votes with Coalition on Indigenous land ...        0     0          0
#
#                                                     володимир  зеленський  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...          1           1
# Russia-Ukraine war – as it happened: Ukraine to...          0           0
# Russia-Ukraine war: Zelenskiy and UK prime mini...          1           1
# Russia-Ukraine war live: Putin visits Mariupol ...          0           0
# Russia-Ukraine war: Russia nearly shot down Bri...          0           0
# ...                                                       ...         ...
# BoM shifts to El Niño watch after La Niña offic...          0           0
# PM reportedly issued invitation to visit Beijin...          0           0
# Myer to close flagship Brisbane store – as it h...          0           0
# Voice referendum question and constitutional am...          0           0
# Thorpe votes with Coalition on Indigenous land ...          0           0
#
#                                                     михайло  подоляк  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...        0        0
# Russia-Ukraine war – as it happened: Ukraine to...        1        1
# Russia-Ukraine war: Zelenskiy and UK prime mini...        0        0
# Russia-Ukraine war live: Putin visits Mariupol ...        0        0
# Russia-Ukraine war: Russia nearly shot down Bri...        0        0
# ...                                                     ...      ...
# BoM shifts to El Niño watch after La Niña offic...        0        0
# PM reportedly issued invitation to visit Beijin...        0        0
# Myer to close flagship Brisbane store – as it h...        0        0
# Voice referendum question and constitutional am...        0        0
# Thorpe votes with Coalition on Indigenous land ...        0        0
#
#                                                     сhildren  та
# Russia-Ukraine war live: Ukraine ‘buying time’ ...         0   0
# Russia-Ukraine war – as it happened: Ukraine to...         4   0
# Russia-Ukraine war: Zelenskiy and UK prime mini...         0   0
# Russia-Ukraine war live: Putin visits Mariupol ...         0   0
# Russia-Ukraine war: Russia nearly shot down Bri...         0   0
# ...                                                      ...  ..
# BoM shifts to El Niño watch after La Niña offic...         0   0
# PM reportedly issued invitation to visit Beijin...         0   0
# Myer to close flagship Brisbane store – as it h...         0   0
# Voice referendum question and constitutional am...         0   0
# Thorpe votes with Coalition on Indigenous land ...         0   0
#
# [202 rows x 10000 columns]

# %% [markdown]
# By selecting a row from the dataframe and sorting the values (counts), we can identify the top 10 terms

# %%
# Sample 5 random articles
samples = random.sample(range(0,202),5)

for sample in samples:
    doc = count_df.iloc[sample]
    top_terms = dict(count_df.iloc[sample].sort_values(ascending=False).head(10))
    print(f"[{sample}] {doc.name}")
    print("\t- Top terms:",top_terms)
# Out:
# [105] Russian ambassador to the US says Moscow does not want confrontation after drone crash – as it happened [2023-03-15T00:38:07Z]
# 	- Top terms: {'gmt': 95, 'ukrainian': 71, 'forces': 55, 'drone': 52, 'military': 41, 'defence': 41, 'state': 36, 'black': 35, 'sea': 35, 'reports': 30}
# [65] Russia-Ukraine war live: US sanctions over 120 people and entities supporting Russia’s invasion — as it happened [2023-04-12T17:59:24Z]
# 	- Top terms: {'bst': 86, 'ukrainian': 67, 'military': 47, 'sanctions': 41, 'forces': 34, 'video': 34, 'updated': 32, 'documents': 31, 'wednesday': 27, 'president': 27}
# [151] Morning Mail: Dutton hangs on, Russian pro-war blogger killed in bomb blast, Sakamoto dies at 71 [2023-04-02T21:01:43Z]
# 	- Top terms: {'australia': 9, 'photograph': 6, 'says': 5, 'crisis': 5, 'melbourne': 4, 'images': 4, 'getty': 4, 'federal': 3, 'report': 3, 'day': 3}
# [186] Government says opposition leader’s Aukus comments ‘irresponsible’ – as it happened [2023-03-01T08:06:45Z]
# 	- Top terms: {'gmt': 172, 'updated': 81, 'australia': 70, 'health': 60, 'tax': 56, 'today': 41, 'changes': 40, 'says': 38, 'economy': 37, 'australian': 34}
# [32] Russia-Ukraine war at a glance: what we know on day 402 of the invasion [2023-04-01T00:28:37Z]
# 	- Top terms: {'president': 5, 'invasion': 4, 'rights': 4, 'belarusian': 4, 'forces': 3, 'council': 3, 'players': 3, 'nato': 3, 'charges': 3, 'international': 3}

# %% [markdown]
# #### Create a top10 terms dataframe
#
# Using the index from the documents, create a dataframe that can hold the top10 terms for each document. We also include columns for our other analysis (tfidf, lda, nmf)

# %%
# Create a dataframe to hold top terms for each analysis type
terms_df = pd.DataFrame(index=count_df.index,columns=['count','tfidf','lda','nmf'])
terms_df
# Out:
#                                                    count tfidf  lda  nmf
# Russia-Ukraine war live: Ukraine ‘buying time’ ...   NaN   NaN  NaN  NaN
# Russia-Ukraine war – as it happened: Ukraine to...   NaN   NaN  NaN  NaN
# Russia-Ukraine war: Zelenskiy and UK prime mini...   NaN   NaN  NaN  NaN
# Russia-Ukraine war live: Putin visits Mariupol ...   NaN   NaN  NaN  NaN
# Russia-Ukraine war: Russia nearly shot down Bri...   NaN   NaN  NaN  NaN
# ...                                                  ...   ...  ...  ...
# BoM shifts to El Niño watch after La Niña offic...   NaN   NaN  NaN  NaN
# PM reportedly issued invitation to visit Beijin...   NaN   NaN  NaN  NaN
# Myer to close flagship Brisbane store – as it h...   NaN   NaN  NaN  NaN
# Voice referendum question and constitutional am...   NaN   NaN  NaN  NaN
# Thorpe votes with Coalition on Indigenous land ...   NaN   NaN  NaN  NaN
#
# [202 rows x 4 columns]

# %% [markdown]
# Populate the count column with data created by the count vectorizer.

# %%
#For each doc, get the 10 columns with the largest counts
for idx in terms_df.index:
    counts = dict(count_df.loc[idx].sort_values(ascending=False).head(10))
    #print(counts)
    terms_df.at[idx,'count'] = list(counts.keys()) # Just the list of terms

terms_df
# Out:
#                                                                                                 count  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  [gmt, ukrainian, bakhmut, updated, forces, mos...
# Russia-Ukraine war – as it happened: Ukraine to...  [ukrainian, bst, children, photograph, forces,...
# Russia-Ukraine war: Zelenskiy and UK prime mini...  [bst, ukrainian, china, friday, military, defe...
# Russia-Ukraine war live: Putin visits Mariupol ...  [putin, gmt, mariupol, city, ukrainian, march,...
# Russia-Ukraine war: Russia nearly shot down Bri...  [bst, ukrainian, documents, defence, air, city...
# ...                                                                                               ...
# BoM shifts to El Niño watch after La Niña offic...  [gmt, australia, nuclear, aukus, updated, defe...
# PM reportedly issued invitation to visit Beijin...  [bst, updated, tiktok, australia, australian, ...
# Myer to close flagship Brisbane store – as it h...  [gmt, australia, updated, says, lehrmann, auku...
# Voice referendum question and constitutional am...  [gmt, updated, australia, prime, australian, s...
# Thorpe votes with Coalition on Indigenous land ...  [bst, updated, labor, australia, national, alb...
#
#                                                                                                 tfidf  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  {'gmt': 0.4254, 'ukrainian': 0.1954, 'swiss': ...
# Russia-Ukraine war – as it happened: Ukraine to...  {'bst': 0.3907, 'ukrainian': 0.2819, 'children...
# Russia-Ukraine war: Zelenskiy and UK prime mini...  {'bst': 0.4633, 'friday': 0.1966, 'teixeira': ...
# Russia-Ukraine war live: Putin visits Mariupol ...  {'gmt': 0.3642, 'mariupol': 0.3471, 'putin': 0...
# Russia-Ukraine war: Russia nearly shot down Bri...  {'bst': 0.414, 'documents': 0.2066, 'ukrainian...
# ...                                                                                               ...
# BoM shifts to El Niño watch after La Niña offic...  {'gmt': 0.458, 'aukus': 0.3142, 'australia': 0...
# PM reportedly issued invitation to visit Beijin...  {'bst': 0.5509, 'tiktok': 0.2961, 'updated': 0...
# Myer to close flagship Brisbane store – as it h...  {'gmt': 0.4896, 'lehrmann': 0.2857, 'keating':...
# Voice referendum question and constitutional am...  {'gmt': 0.5582, 'updated': 0.204, 'samoa': 0.1...
# Thorpe votes with Coalition on Indigenous land ...  {'bst': 0.6123, 'updated': 0.2123, 'labor': 0....
#
#                                                                                                   lda  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  [ukrainian, bst, military, forces, president, ...
# Russia-Ukraine war – as it happened: Ukraine to...  [ukrainian, bst, military, forces, president, ...
# Russia-Ukraine war: Zelenskiy and UK prime mini...  [ukrainian, bst, military, forces, president, ...
# Russia-Ukraine war live: Putin visits Mariupol ...  [ukrainian, bst, military, forces, president, ...
# Russia-Ukraine war: Russia nearly shot down Bri...  [ukrainian, bst, military, forces, president, ...
# ...                                                                                               ...
# BoM shifts to El Niño watch after La Niña offic...  [gmt, australia, updated, bst, australian, say...
# PM reportedly issued invitation to visit Beijin...  [gmt, australia, updated, bst, australian, say...
# Myer to close flagship Brisbane store – as it h...  [gmt, australia, updated, bst, australian, say...
# Voice referendum question and constitutional am...  [gmt, australia, updated, bst, australian, say...
# Thorpe votes with Coalition on Indigenous land ...  [gmt, australia, updated, bst, australian, say...
#
#                                                                                                   nmf
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  [gmt, updated, march, 12, 2023, today, 11, 10,...
# Russia-Ukraine war – as it happened: Ukraine to...  [ukrainian, bakhmut, forces, defence, city, ky...
# Russia-Ukraine war: Zelenskiy and UK prime mini...  [bst, updated, april, 2023, 11, photograph, re...
# Russia-Ukraine war live: Putin visits Mariupol ...  [gmt, updated, march, 12, 2023, today, 11, 10,...
# Russia-Ukraine war: Russia nearly shot down Bri...  [documents, pentagon, leak, korea, classified,...
# ...                                                                                               ...
# BoM shifts to El Niño watch after La Niña offic...  [gmt, updated, march, 12, 2023, today, 11, 10,...
# PM reportedly issued invitation to visit Beijin...  [bst, updated, april, 2023, 11, photograph, re...
# Myer to close flagship Brisbane store – as it h...  [gmt, updated, march, 12, 2023, today, 11, 10,...
# Voice referendum question and constitutional am...  [gmt, updated, march, 12, 2023, today, 11, 10,...
# Thorpe votes with Coalition on Indigenous land ...  [bst, updated, april, 2023, 11, photograph, re...
#
# [202 rows x 4 columns]

# %% [markdown]
# ### Term Frequency / Inverse Document Frequency (TF/IDF)
#
# **Finding terms that are very common in a document, but less common in the whole collection**
#
# The [TF/IDF](https://en.wikipedia.org/wiki/Tf–idf) algorithm takes the term frequencies for a document and divides them by the frequencies of the terms in the whole collection.

# %%
# Only count terms that in maximum of 75% of documents, and a minimum of 2 documents. 
# Count a maximum of 10000 terms, and remove common english stop words
tfidf_vectorizer = TfidfVectorizer(
    max_df=0.75, min_df=2, max_features=10000, stop_words="english"
)

# %%
# Get the document vectors
tfidf_dt_matrix = tfidf_vectorizer.fit_transform(articles.values())

# Display the vector for the first document
tfidf_dt_matrix.toarray()[0]
# Out:
# array([0.0210132, 0.       , 0.       , ..., 0.       , 0.       ,
#        0.       ])

# %% [markdown]
# #### Display matrix in dataframe

# %%
tfidf_df = pd.DataFrame(tfidf_dt_matrix.toarray(), index=articles.keys(), columns=tfidf_vectorizer.get_feature_names_out())
tfidf_df
# Out:
#                                                          000  000km      00am  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  0.021013    0.0  0.000000
# Russia-Ukraine war – as it happened: Ukraine to...  0.019765    0.0  0.000000
# Russia-Ukraine war: Zelenskiy and UK prime mini...  0.000000    0.0  0.008853
# Russia-Ukraine war live: Putin visits Mariupol ...  0.018333    0.0  0.000000
# Russia-Ukraine war: Russia nearly shot down Bri...  0.047873    0.0  0.005840
# ...                                                      ...    ...       ...
# BoM shifts to El Niño watch after La Niña offic...  0.015163    0.0  0.005122
# PM reportedly issued invitation to visit Beijin...  0.004288    0.0  0.003138
# Myer to close flagship Brisbane store – as it h...  0.037121    0.0  0.005720
# Voice referendum question and constitutional am...  0.011477    0.0  0.005600
# Thorpe votes with Coalition on Indigenous land ...  0.013343    0.0  0.011161
#
#                                                         00pm      01am  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  0.007957  0.000000
# Russia-Ukraine war – as it happened: Ukraine to...  0.000000  0.000000
# Russia-Ukraine war: Zelenskiy and UK prime mini...  0.018321  0.000000
# Russia-Ukraine war live: Putin visits Mariupol ...  0.000000  0.000000
# Russia-Ukraine war: Russia nearly shot down Bri...  0.000000  0.000000
# ...                                                      ...       ...
# BoM shifts to El Niño watch after La Niña offic...  0.003533  0.001815
# PM reportedly issued invitation to visit Beijin...  0.000000  0.006670
# Myer to close flagship Brisbane store – as it h...  0.000000  0.003039
# Voice referendum question and constitutional am...  0.002897  0.011903
# Thorpe votes with Coalition on Indigenous land ...  0.000000  0.008896
#
#                                                         01pm       020  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  0.000000  0.000000
# Russia-Ukraine war – as it happened: Ukraine to...  0.000000  0.039577
# Russia-Ukraine war: Zelenskiy and UK prime mini...  0.009496  0.000000
# Russia-Ukraine war live: Putin visits Mariupol ...  0.019190  0.000000
# Russia-Ukraine war: Russia nearly shot down Bri...  0.006264  0.000000
# ...                                                      ...       ...
# BoM shifts to El Niño watch after La Niña offic...  0.007325  0.000000
# PM reportedly issued invitation to visit Beijin...  0.000000  0.000000
# Myer to close flagship Brisbane store – as it h...  0.000000  0.000000
# Voice referendum question and constitutional am...  0.003003  0.000000
# Thorpe votes with Coalition on Indigenous land ...  0.000000  0.000000
#
#                                                         02am      02pm  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  0.000000  0.000000
# Russia-Ukraine war – as it happened: Ukraine to...  0.000000  0.010642
# Russia-Ukraine war: Zelenskiy and UK prime mini...  0.000000  0.000000
# Russia-Ukraine war live: Putin visits Mariupol ...  0.000000  0.009871
# Russia-Ukraine war: Russia nearly shot down Bri...  0.000000  0.006444
# ...                                                      ...       ...
# BoM shifts to El Niño watch after La Niña offic...  0.001866  0.013188
# PM reportedly issued invitation to visit Beijin...  0.013719  0.000000
# Myer to close flagship Brisbane store – as it h...  0.009377  0.003156
# Voice referendum question and constitutional am...  0.006120  0.000000
# Thorpe votes with Coalition on Indigenous land ...  0.006099  0.003079
#
#                                                         03am  ...  zoom  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  0.008099  ...   0.0
# Russia-Ukraine war – as it happened: Ukraine to...  0.010158  ...   0.0
# Russia-Ukraine war: Zelenskiy and UK prime mini...  0.004662  ...   0.0
# Russia-Ukraine war live: Putin visits Mariupol ...  0.000000  ...   0.0
# Russia-Ukraine war: Russia nearly shot down Bri...  0.000000  ...   0.0
# ...                                                      ...  ...   ...
# BoM shifts to El Niño watch after La Niña offic...  0.003597  ...   0.0
# PM reportedly issued invitation to visit Beijin...  0.009915  ...   0.0
# Myer to close flagship Brisbane store – as it h...  0.006024  ...   0.0
# Voice referendum question and constitutional am...  0.011796  ...   0.0
# Thorpe votes with Coalition on Indigenous land ...  0.002939  ...   0.0
#
#                                                     zoopark      zuma  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...      0.0  0.000000
# Russia-Ukraine war – as it happened: Ukraine to...      0.0  0.000000
# Russia-Ukraine war: Zelenskiy and UK prime mini...      0.0  0.000000
# Russia-Ukraine war live: Putin visits Mariupol ...      0.0  0.015772
# Russia-Ukraine war: Russia nearly shot down Bri...      0.0  0.000000
# ...                                                     ...       ...
# BoM shifts to El Niño watch after La Niña offic...      0.0  0.000000
# PM reportedly issued invitation to visit Beijin...      0.0  0.000000
# Myer to close flagship Brisbane store – as it h...      0.0  0.000000
# Voice referendum question and constitutional am...      0.0  0.000000
# Thorpe votes with Coalition on Indigenous land ...      0.0  0.000000
#
#                                                     çavuşoğlu  володимир  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...        0.0   0.012844
# Russia-Ukraine war – as it happened: Ukraine to...        0.0   0.000000
# Russia-Ukraine war: Zelenskiy and UK prime mini...        0.0   0.007393
# Russia-Ukraine war live: Putin visits Mariupol ...        0.0   0.000000
# Russia-Ukraine war: Russia nearly shot down Bri...        0.0   0.000000
# ...                                                       ...        ...
# BoM shifts to El Niño watch after La Niña offic...        0.0   0.000000
# PM reportedly issued invitation to visit Beijin...        0.0   0.000000
# Myer to close flagship Brisbane store – as it h...        0.0   0.000000
# Voice referendum question and constitutional am...        0.0   0.000000
# Thorpe votes with Coalition on Indigenous land ...        0.0   0.000000
#
#                                                     зеленський   михайло  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...    0.012844  0.000000
# Russia-Ukraine war – as it happened: Ukraine to...    0.000000  0.016531
# Russia-Ukraine war: Zelenskiy and UK prime mini...    0.007393  0.000000
# Russia-Ukraine war live: Putin visits Mariupol ...    0.000000  0.000000
# Russia-Ukraine war: Russia nearly shot down Bri...    0.000000  0.000000
# ...                                                        ...       ...
# BoM shifts to El Niño watch after La Niña offic...    0.000000  0.000000
# PM reportedly issued invitation to visit Beijin...    0.000000  0.000000
# Myer to close flagship Brisbane store – as it h...    0.000000  0.000000
# Voice referendum question and constitutional am...    0.000000  0.000000
# Thorpe votes with Coalition on Indigenous land ...    0.000000  0.000000
#
#                                                      подоляк  сhildren   та
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  0.000000  0.000000  0.0
# Russia-Ukraine war – as it happened: Ukraine to...  0.016531  0.083775  0.0
# Russia-Ukraine war: Zelenskiy and UK prime mini...  0.000000  0.000000  0.0
# Russia-Ukraine war live: Putin visits Mariupol ...  0.000000  0.000000  0.0
# Russia-Ukraine war: Russia nearly shot down Bri...  0.000000  0.000000  0.0
# ...                                                      ...       ...  ...
# BoM shifts to El Niño watch after La Niña offic...  0.000000  0.000000  0.0
# PM reportedly issued invitation to visit Beijin...  0.000000  0.000000  0.0
# Myer to close flagship Brisbane store – as it h...  0.000000  0.000000  0.0
# Voice referendum question and constitutional am...  0.000000  0.000000  0.0
# Thorpe votes with Coalition on Indigenous land ...  0.000000  0.000000  0.0
#
# [202 rows x 10000 columns]

# %% [markdown]
# #### Update the terms matrix

# %%
for idx in terms_df.index:
    tfidf = dict(tfidf_df.loc[idx].sort_values(ascending=False).head(10))
    #print(counts)
    terms_df.at[idx,'tfidf'] = list(tfidf.keys()) 

terms_df
# Out:
#                                                                                                 count  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  [gmt, ukrainian, bakhmut, updated, forces, mos...
# Russia-Ukraine war – as it happened: Ukraine to...  [ukrainian, bst, children, photograph, forces,...
# Russia-Ukraine war: Zelenskiy and UK prime mini...  [bst, ukrainian, china, friday, military, defe...
# Russia-Ukraine war live: Putin visits Mariupol ...  [putin, gmt, mariupol, city, ukrainian, march,...
# Russia-Ukraine war: Russia nearly shot down Bri...  [bst, ukrainian, documents, defence, air, city...
# ...                                                                                               ...
# BoM shifts to El Niño watch after La Niña offic...  [gmt, australia, nuclear, aukus, updated, defe...
# PM reportedly issued invitation to visit Beijin...  [bst, updated, tiktok, australia, australian, ...
# Myer to close flagship Brisbane store – as it h...  [gmt, australia, updated, says, lehrmann, auku...
# Voice referendum question and constitutional am...  [gmt, updated, australia, prime, australian, s...
# Thorpe votes with Coalition on Indigenous land ...  [bst, updated, labor, australia, national, alb...
#
#                                                                                                 tfidf  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  [gmt, ukrainian, swiss, bakhmut, updated, satu...
# Russia-Ukraine war – as it happened: Ukraine to...  [bst, ukrainian, children, reunited, photograp...
# Russia-Ukraine war: Zelenskiy and UK prime mini...  [bst, friday, teixeira, ukrainian, china, upda...
# Russia-Ukraine war live: Putin visits Mariupol ...  [gmt, mariupol, putin, ukrainian, city, warran...
# Russia-Ukraine war: Russia nearly shot down Bri...  [bst, documents, ukrainian, easter, orthodox, ...
# ...                                                                                               ...
# BoM shifts to El Niño watch after La Niña offic...  [gmt, aukus, australia, nuclear, submarine, su...
# PM reportedly issued invitation to visit Beijin...  [bst, tiktok, updated, gambling, devices, aust...
# Myer to close flagship Brisbane store – as it h...  [gmt, lehrmann, keating, australia, updated, p...
# Voice referendum question and constitutional am...  [gmt, updated, samoa, australia, australian, p...
# Thorpe votes with Coalition on Indigenous land ...  [bst, updated, labor, albanese, senate, austra...
#
#                                                                                                   lda  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  [ukrainian, bst, military, forces, president, ...
# Russia-Ukraine war – as it happened: Ukraine to...  [ukrainian, bst, military, forces, president, ...
# Russia-Ukraine war: Zelenskiy and UK prime mini...  [ukrainian, bst, military, forces, president, ...
# Russia-Ukraine war live: Putin visits Mariupol ...  [ukrainian, bst, military, forces, president, ...
# Russia-Ukraine war: Russia nearly shot down Bri...  [ukrainian, bst, military, forces, president, ...
# ...                                                                                               ...
# BoM shifts to El Niño watch after La Niña offic...  [gmt, australia, updated, bst, australian, say...
# PM reportedly issued invitation to visit Beijin...  [gmt, australia, updated, bst, australian, say...
# Myer to close flagship Brisbane store – as it h...  [gmt, australia, updated, bst, australian, say...
# Voice referendum question and constitutional am...  [gmt, australia, updated, bst, australian, say...
# Thorpe votes with Coalition on Indigenous land ...  [gmt, australia, updated, bst, australian, say...
#
#                                                                                                   nmf
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  [gmt, updated, march, 12, 2023, today, 11, 10,...
# Russia-Ukraine war – as it happened: Ukraine to...  [ukrainian, bakhmut, forces, defence, city, ky...
# Russia-Ukraine war: Zelenskiy and UK prime mini...  [bst, updated, april, 2023, 11, photograph, re...
# Russia-Ukraine war live: Putin visits Mariupol ...  [gmt, updated, march, 12, 2023, today, 11, 10,...
# Russia-Ukraine war: Russia nearly shot down Bri...  [documents, pentagon, leak, korea, classified,...
# ...                                                                                               ...
# BoM shifts to El Niño watch after La Niña offic...  [gmt, updated, march, 12, 2023, today, 11, 10,...
# PM reportedly issued invitation to visit Beijin...  [bst, updated, april, 2023, 11, photograph, re...
# Myer to close flagship Brisbane store – as it h...  [gmt, updated, march, 12, 2023, today, 11, 10,...
# Voice referendum question and constitutional am...  [gmt, updated, march, 12, 2023, today, 11, 10,...
# Thorpe votes with Coalition on Indigenous land ...  [bst, updated, april, 2023, 11, photograph, re...
#
# [202 rows x 4 columns]

# %% [markdown]
# #### Compare approaches

# %%
# Sample 5 random articles
samples = random.sample(range(0,202),5)

for sample in samples:
    doc = terms_df.iloc[sample]
    print(f"[{sample}] {doc.name}")
    print("\t- Counts:\t",doc['count'])
    print("\t- TFIDF:\t",doc['tfidf'])
    print()
# Out:
# [82] Russia-Ukraine war: Zaporizhzhia nuclear plant reconnected to energy grid as UN warns ‘one day our luck will run out’ – as it happened [2023-03-09T18:50:51Z]
# 	- Counts:	 ['gmt', 'power', 'kyiv', 'strikes', 'ukrainian', 'plant', 'region', 'thursday', 'nuclear', 'updated']
# 	- TFIDF:	 ['gmt', 'kyiv', 'power', 'strikes', 'plant', 'thursday', 'lviv', 'ukrainian', 'updated', 'zaporizhzhia']
#
# [101] Russia-Ukraine war: Xi to visit Russia as early as next week; Moscow says it could agree to shorter Black Sea grain deal – as it happened [2023-03-13T18:48:18Z]
# 	- Counts:	 ['gmt', 'ukrainian', 'forces', 'photograph', 'defence', 'military', 'updated', 'moscow', 'monday', 'president']
# 	- TFIDF:	 ['gmt', 'matsievskyi', 'ukrainian', 'forces', 'patriarch', 'updated', 'photograph', 'warrants', 'pope', 'monday']
#
# [179] PM urged to ‘reset tone’ of voice debate – as it happened [2023-04-11T08:41:13Z]
# 	- Counts:	 ['bst', 'leeser', 'voice', 'updated', 'australia', 'julian', 'shadow', 'australian', 'dutton', 'liberal']
# 	- TFIDF:	 ['bst', 'leeser', 'julian', 'voice', 'shadow', 'updated', 'dutton', 'liberal', 'australia', 'barley']
#
# [1] Russia-Ukraine war – as it happened: Ukraine to boost defences along border with Belarus [2023-04-08T17:16:35Z]
# 	- Counts:	 ['ukrainian', 'bst', 'children', 'photograph', 'forces', 'energy', 'ministry', 'defence', 'images', 'april']
# 	- TFIDF:	 ['bst', 'ukrainian', 'children', 'reunited', 'photograph', 'india', 'iftar', 'missile', 'energy', 'aksyonov']
#
# [95] Outrage as Moscow takes presidency of UN security council – as it happened [2023-04-01T17:11:51Z]
# 	- Counts:	 ['bst', 'ukrainian', 'kyiv', 'security', 'defence', 'general', 'president', 'updated', 'forces', 'council']
# 	- TFIDF:	 ['bst', 'pavel', 'kyiv', 'ukrainian', 'gerasimov', 'symbolic', 'jong', 'updated', 'blow', 'pechersk']

# %% [markdown]
# ### Topic modelling with Latent Dirichlet Allocation (LDA)
#
# [LDA](https://en.wikipedia.org/wiki/Latent_Dirichlet_allocation) is an algorithm for obtaining *topics* (a list of terms) from a document-term matrix. It is a generative probabilistic approach to *decomposition* of the document-term matrix into 2 factor matrices: document-topic and topic-term.
#
# ![img](https://editor.analyticsvidhya.com/uploads/26864dtm.JPG)
#
# *Source: [Analytics Vidhya](https://www.analyticsvidhya.com/blog/2021/06/part-2-topic-modeling-and-latent-dirichlet-allocation-lda-using-gensim-and-sklearn/)*

# %% [markdown]
# The LDA model requires the number of topics to be set in advance. As it is a generative model, it also runs over a number of iterations. These values usually need to be experimented with to obtain quality topics.

# %%
# Set number of topics
num_topics = 20
# Set max number of iteractions
max_iterations = 100

# Create the model
lda_model = LatentDirichletAllocation(n_components=num_topics,max_iter=max_iterations,learning_method='online')

# Fit the model to the data, and use the model to transform the data (do the decomposition)
doc_topic_matrix = lda_model.fit_transform(count_dt_matrix)

# Obtain the topics
topic_term_matrix = lda_model.components_

# %% [markdown]
# #### View the topics

# %%
# Get the topics and their terms
lda_topic_dict = {}
for index, topic in enumerate(topic_term_matrix):
    zipped = zip(feature_names, topic)
    top_terms=dict(sorted(zipped, key = lambda t: t[1], reverse=True)[:10])
    print(top_terms)
    top_terms_list= {key : round(top_terms[key], 4) for key in top_terms.keys()}
    lda_topic_dict[f"topic_{index}"] = top_terms_list

# Print the topics with their terms    
for k,v in lda_topic_dict.items():
    print(k)
    print(v)
    print()
# Out:
# {'bst': 0.05062464022508545, 'ukrainian': 0.05061109650082177, 'defence': 0.0504366215310309, 'military': 0.05042837788002845, 'gmt': 0.050419838073145165, 'updated': 0.05039230826154305, 'photograph': 0.05037395271982523, 'ministry': 0.05036467842970517, 'reuters': 0.050357087389385005, 'kyiv': 0.05035115512062176}
# {'ukrainian': 0.051202509519921266, 'bst': 0.05116161690282603, 'gmt': 0.05072423087382788, 'president': 0.050671732857621235, 'updated': 0.05065403289872125, 'military': 0.05060117887101784, 'defence': 0.05059045647762943, 'forces': 0.05058565232149159, 'kyiv': 0.05049298563817203, 'putin': 0.05048584778797993}
# {'ukrainian': 0.05137603896664686, 'bst': 0.050922551015423645, 'defence': 0.050879954925659554, 'bakhmut': 0.05083775879006237, 'forces': 0.05069537350784578, 'city': 0.05065282893988138, 'military': 0.05064124135067999, 'foreign': 0.05064004161059797, 'moscow': 0.050616215260691946, 'state': 0.05059373141348848}
# {'ukrainian': 0.05125545174709058, 'president': 0.050853318226226185, 'military': 0.05085122200758417, 'forces': 0.050842217355600156, 'gmt': 0.050698074076945335, 'putin': 0.05063963148145803, 'moscow': 0.050595553261748694, 'foreign': 0.05055480825348027, 'updated': 0.05055430066960491, 'city': 0.0505272146339292}
# {'nato': 331.1382432478186, 'bst': 295.1776094609594, 'president': 228.77409614230058, 'finland': 224.64960424893127, 'putin': 175.1946954689607, 'military': 164.79307440998844, 'ukrainian': 162.45063528460017, 'children': 144.64828280690102, 'state': 139.07815525258755, 'security': 138.88614740133107}
# {'ukrainian': 0.050871776390095894, 'gmt': 0.05067003170367475, 'president': 0.05064753098516313, 'bst': 0.05064617263641984, 'updated': 0.05052247298420681, 'forces': 0.050413583820766036, 'china': 0.05039740686523607, 'ministry': 0.05039644314051188, 'moscow': 0.050396334621986894, 'defence': 0.05039207636844861}
# {'gmt': 0.05140371901690216, 'ukrainian': 0.051329294776715856, 'city': 0.05075205908255288, 'updated': 0.05068275035748068, 'kyiv': 0.05068253224950728, 'president': 0.05066567826809089, 'military': 0.050629161615008564, 'state': 0.05061373645796656, 'putin': 0.050552520042383434, 'bakhmut': 0.05051262623007664}
# {'gmt': 0.05192476033183288, 'ukrainian': 0.051901878750376315, 'bst': 0.05166805581374896, 'moscow': 0.05119792420514613, 'military': 0.05113119861054766, 'president': 0.0511079558770806, 'updated': 0.05109537161537803, 'putin': 0.0510578175063329, 'defence': 0.05093318368236463, 'city': 0.050924098446317734}
# {'ukrainian': 1801.679949493087, 'gmt': 1260.342536427968, 'bst': 992.9003990828496, 'forces': 940.6867960429527, 'military': 904.3822837149343, 'president': 885.4228728418052, 'defence': 852.0611376219567, 'updated': 847.9229077731254, 'bakhmut': 786.150487947075, 'city': 730.5236027163836}
# {'ukrainian': 0.05053952490864892, 'military': 0.05039613629686841, 'forces': 0.05037319285603571, 'kyiv': 0.05029599117054441, 'state': 0.05028487716133527, 'bakhmut': 0.05027736232775071, 'updated': 0.05027429593641822, 'ministry': 0.050265601764332035, 'president': 0.05026255129771669, 'city': 0.050248486843360876}
# {'qin': 6.11394659134135, 'suppression': 2.3263735873029256, 'surely': 1.564785522079593, 'modernisation': 1.510876935948109, 'myth': 0.8113545641799919, 'achievements': 0.8016103555393046, 'bust': 0.7740165084295854, 'china': 0.05207936569442989, 'ukrainian': 0.051805942581751724, 'forces': 0.05138947089743469}
# {'gmt': 2861.919815046859, 'updated': 2357.7145923967064, 'australia': 1954.1563674797278, 'bst': 1913.1747675901804, 'australian': 1265.0871644569343, 'says': 1112.3712704967757, 'voice': 1002.7110668354553, 'labor': 932.226833700723, 'albanese': 919.8798528023862, 'today': 888.8439956846876}
# {'kishida': 58.438710791141375, 'japan': 39.53880984108822, 'japanese': 20.17124468410169, 'bucha': 6.941563312459219, 'tokyo': 5.4569113450099325, 'dinner': 4.059743621323592, 'hiroshima': 3.9005514912587995, 'facets': 2.38397711511151, 'billboards': 2.3418672820790136, 'wreath': 1.7024932986264505}
# {'og': 6.814044434242093, 'interviewed': 2.8409633758468, 'teenage': 2.32211804281589, 'fellow': 1.6786291787510605, 'contractors': 1.4085161352358133, 'delete': 0.8296070750237756, 'vs': 0.7897054421526942, 'yells': 0.7895548033747238, 'capitals': 0.7895218339710951, 'disclosures': 0.7893266388018919}
# {'australia': 1009.1741945245936, 'gmt': 982.6531405649937, 'aukus': 583.9616700552422, 'nuclear': 571.1885126935204, 'china': 382.71202936756646, 'submarines': 369.45972987502836, 'defence': 367.3162282806802, 'updated': 361.6031892578542, 'australian': 360.34051600041795, 'submarine': 280.7736862038476}
# {'ukrainian': 0.05110903066883779, 'gmt': 0.05103328730983263, 'bst': 0.05090024777038456, 'forces': 0.05075098701951078, 'city': 0.0507384457922105, 'military': 0.050710914884518704, 'defence': 0.05068631498369969, 'updated': 0.050641053660467006, 'president': 0.050621406911144445, 'reports': 0.05061437516310972}
# {'gmt': 0.05193968594290402, 'forces': 0.05145268160501533, 'ukrainian': 0.051383312605904605, 'bakhmut': 0.051308298028933996, 'bst': 0.05103681454276095, 'military': 0.050980851253245946, 'city': 0.050912205115584544, 'moscow': 0.05091053363039995, 'updated': 0.050885135037102736, 'president': 0.05077004768659392}
# {'ukrainian': 0.050780045119991846, 'gmt': 0.0505754160461243, 'defence': 0.05056844730489268, 'updated': 0.0505285648234859, 'bst': 0.050488011800690125, 'forces': 0.05047793234005918, 'president': 0.05047650009478763, 'putin': 0.050469632565289704, 'state': 0.050449208239137705, 'zelenskiy': 0.050407548408262615}
# {'ukrainian': 0.05129593884442181, 'gmt': 0.05086470059989753, 'bst': 0.050834277452082285, 'updated': 0.05076812430073835, 'president': 0.050733454643448625, 'forces': 0.05070047030014402, 'military': 0.05063314635392824, 'defence': 0.05052523054584718, 'kyiv': 0.050497961146211065, 'region': 0.05048687651110187}
# {'ukrainian': 0.051819770928013265, 'bst': 0.05153425436231704, 'updated': 0.05129943280135736, 'president': 0.05105500250775828, 'defence': 0.051028193447025624, 'gmt': 0.050897916048505396, 'putin': 0.05082666609537169, 'military': 0.05080610805372178, 'moscow': 0.05074121185375305, 'forces': 0.050658766316077214}
# topic_0
# {'bst': 0.0506, 'ukrainian': 0.0506, 'defence': 0.0504, 'military': 0.0504, 'gmt': 0.0504, 'updated': 0.0504, 'photograph': 0.0504, 'ministry': 0.0504, 'reuters': 0.0504, 'kyiv': 0.0504}
#
# topic_1
# {'ukrainian': 0.0512, 'bst': 0.0512, 'gmt': 0.0507, 'president': 0.0507, 'updated': 0.0507, 'military': 0.0506, 'defence': 0.0506, 'forces': 0.0506, 'kyiv': 0.0505, 'putin': 0.0505}
#
# topic_2
# {'ukrainian': 0.0514, 'bst': 0.0509, 'defence': 0.0509, 'bakhmut': 0.0508, 'forces': 0.0507, 'city': 0.0507, 'military': 0.0506, 'foreign': 0.0506, 'moscow': 0.0506, 'state': 0.0506}
#
# topic_3
# {'ukrainian': 0.0513, 'president': 0.0509, 'military': 0.0509, 'forces': 0.0508, 'gmt': 0.0507, 'putin': 0.0506, 'moscow': 0.0506, 'foreign': 0.0506, 'updated': 0.0506, 'city': 0.0505}
#
# topic_4
# {'nato': 331.1382, 'bst': 295.1776, 'president': 228.7741, 'finland': 224.6496, 'putin': 175.1947, 'military': 164.7931, 'ukrainian': 162.4506, 'children': 144.6483, 'state': 139.0782, 'security': 138.8861}
#
# topic_5
# {'ukrainian': 0.0509, 'gmt': 0.0507, 'president': 0.0506, 'bst': 0.0506, 'updated': 0.0505, 'forces': 0.0504, 'china': 0.0504, 'ministry': 0.0504, 'moscow': 0.0504, 'defence': 0.0504}
#
# topic_6
# {'gmt': 0.0514, 'ukrainian': 0.0513, 'city': 0.0508, 'updated': 0.0507, 'kyiv': 0.0507, 'president': 0.0507, 'military': 0.0506, 'state': 0.0506, 'putin': 0.0506, 'bakhmut': 0.0505}
#
# topic_7
# {'gmt': 0.0519, 'ukrainian': 0.0519, 'bst': 0.0517, 'moscow': 0.0512, 'military': 0.0511, 'president': 0.0511, 'updated': 0.0511, 'putin': 0.0511, 'defence': 0.0509, 'city': 0.0509}
#
# topic_8
# {'ukrainian': 1801.6799, 'gmt': 1260.3425, 'bst': 992.9004, 'forces': 940.6868, 'military': 904.3823, 'president': 885.4229, 'defence': 852.0611, 'updated': 847.9229, 'bakhmut': 786.1505, 'city': 730.5236}
#
# topic_9
# {'ukrainian': 0.0505, 'military': 0.0504, 'forces': 0.0504, 'kyiv': 0.0503, 'state': 0.0503, 'bakhmut': 0.0503, 'updated': 0.0503, 'ministry': 0.0503, 'president': 0.0503, 'city': 0.0502}
#
# topic_10
# {'qin': 6.1139, 'suppression': 2.3264, 'surely': 1.5648, 'modernisation': 1.5109, 'myth': 0.8114, 'achievements': 0.8016, 'bust': 0.774, 'china': 0.0521, 'ukrainian': 0.0518, 'forces': 0.0514}
#
# topic_11
# {'gmt': 2861.9198, 'updated': 2357.7146, 'australia': 1954.1564, 'bst': 1913.1748, 'australian': 1265.0872, 'says': 1112.3713, 'voice': 1002.7111, 'labor': 932.2268, 'albanese': 919.8799, 'today': 888.844}
#
# topic_12
# {'kishida': 58.4387, 'japan': 39.5388, 'japanese': 20.1712, 'bucha': 6.9416, 'tokyo': 5.4569, 'dinner': 4.0597, 'hiroshima': 3.9006, 'facets': 2.384, 'billboards': 2.3419, 'wreath': 1.7025}
#
# topic_13
# {'og': 6.814, 'interviewed': 2.841, 'teenage': 2.3221, 'fellow': 1.6786, 'contractors': 1.4085, 'delete': 0.8296, 'vs': 0.7897, 'yells': 0.7896, 'capitals': 0.7895, 'disclosures': 0.7893}
#
# topic_14
# {'australia': 1009.1742, 'gmt': 982.6531, 'aukus': 583.9617, 'nuclear': 571.1885, 'china': 382.712, 'submarines': 369.4597, 'defence': 367.3162, 'updated': 361.6032, 'australian': 360.3405, 'submarine': 280.7737}
#
# topic_15
# {'ukrainian': 0.0511, 'gmt': 0.051, 'bst': 0.0509, 'forces': 0.0508, 'city': 0.0507, 'military': 0.0507, 'defence': 0.0507, 'updated': 0.0506, 'president': 0.0506, 'reports': 0.0506}
#
# topic_16
# {'gmt': 0.0519, 'forces': 0.0515, 'ukrainian': 0.0514, 'bakhmut': 0.0513, 'bst': 0.051, 'military': 0.051, 'city': 0.0509, 'moscow': 0.0509, 'updated': 0.0509, 'president': 0.0508}
#
# topic_17
# {'ukrainian': 0.0508, 'gmt': 0.0506, 'defence': 0.0506, 'updated': 0.0505, 'bst': 0.0505, 'forces': 0.0505, 'president': 0.0505, 'putin': 0.0505, 'state': 0.0504, 'zelenskiy': 0.0504}
#
# topic_18
# {'ukrainian': 0.0513, 'gmt': 0.0509, 'bst': 0.0508, 'updated': 0.0508, 'president': 0.0507, 'forces': 0.0507, 'military': 0.0506, 'defence': 0.0505, 'kyiv': 0.0505, 'region': 0.0505}
#
# topic_19
# {'ukrainian': 0.0518, 'bst': 0.0515, 'updated': 0.0513, 'president': 0.0511, 'defence': 0.051, 'gmt': 0.0509, 'putin': 0.0508, 'military': 0.0508, 'moscow': 0.0507, 'forces': 0.0507}

# %% [markdown]
# #### List of topics for each document

# %%
doc_topic_matrix[0]
# Out:
# array([1.74398326e-05, 1.74398326e-05, 1.74398326e-05, 1.74398326e-05,
#        1.74398329e-05, 1.74398326e-05, 1.74398326e-05, 1.74398326e-05,
#        9.99668643e-01, 1.74398326e-05, 1.74398326e-05, 1.74398344e-05,
#        1.74398326e-05, 1.74398326e-05, 1.74398330e-05, 1.74398326e-05,
#        1.74398326e-05, 1.74398326e-05, 1.74398326e-05, 1.74398326e-05])

# %%
doc_topic_matrix[200]
# Out:
# array([5.41653125e-06, 5.41653125e-06, 5.41653125e-06, 5.41653125e-06,
#        5.41653135e-06, 5.41653125e-06, 5.41653125e-06, 5.41653125e-06,
#        5.41653137e-06, 5.41653125e-06, 5.41653125e-06, 7.62981737e-01,
#        5.41653126e-06, 5.41653126e-06, 2.36920765e-01, 5.41653125e-06,
#        5.41653125e-06, 5.41653125e-06, 5.41653125e-06, 5.41653125e-06])

# %% [markdown]
# #### Update the terms matrix

# %%
for idx,topic in enumerate(doc_topic_matrix):
    topic_num = topic.argmax()
    top_topic = lda_topic_dict[f"topic_{topic_num}"]
    terms_df['lda'].iloc[idx] = list(top_topic.keys())

terms_df
# Out:
#                                                                                                 count  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  [gmt, ukrainian, bakhmut, updated, forces, mos...
# Russia-Ukraine war – as it happened: Ukraine to...  [ukrainian, bst, children, photograph, forces,...
# Russia-Ukraine war: Zelenskiy and UK prime mini...  [bst, ukrainian, china, friday, military, defe...
# Russia-Ukraine war live: Putin visits Mariupol ...  [putin, gmt, mariupol, city, ukrainian, march,...
# Russia-Ukraine war: Russia nearly shot down Bri...  [bst, ukrainian, documents, defence, air, city...
# ...                                                                                               ...
# BoM shifts to El Niño watch after La Niña offic...  [gmt, australia, nuclear, aukus, updated, defe...
# PM reportedly issued invitation to visit Beijin...  [bst, updated, tiktok, australia, australian, ...
# Myer to close flagship Brisbane store – as it h...  [gmt, australia, updated, says, lehrmann, auku...
# Voice referendum question and constitutional am...  [gmt, updated, australia, prime, australian, s...
# Thorpe votes with Coalition on Indigenous land ...  [bst, updated, labor, australia, national, alb...
#
#                                                                                                 tfidf  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  [gmt, ukrainian, swiss, bakhmut, updated, satu...
# Russia-Ukraine war – as it happened: Ukraine to...  [bst, ukrainian, children, reunited, photograp...
# Russia-Ukraine war: Zelenskiy and UK prime mini...  [bst, friday, teixeira, ukrainian, china, upda...
# Russia-Ukraine war live: Putin visits Mariupol ...  [gmt, mariupol, putin, ukrainian, city, warran...
# Russia-Ukraine war: Russia nearly shot down Bri...  [bst, documents, ukrainian, easter, orthodox, ...
# ...                                                                                               ...
# BoM shifts to El Niño watch after La Niña offic...  [gmt, aukus, australia, nuclear, submarine, su...
# PM reportedly issued invitation to visit Beijin...  [bst, tiktok, updated, gambling, devices, aust...
# Myer to close flagship Brisbane store – as it h...  [gmt, lehrmann, keating, australia, updated, p...
# Voice referendum question and constitutional am...  [gmt, updated, samoa, australia, australian, p...
# Thorpe votes with Coalition on Indigenous land ...  [bst, updated, labor, albanese, senate, austra...
#
#                                                                                                   lda  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  [ukrainian, gmt, bst, forces, military, presid...
# Russia-Ukraine war – as it happened: Ukraine to...  [ukrainian, gmt, bst, forces, military, presid...
# Russia-Ukraine war: Zelenskiy and UK prime mini...  [ukrainian, gmt, bst, forces, military, presid...
# Russia-Ukraine war live: Putin visits Mariupol ...  [ukrainian, gmt, bst, forces, military, presid...
# Russia-Ukraine war: Russia nearly shot down Bri...  [ukrainian, gmt, bst, forces, military, presid...
# ...                                                                                               ...
# BoM shifts to El Niño watch after La Niña offic...  [australia, gmt, aukus, nuclear, china, submar...
# PM reportedly issued invitation to visit Beijin...  [gmt, updated, australia, bst, australian, say...
# Myer to close flagship Brisbane store – as it h...  [gmt, updated, australia, bst, australian, say...
# Voice referendum question and constitutional am...  [gmt, updated, australia, bst, australian, say...
# Thorpe votes with Coalition on Indigenous land ...  [gmt, updated, australia, bst, australian, say...
#
#                                                                                                   nmf
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  [gmt, updated, march, 12, 2023, today, 11, 10,...
# Russia-Ukraine war – as it happened: Ukraine to...  [ukrainian, bakhmut, forces, defence, city, ky...
# Russia-Ukraine war: Zelenskiy and UK prime mini...  [bst, updated, april, 2023, 11, photograph, re...
# Russia-Ukraine war live: Putin visits Mariupol ...  [gmt, updated, march, 12, 2023, today, 11, 10,...
# Russia-Ukraine war: Russia nearly shot down Bri...  [documents, pentagon, leak, korea, classified,...
# ...                                                                                               ...
# BoM shifts to El Niño watch after La Niña offic...  [gmt, updated, march, 12, 2023, today, 11, 10,...
# PM reportedly issued invitation to visit Beijin...  [bst, updated, april, 2023, 11, photograph, re...
# Myer to close flagship Brisbane store – as it h...  [gmt, updated, march, 12, 2023, today, 11, 10,...
# Voice referendum question and constitutional am...  [gmt, updated, march, 12, 2023, today, 11, 10,...
# Thorpe votes with Coalition on Indigenous land ...  [bst, updated, april, 2023, 11, photograph, re...
#
# [202 rows x 4 columns]

# %% [markdown]
# #### Compare approaches

# %%
# Sample 5 random articles
samples = random.sample(range(0,202),5)

for sample in samples:
    doc = terms_df.iloc[sample]
    print(f"[{sample}] {doc.name}")
    print("\t- Counts:\t",doc['count'])
    print("\t- TFIDF:\t",doc['tfidf'])
    print("\t- LDA:\t\t",doc['lda'])
    print()
# Out:
# [153] Australia’s drought planning should begin now, not when the rain dries up | Gabrielle Chan [2023-03-06T14:00:28Z]
# 	- Counts:	 ['farmers', 'drought', 'years', 'record', 'australian', 'agricultural', 'scenario', 'australia', 'climate', 'dry']
# 	- TFIDF:	 ['drought', 'farmers', 'scenario', 'dry', 'floods', 'agricultural', 'record', 'drier', 'crops', 'climate']
# 	- LDA:		 ['ukrainian', 'bst', 'gmt', 'president', 'updated', 'military', 'defence', 'forces', 'kyiv', 'putin']
#
# [58] Russia-Ukraine war at a glance: what we know on day 374 of the invasion [2023-03-04T01:30:24Z]
# 	- Counts:	 ['city', 'ukrainian', 'foreign', 'friday', 'western', 'bakhmut', 'president', 'eastern', 'biden', 'group']
# 	- TFIDF:	 ['city', 'ukrainian', 'garland', 'friday', 'kupiansk', 'serbia', 'evacuation', 'foreign', 'reznikov', 'biden']
# 	- LDA:		 ['nato', 'bst', 'president', 'finland', 'putin', 'military', 'ukrainian', 'children', 'state', 'security']
#
# [57] ‘Algebra under air raids’: the children in a Ukraine war zone who attend class in Australia [2023-04-01T20:00:00Z]
# 	- Counts:	 ['says', 'school', 'ukrainian', 'students', 'day', 'children', 'lessons', 'like', 'raids', 'online']
# 	- TFIDF:	 ['students', 'raids', 'lessons', 'school', 'teachers', 'learning', 'says', 'virtual', 'ukrainian', 'snow']
# 	- LDA:		 ['ukrainian', 'bst', 'gmt', 'president', 'updated', 'military', 'defence', 'forces', 'kyiv', 'putin']
#
# [13] Russia-Ukraine war live: Kyiv vows to defend ‘fortress Bakhmut’  – as it happened [2023-03-05T18:17:36Z]
# 	- Counts:	 ['ukrainian', 'bakhmut', 'gmt', 'city', 'sunday', 'defence', 'military', 'forces', 'ministry', 'children']
# 	- TFIDF:	 ['ukrainian', 'gmt', 'bakhmut', 'sunday', 'city', 'tsintsadze', 'klympush', 'saturday', 'evacuations', 'ministry']
# 	- LDA:		 ['og', 'interviewed', 'teenage', 'fellow', 'contractors', 'delete', 'vs', 'yells', 'capitals', 'disclosures']
#
# [68] Russia-Ukraine war – as it happened: Finland joins Nato in move Moscow says increases risks of wider conflict [2023-04-04T18:07:09Z]
# 	- Counts:	 ['finland', 'nato', 'bst', 'military', 'member', 'alliance', 'tuesday', 'accession', 'invasion', 'state']
# 	- TFIDF:	 ['finland', 'nato', 'bst', 'accession', 'stoltenberg', 'alliance', 'military', 'member', 'brussels', 'tuesday']
# 	- LDA:		 ['og', 'interviewed', 'teenage', 'fellow', 'contractors', 'delete', 'vs', 'yells', 'capitals', 'disclosures']

# %% [markdown]
# ### Topic modelling with Non-negative Matrix Factorisation (NMF)
#
#
# [NMF](https://en.wikipedia.org/wiki/Latent_Dirichlet_allocation) is a different algorithm for obtaining *topics* (a list of terms) from a document-term matrix. It also factorises the document-term matrix into 2 factor matrices: document-topic and topic-term.

# %%
# Set the number of topics
num_topics = 20

# Create the model
nmf_model = NMF(n_components=num_topics,init='random',beta_loss='frobenius')

# Fit the model to the data and use it to transform the data
doc_topic_nmf = nmf_model.fit_transform(tfidf_dt_matrix)

topic_term_nmf = nmf_model.components_

# %%
# Get the topics and their terms
nmf_topic_dict = {}
for index, topic in enumerate(topic_term_nmf):
    zipped = zip(feature_names, topic)
    top_terms=dict(sorted(zipped, key = lambda t: t[1], reverse=True)[:10])
    #print(top_terms)
    top_terms_list= {key : round(top_terms[key], 4) for key in top_terms.keys()}
    nmf_topic_dict[f"topic_{index}"] = top_terms_list

# Print the topics with their terms    
for k,v in nmf_topic_dict.items():
    print(k)
    print(v)
    print()
# Out:
# topic_0
# {'gmt': 4.1325, 'updated': 1.2509, 'march': 0.3253, '12': 0.2976, '2023': 0.277, 'today': 0.2655, '11': 0.2216, '10': 0.2041, 'says': 0.1871, 'twitter': 0.1797}
#
# topic_1
# {'bst': 2.011, 'updated': 0.5584, '2023': 0.1229, 'reuters': 0.1195, 'april': 0.1191, 'photograph': 0.1148, '11': 0.112, 'reports': 0.1056, '12': 0.1002, 'today': 0.0947}
#
# topic_2
# {'ukrainian': 1.2683, 'bakhmut': 0.9844, 'city': 0.7187, 'forces': 0.6798, 'defence': 0.3882, 'moscow': 0.3665, 'kyiv': 0.3664, 'military': 0.3482, 'ministry': 0.3014, 'eastern': 0.298}
#
# topic_3
# {'australia': 1.1637, 'photograph': 0.9061, 'crossword': 0.8935, 'notifications': 0.8529, 'day': 0.7912, 'guardian': 0.7466, 'morning': 0.7056, 'sydney': 0.6937, 'app': 0.6695, 'sign': 0.6634}
#
# topic_4
# {'imf': 4.113, 'growth': 2.1194, 'inflation': 1.4525, 'australia': 1.3082, 'economy': 1.1185, 'forecasts': 1.0599, 'global': 0.9709, 'economic': 0.8915, 'rates': 0.8137, 'chalmers': 0.7537}
#
# topic_5
# {'nato': 2.281, 'finland': 1.9902, 'military': 1.4341, 'zelenskiy': 1.3725, 'poland': 1.2702, 'nuclear': 1.1403, 'president': 1.1326, 'petersburg': 1.0942, 'ukrainian': 1.0634, 'wednesday': 1.0207}
#
# topic_6
# {'tiktok': 1.5934, 'data': 1.33, 'centres': 0.6317, 'user': 0.6084, 'electricity': 0.5145, 'european': 0.4645, 'chinese': 0.3426, 'access': 0.3274, 'tech': 0.312, 'company': 0.3062}
#
# topic_7
# {'australia': 1.4574, 'voice': 1.3069, 'labor': 1.2725, 'albanese': 1.2374, 'australian': 1.1823, 'australians': 0.9958, 'referendum': 0.9441, 'liberal': 0.9194, 'dutton': 0.8711, 'party': 0.8447}
#
# topic_8
# {'easter': 1.3955, 'ukrainian': 1.0706, 'documents': 0.7227, 'canterbury': 0.7093, 'ministry': 0.6925, 'defence': 0.6854, 'zaporizhzhia': 0.6666, 'forces': 0.5806, 'india': 0.5383, 'pope': 0.5293}
#
# topic_9
# {'documents': 1.8099, 'pentagon': 0.917, 'leak': 0.9118, 'classified': 0.6941, 'ukrainian': 0.6278, 'korea': 0.6199, 'leaked': 0.5554, 'leaks': 0.5344, 'secret': 0.5176, 'south': 0.4917}
#
# topic_10
# {'australia': 2.0301, 'aukus': 1.7803, 'submarines': 1.6105, 'nuclear': 1.4616, 'submarine': 1.0442, 'australian': 0.8102, 'mead': 0.7155, 'keating': 0.6329, 'powered': 0.626, 'courtney': 0.6244}
#
# topic_11
# {'obama': 0.368, 'photograph': 0.2565, 'says': 0.1982, 'crowd': 0.1837, 'writers': 0.1809, 'millar': 0.1763, 'couples': 0.1761, 'adelaide': 0.1742, 'word': 0.1696, 'festival': 0.1607}
#
# topic_12
# {'china': 2.8194, 'xi': 2.5061, 'kishida': 1.4803, 'putin': 1.1502, 'taiwan': 1.0948, 'chinese': 0.988, 'japan': 0.8841, 'beijing': 0.8289, 'moscow': 0.8146, 'visit': 0.756}
#
# topic_13
# {'ukrainian': 1.2009, 'friday': 0.9504, 'restored': 0.8767, 'georgia': 0.8392, 'kyiv': 0.7943, 'kotsiubailo': 0.7664, 'wagner': 0.6664, 'olympic': 0.6615, 'bakhmut': 0.6559, 'saturday': 0.5959}
#
# topic_14
# {'drone': 0.6505, 'reaper': 0.4705, 'mq': 0.3235, 'military': 0.3077, 'incident': 0.2914, 'black': 0.2871, 'defence': 0.283, 'fighter': 0.2786, 'sea': 0.2556, 'ukrainian': 0.2146}
#
# topic_15
# {'zealand': 3.2097, 'tai': 1.9167, 'te': 1.9167, 'mahuta': 0.8615, 'foreign': 0.6447, 'nuclear': 0.5618, 'thursday': 0.551, 'china': 0.5026, 'hipkins': 0.4859, 'wood': 0.4786}
#
# topic_16
# {'inflation': 0.984, 'rba': 0.9082, 'rate': 0.9028, 'lowe': 0.4333, 'australia': 0.3395, 'rises': 0.3341, 'wage': 0.2921, 'rise': 0.2902, 'pause': 0.2884, 'price': 0.2703}
#
# topic_17
# {'gas': 2.5005, 'emissions': 2.2756, 'fossil': 1.5423, 'climate': 1.4215, 'energy': 1.1111, 'carbon': 1.0895, 'australia': 1.0742, 'coal': 0.9828, 'tonnes': 0.8187, 'projects': 0.816}
#
# topic_18
# {'kara': 1.0815, 'murza': 1.0815, 'ukrainian': 0.6613, 'grain': 0.5757, 'gershkovich': 0.5544, 'military': 0.4594, 'moscow': 0.4115, 'lula': 0.3989, 'monday': 0.3741, 'tuesday': 0.3643}
#
# topic_19
# {'icc': 0.8629, 'putin': 0.8134, 'warrant': 0.652, 'arrest': 0.5897, 'children': 0.4712, 'ukrainian': 0.4016, 'president': 0.3754, 'nato': 0.373, 'court': 0.3596, 'turkey': 0.353}

# %% [markdown]
# #### Update the terms matrix

# %%
for idx,topic in enumerate(doc_topic_nmf):
    topic_num = topic.argmax()
    top_topic = lda_topic_dict[f"topic_{topic_num}"]
    terms_df['nmf'].iloc[idx] = list(top_topic.keys())

terms_df
# Out:
#                                                                                                 count  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  [gmt, ukrainian, bakhmut, updated, forces, mos...
# Russia-Ukraine war – as it happened: Ukraine to...  [ukrainian, bst, children, photograph, forces,...
# Russia-Ukraine war: Zelenskiy and UK prime mini...  [bst, ukrainian, china, friday, military, defe...
# Russia-Ukraine war live: Putin visits Mariupol ...  [putin, gmt, mariupol, city, ukrainian, march,...
# Russia-Ukraine war: Russia nearly shot down Bri...  [bst, ukrainian, documents, defence, air, city...
# ...                                                                                               ...
# BoM shifts to El Niño watch after La Niña offic...  [gmt, australia, nuclear, aukus, updated, defe...
# PM reportedly issued invitation to visit Beijin...  [bst, updated, tiktok, australia, australian, ...
# Myer to close flagship Brisbane store – as it h...  [gmt, australia, updated, says, lehrmann, auku...
# Voice referendum question and constitutional am...  [gmt, updated, australia, prime, australian, s...
# Thorpe votes with Coalition on Indigenous land ...  [bst, updated, labor, australia, national, alb...
#
#                                                                                                 tfidf  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  [gmt, ukrainian, swiss, bakhmut, updated, satu...
# Russia-Ukraine war – as it happened: Ukraine to...  [bst, ukrainian, children, reunited, photograp...
# Russia-Ukraine war: Zelenskiy and UK prime mini...  [bst, friday, teixeira, ukrainian, china, upda...
# Russia-Ukraine war live: Putin visits Mariupol ...  [gmt, mariupol, putin, ukrainian, city, warran...
# Russia-Ukraine war: Russia nearly shot down Bri...  [bst, documents, ukrainian, easter, orthodox, ...
# ...                                                                                               ...
# BoM shifts to El Niño watch after La Niña offic...  [gmt, aukus, australia, nuclear, submarine, su...
# PM reportedly issued invitation to visit Beijin...  [bst, tiktok, updated, gambling, devices, aust...
# Myer to close flagship Brisbane store – as it h...  [gmt, lehrmann, keating, australia, updated, p...
# Voice referendum question and constitutional am...  [gmt, updated, samoa, australia, australian, p...
# Thorpe votes with Coalition on Indigenous land ...  [bst, updated, labor, albanese, senate, austra...
#
#                                                                                                   lda  \
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  [ukrainian, gmt, bst, forces, military, presid...
# Russia-Ukraine war – as it happened: Ukraine to...  [ukrainian, gmt, bst, forces, military, presid...
# Russia-Ukraine war: Zelenskiy and UK prime mini...  [ukrainian, gmt, bst, forces, military, presid...
# Russia-Ukraine war live: Putin visits Mariupol ...  [ukrainian, gmt, bst, forces, military, presid...
# Russia-Ukraine war: Russia nearly shot down Bri...  [ukrainian, gmt, bst, forces, military, presid...
# ...                                                                                               ...
# BoM shifts to El Niño watch after La Niña offic...  [australia, gmt, aukus, nuclear, china, submar...
# PM reportedly issued invitation to visit Beijin...  [gmt, updated, australia, bst, australian, say...
# Myer to close flagship Brisbane store – as it h...  [gmt, updated, australia, bst, australian, say...
# Voice referendum question and constitutional am...  [gmt, updated, australia, bst, australian, say...
# Thorpe votes with Coalition on Indigenous land ...  [gmt, updated, australia, bst, australian, say...
#
#                                                                                                   nmf
# Russia-Ukraine war live: Ukraine ‘buying time’ ...  [bst, ukrainian, defence, military, gmt, updat...
# Russia-Ukraine war – as it happened: Ukraine to...  [ukrainian, bst, gmt, president, updated, mili...
# Russia-Ukraine war: Zelenskiy and UK prime mini...  [ukrainian, bst, gmt, president, updated, mili...
# Russia-Ukraine war live: Putin visits Mariupol ...  [ukrainian, bst, updated, president, defence, ...
# Russia-Ukraine war: Russia nearly shot down Bri...  [ukrainian, bst, gmt, president, updated, mili...
# ...                                                                                               ...
# BoM shifts to El Niño watch after La Niña offic...  [qin, suppression, surely, modernisation, myth...
# PM reportedly issued invitation to visit Beijin...  [ukrainian, bst, gmt, president, updated, mili...
# Myer to close flagship Brisbane store – as it h...  [bst, ukrainian, defence, military, gmt, updat...
# Voice referendum question and constitutional am...  [bst, ukrainian, defence, military, gmt, updat...
# Thorpe votes with Coalition on Indigenous land ...  [ukrainian, bst, gmt, president, updated, mili...
#
# [202 rows x 4 columns]

# %% [markdown]
# ### Compare approaches

# %%
# Sample 5 random articles
samples = random.sample(range(0,202),5)

for sample in samples:
    doc = terms_df.iloc[sample]
    print(f"[{sample}] {doc.name}")
    print("\t- Counts:\t",doc['count'])
    print("\t- TFIDF:\t",doc['tfidf'])
    print("\t- LDA:\t\t",doc['lda'])
    print("\t- NMF:\t\t",doc['nmf'])
    print()
# Out:
# [4] Russia-Ukraine war: Russia nearly shot down British spy plane near Ukraine, alleged leaked US document claims – as it happened [2023-04-10T18:24:19Z]
# 	- Counts:	 ['bst', 'ukrainian', 'documents', 'defence', 'air', 'city', 'bakhmut', 'president', 'updated', 'south']
# 	- TFIDF:	 ['bst', 'documents', 'ukrainian', 'easter', 'orthodox', 'palm', 'bakhmut', 'updated', 'air', 'defence']
# 	- LDA:		 ['ukrainian', 'gmt', 'bst', 'forces', 'military', 'president', 'defence', 'updated', 'bakhmut', 'city']
# 	- NMF:		 ['ukrainian', 'bst', 'gmt', 'president', 'updated', 'military', 'defence', 'forces', 'kyiv', 'putin']
#
# [64] What happened in the Russia-Ukraine war this week? Catch up with the must-read news and analysis [2023-04-21T20:00:50Z]
# 	- Counts:	 ['ukrainian', 'reported', 'photograph', 'kyiv', 'military', 'city', 'state', 'lula', 'putin', 'grain']
# 	- TFIDF:	 ['ukrainian', 'lula', 'belgorod', 'brazil', 'accidentally', 'reported', 'kyiv', 'corruption', 'photograph', 'easter']
# 	- LDA:		 ['ukrainian', 'gmt', 'bst', 'forces', 'military', 'president', 'defence', 'updated', 'bakhmut', 'city']
# 	- NMF:		 ['ukrainian', 'gmt', 'bst', 'updated', 'president', 'forces', 'military', 'defence', 'kyiv', 'region']
#
# [55] Russia-Ukraine war live: new Russian law shows Moscow expects lengthy conflict, warns UK — as it happened [2023-04-15T16:54:33Z]
# 	- Counts:	 ['bst', 'ukrainian', 'president', 'updated', 'friday', 'city', 'saturday', 'defence', 'lula', 'killed']
# 	- TFIDF:	 ['bst', 'ukrainian', 'lula', 'updated', 'friday', 'saturday', 'president', 'sloviansk', 'rescue', 'city']
# 	- LDA:		 ['ukrainian', 'gmt', 'bst', 'forces', 'military', 'president', 'defence', 'updated', 'bakhmut', 'city']
# 	- NMF:		 ['ukrainian', 'bst', 'gmt', 'president', 'updated', 'military', 'defence', 'forces', 'kyiv', 'putin']
#
# [5] Russia-Ukraine war live: Hungary signs new energy deals with Russia; UN tally of Ukraine civilian deaths approaches 8,500 [2023-04-11T18:00:08Z]
# 	- Counts:	 ['bst', 'ukrainian', 'forces', 'documents', 'defence', 'updated', 'state', 'military', 'gershkovich', 'prime']
# 	- TFIDF:	 ['bst', 'ukrainian', 'documents', 'gershkovich', 'shmyhal', 'forces', 'updated', 'poulsen', 'leak', 'szijjártó']
# 	- LDA:		 ['ukrainian', 'gmt', 'bst', 'forces', 'military', 'president', 'defence', 'updated', 'bakhmut', 'city']
# 	- NMF:		 ['ukrainian', 'bst', 'gmt', 'president', 'updated', 'military', 'defence', 'forces', 'kyiv', 'putin']
#
# [172] ‘We get to hear the stories’: unpacking the Archibald prize at the Art Gallery of NSW [2023-03-29T14:00:36Z]
# 	- Counts:	 ['says', 'portrait', 'finlay', 'archibald', 'blake', 'photograph', 'wiggins', 'sharp', 'guardian', 'prize']
# 	- TFIDF:	 ['finlay', 'portrait', 'archibald', 'wiggins', 'blake', 'painting', 'says', 'sharp', 'gallery', 'prize']
# 	- LDA:		 ['australia', 'gmt', 'aukus', 'nuclear', 'china', 'submarines', 'defence', 'updated', 'australian', 'submarine']
# 	- NMF:		 ['gmt', 'updated', 'australia', 'bst', 'australian', 'says', 'voice', 'labor', 'albanese', 'today']

# %%
doc
# Out:
# count    [says, portrait, finlay, archibald, blake, pho...
# tfidf    [finlay, portrait, archibald, wiggins, blake, ...
# lda      [australia, gmt, aukus, nuclear, china, submar...
# nmf      [gmt, updated, australia, bst, australian, say...
# Name: ‘We get to hear the stories’: unpacking the Archibald prize at the Art Gallery of NSW [2023-03-29T14:00:36Z], dtype: object
