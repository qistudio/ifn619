# %% [markdown]
# # IFN619 - Data Analytics for Strategic Decision Makers
# ---

# %% [markdown]
# Welcome to IFN619.
#
# All Jupyter notebook resources for this unit, can be obtained from the [QI Studio GitHub repo for IFN619](https://github.com/qistudio/ifn619)
#
# You can easily copy the latest files to your Jupyter folder by clicking here: [Get files from GitHub](https://jupyter-oncampus.qutanalytics.io/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fqistudio%2Fifn619&urlpath=lab%2Ftree%2F&branch=release)
