# %% [markdown]
# <div style="background:#E9FFF6; color:#440404; padding:8px; border-radius: 4px; text-align: center; font-weight: 500;">IFN619 - Data Analytics for Strategic Decision Makers</div>

# %% [markdown]
# # IFN619 :: B4-Tutorial: Building a Meaningful Narrative
# This tutorial notebook aims to help you understand the importance of building a meaningful narrative. Prompt questions are included throughout this notebook to help you reflect on how each phase of the data analytics cycle connects to your question and ethical considerations, contributing to build a meaningful narrative. Use appropriate headings - the QDAVI cycle is a good place to start.

# %%
import pandas as pd 
import plotly.express as px

# %% [markdown]
# ### Scenario
#
# You work for the Brisbane City Council. Your office has received multiple complaints over the past month from disability advocacy groups and individual residents about accessibility barriers at various ferry terminals.Your manager has asked you to prepare a brief report with data-driven insights and actionable recommendations for the next council meeting in two weeks. The report should be accessible to council members who may not have technical backgrounds or detailed knowledge of current ferry terminal conditions.
#
# **Note:** For the purpose of demonstration, we will continue using the Brisbane Ferry Terminal data we saved (assume the dataset is the current status of ferry terminals).

# %% [markdown]
# Use this space to brainstorm your approach to addressing the business concerns. This is your working space - ideas will evolve as you explore the data. You can later move relevant content to your final report sections.
#
# **[Write here]**

# %% [markdown]
# ### QDAVI - Question
#
# - **CONCERN:** What is the main concern from the scenario, and why does it matter?
# - **STAKEHOLDERS/STAKES:** Who are the stakeholders? What are the stakes for each group of stakeholders? Who might have the highest stakes, and why?
# - **QUESTION:** What is a good question that addresses the concern? Why do you think your question is significant to stakeholders? Based on the significance, what might you look for in the data?
#
# Note: Data analysis is iterative. As you investigate further, revisit your initial responses to these questions:
# - Does your analysis still align with the stakeholders’ core concerns?
# - Have new findings changed the significance of your original question?
# - If you uncovered unexpected insights (e.g., fairness issues in a specific department), how do they reshape your narrative?

# %% [markdown]
# **[Write here]**

# %% [markdown]
# ### QDAVI - Data

# %%
# use brisbane ferry terminals dataset saved from B1 tutorial
df = pd.read_csv("data/brisbane_ferry_terminals.csv")
df.head()
# Out:
#                   DESCRIPTION                STREETNAME ADJ_PROPERTY_ADDRESS  \
# 0  UQ St Lucia ferry terminal  Sir William Macgregor Dr       342 CARMODY RD
# 1     West End ferry terminal                Hoogley St        55 HOOGLEY ST
# 2  Guyatt Park ferry terminal              Macquarie St          46 HIRON ST
# 3      Regatta ferry terminal             Coronation Dr    566 CORONATION DR
# 4       Milton ferry terminal             Coronation Dr    299 CORONATION DR
#
#      SUBURB    LATITUDE  LATITUDE.1  LONGITUDE    STATUS SERVICE_TYPE  \
# 0  ST LUCIA  501,931.56     -27.497    153.020    ACTIVE      CityCat
# 1  WEST END  500,318.37     -27.490    153.003    ACTIVE      CityCat
# 2  ST LUCIA  500,216.72     -27.492    153.002    ACTIVE      CityCat
# 3   TOOWONG  499,692.57     -27.483    152.997  INACTIVE      CityCat
# 4    MILTON  500,543.38     -27.474    153.006    ACTIVE      CityCat
#
#            PARKING LIFT_ACCESS ACCESSIBLE_PARKING  \
# ...

# %% [markdown]
# #### Reflect on the data
#
# - What does the data tell us?
# - What can we do with the data to address your question?
# - Why is the data relevant to addressing your question?
# - Are their data quality issues? What consequences we might have if we don't address those issues (in relation to addressing your question), and why?

# %% [markdown]
# **[Write here]**

# %% [markdown]
# **Note:** You may need to clean the data in most occasions. Also, you may need to find supplementary data to help you address your question. For the purpose of this tutorial, this will be skipped; however, it is important to ask yourself questions such as:
# - Do you need to clean the data before analysing them? (e.g., missing values or erroneous values in some columns)
# - Do you have enough information from the existing dataset to address our question(s)? If not, what can you do? (e.g., adjust the scope of our investigation, find additional reliable data, etc.)

# %% [markdown]
# Before we move on, this might be a good place to include the map visualisation we practiced in Part 1.
# - Why it is important (or necessary) to include the map here? How does it help with understanding the data and the question?
# - What levels of information/justification should you include, and how do they relate to the big picture?

# %% [markdown]
# **[Write here]**

# %%
# code for map - add more cells if necessary

# %% [markdown]
# - What can we conclude from the map?
# - How are the results singificant to the question? Why might this be important to stakeholders?
# - What can we do next from the insights?

# %% [markdown]
# **[Write here]**

# %% [markdown]
# ### QDAVI - Analysis
#
# Based on your reflections above, you can start investigating relevant information from the data. Some questions to consider throughout this section:
# - Why do you decide to conduct [any specific analysis]?
# - What does the result from your specific analysis tell us? Does the result help to answer your question, and how?
# - What are the ethical considerations associated with the result? Is it fair and why?
# - Do you need to investigate further, and why?
#
# **Note:** Make sure you use a combination of code and markdown cells throughout.
# - `code` cells: how you do it
# - `markdown` cells: what you do (including decisions you make), why you do it (including decisions you make), what you find, how does your result relevant to the question(s) and business concern(s), etc.

# %%
# data exploration - add more cells

# %% [markdown]
# **[Write here]** - add more cells

# %% [markdown]
# ## QDAVI - Visualisation
#
# You can think of this section as an extension of `Analysis` because most of times it makes more sense to visualise what you are analysing to present the results that are easier to interpret. You may also include visualisation in any other sections to help understand the data. For example, you could have included a map in the `Data` section to help us understand the distribution of the ferry terminals before conducting any further analyses.
#
# Some questions to consider for visualisation:
# - What is the purpose of including [a specific visualisation]?
# - Why do you decide to use [a certain plot (e.g., line plot, histogram, etc.)]? What decision do you make for this visualisation, and why?
#
# [This could be a good place to include the code for one visualisation]
#
# - What can we see from the visualisation? Why is it important to answer your question? Why might the results be important to stakeholders?
# - What are the ethical considerations associated with the result? Is it fair and why?
# - Do you need to investigate further, and why?

# %% [markdown]
# **[Write here]** - add more cells

# %%
# data visualisation - add more cells

# %% [markdown]
# ## QDAVI - Insights
# - What are your key findings? What can we learn from them?
# - How are your findings and insights directly address the question and are appropriate to the scenario?
# - Why the insights are signficant for the question and in turn for the overall scenario?
# - How are the insights limited? What are the implications of these limitations for the stakeholders?
# - What ethical considerations did you take into account and why?
# - How might the analysis be improved for better quality insights? Why didn't you make these improvements in your analysis?

# %% [markdown]
# **[Write here]**
