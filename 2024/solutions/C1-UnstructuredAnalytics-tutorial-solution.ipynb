# %% [markdown]
# <div style="background:#E9FFF6; color:#440404; padding:8px; border-radius: 4px; text-align: center; font-weight: 500;">IFN619 - Data Analytics for Strategic Decision Makers (2024_sem1)</div>

# %% [markdown]
# # IFN619 :: C1-UnstructuredAnalytics
#
# For this tutorial, you will use the studio notebook as a guide, and:
#
# 1. Use the Guardian API to undertake your own search and obtain a json file of documents
# 2. Create a TF/IDF document-term matrix for your documents
# 3. Perform topic modelling of your documents using NMF

# %%
# Import the necessary libraries
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF
import pandas as pd
import json
import random
# Out:
# /tmp/ipykernel_1436/2854994355.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ### 1. Accessing the data via The Guardian API
#
# Make a copy of the studio notebook file, and modify it to perform your own search of the Guardian API. **NOTE:** you will need to obtain a developer API key first.
#
# A suggested search term is "ukraine", or come up with another that is of interest to you and will return a fair amount of data.
#
# Save your search results in a json file, then read in that data below...

# %%
# Load the data - articles from The Guardian
file_path = "data/"
file_name = "ukraine_articles.json"

with open(f"{file_path}{file_name}",'r', encoding='utf-8') as fp:
    articles = json.load(fp)

print(f"Loaded {len(articles)} articles from {file_name}")
# Out:
# Loaded 99 articles from ukraine_articles.json

# %% [markdown]
# #### Create a top10 terms dataframe
#
# Using the index from the documents, create a dataframe that can hold the top10 terms for each document.

# %%
# Create a dataframe to hold top terms for each analysis type
terms_df = pd.DataFrame(index=articles.keys(),columns=['tfidf','nmf'])
terms_df
# Out:
#                                                    tfidf  nmf
# Ukraine war briefing: Nato foreign ministers to...   NaN  NaN
# Ukraine war briefing: Biden scrapes together $3...   NaN  NaN
# Ukraine war briefing: Russian forces occupying ...   NaN  NaN
# Ukraine war briefing: Russian fighter jet crash...   NaN  NaN
# Ukraine war briefing: Pope urges Ukraine to hav...   NaN  NaN
# ...                                                  ...  ...
# Israel-Gaza war: US condemns ‘cynical’ Russia a...   NaN  NaN
# Collapse at regional mine – as it happened [202...   NaN  NaN
# Nowland family reach settlement – as it happene...   NaN  NaN
# King takes aim at Liberals over preselection of...   NaN  NaN
# Dutton claims PM ‘misrepresented’ earlier comme...   NaN  NaN
#
# [99 rows x 2 columns]

# %% [markdown]
# ### Term Frequency / Inverse Document Frequency (TF/IDF)

# %%
# Set parameters appropriate to your data
tfidf_vectorizer = TfidfVectorizer(
    max_df=0.75, min_df=2, max_features=10000, stop_words="english"
)

# %%
# Get the document vectors
tfidf_dt_matrix = tfidf_vectorizer.fit_transform(articles.values())

# Display the vector for the first document
tfidf_dt_matrix.toarray()[0]
# Out:
# array([0.08039513, 0.        , 0.        , ..., 0.        , 0.        ,
#        0.        ])

# %% [markdown]
# #### Update the terms matrix

# %%
# list of feature names
feature_names = tfidf_vectorizer.get_feature_names_out()

# create a df to combine matrix with feature names
tfidf_df = pd.DataFrame(tfidf_dt_matrix.toarray(), index=articles.keys(), columns=feature_names)
tfidf_df
# Out:
#                                                          000     000km  \
# Ukraine war briefing: Nato foreign ministers to...  0.080395  0.000000
# Ukraine war briefing: Biden scrapes together $3...  0.000000  0.048352
# Ukraine war briefing: Russian forces occupying ...  0.051112  0.000000
# Ukraine war briefing: Russian fighter jet crash...  0.000000  0.000000
# Ukraine war briefing: Pope urges Ukraine to hav...  0.000000  0.000000
# ...                                                      ...       ...
# Israel-Gaza war: US condemns ‘cynical’ Russia a...  0.019069  0.000000
# Collapse at regional mine – as it happened [202...  0.012499  0.000000
# Nowland family reach settlement – as it happene...  0.042069  0.004821
# King takes aim at Liberals over preselection of...  0.021930  0.000000
# Dutton claims PM ‘misrepresented’ earlier comme...  0.026573  0.000000
#
#                                                         00am      00pm  \
# Ukraine war briefing: Nato foreign ministers to...  0.000000  0.000000
# Ukraine war briefing: Biden scrapes together $3...  0.000000  0.000000
# Ukraine war briefing: Russian forces occupying ...  0.000000  0.000000
# Ukraine war briefing: Russian fighter jet crash...  0.000000  0.000000
# Ukraine war briefing: Pope urges Ukraine to hav...  0.000000  0.000000
# ...                                                      ...       ...
# Israel-Gaza war: US condemns ‘cynical’ Russia a...  0.000000  0.000000
# Collapse at regional mine – as it happened [202...  0.008862  0.000000
# Nowland family reach settlement – as it happene...  0.006779  0.011683
# King takes aim at Liberals over preselection of...  0.006479  0.003722
# Dutton claims PM ‘misrepresented’ earlier comme...  0.011775  0.000000
#
#                                                         01am      01pm  \
# Ukraine war briefing: Nato foreign ministers to...  0.000000  0.000000
# Ukraine war briefing: Biden scrapes together $3...  0.000000  0.000000
# Ukraine war briefing: Russian forces occupying ...  0.000000  0.000000
# Ukraine war briefing: Russian fighter jet crash...  0.000000  0.000000
# Ukraine war briefing: Pope urges Ukraine to hav...  0.000000  0.000000
# ...                                                      ...       ...
# Israel-Gaza war: US condemns ‘cynical’ Russia a...  0.000000  0.000000
# Collapse at regional mine – as it happened [202...  0.008862  0.000000
# Nowland family reach settlement – as it happene...  0.010169  0.003390
# King takes aim at Liberals over preselection of...  0.009718  0.006479
# Dutton claims PM ‘misrepresented’ earlier comme...  0.011775  0.002944
#
#                                                         02am      02pm  \
# Ukraine war briefing: Nato foreign ministers to...  0.000000  0.000000
# Ukraine war briefing: Biden scrapes together $3...  0.000000  0.000000
# Ukraine war briefing: Russian forces occupying ...  0.000000  0.000000
# Ukraine war briefing: Russian fighter jet crash...  0.000000  0.000000
# Ukraine war briefing: Pope urges Ukraine to hav...  0.000000  0.000000
# ...                                                      ...       ...
# Israel-Gaza war: US condemns ‘cynical’ Russia a...  0.000000  0.000000
# Collapse at regional mine – as it happened [202...  0.000000  0.005091
# Nowland family reach settlement – as it happene...  0.007131  0.003894
# King takes aim at Liberals over preselection of...  0.006815  0.003722
# Dutton claims PM ‘misrepresented’ earlier comme...  0.012387  0.000000
#
#                                                         03am      03pm  ...  \
# Ukraine war briefing: Nato foreign ministers to...  0.000000  0.000000  ...
# Ukraine war briefing: Biden scrapes together $3...  0.000000  0.000000  ...
# Ukraine war briefing: Russian forces occupying ...  0.000000  0.000000  ...
# Ukraine war briefing: Russian fighter jet crash...  0.000000  0.000000  ...
# Ukraine war briefing: Pope urges Ukraine to hav...  0.000000  0.000000  ...
# ...                                                      ...       ...  ...
# Israel-Gaza war: US condemns ‘cynical’ Russia a...  0.000000  0.004061  ...
# Collapse at regional mine – as it happened [202...  0.009084  0.000000  ...
# Nowland family reach settlement – as it happene...  0.000000  0.003665  ...
# King takes aim at Liberals over preselection of...  0.003320  0.000000  ...
# Dutton claims PM ‘misrepresented’ earlier comme...  0.003017  0.009550  ...
#
#                                                      zdaniel   zealand  \
# Ukraine war briefing: Nato foreign ministers to...  0.000000  0.000000
# Ukraine war briefing: Biden scrapes together $3...  0.000000  0.000000
# Ukraine war briefing: Russian forces occupying ...  0.000000  0.000000
# Ukraine war briefing: Russian fighter jet crash...  0.000000  0.000000
# Ukraine war briefing: Pope urges Ukraine to hav...  0.000000  0.000000
# ...                                                      ...       ...
# Israel-Gaza war: US condemns ‘cynical’ Russia a...  0.000000  0.000000
# Collapse at regional mine – as it happened [202...  0.000000  0.000000
# Nowland family reach settlement – as it happene...  0.000000  0.000000
# King takes aim at Liberals over preselection of...  0.004922  0.000000
# Dutton claims PM ‘misrepresented’ earlier comme...  0.004473  0.003097
#
#                                                     zelenskiy      zero  \
# Ukraine war briefing: Nato foreign ministers to...   0.030689  0.000000
# Ukraine war briefing: Biden scrapes together $3...   0.000000  0.000000
# Ukraine war briefing: Russian forces occupying ...   0.087800  0.000000
# Ukraine war briefing: Russian fighter jet crash...   0.130636  0.000000
# Ukraine war briefing: Pope urges Ukraine to hav...   0.000000  0.000000
# ...                                                       ...       ...
# Israel-Gaza war: US condemns ‘cynical’ Russia a...   0.000000  0.000000
# Collapse at regional mine – as it happened [202...   0.000000  0.009323
# Nowland family reach settlement – as it happene...   0.000000  0.014263
# King takes aim at Liberals over preselection of...   0.000000  0.003408
# Dutton claims PM ‘misrepresented’ earlier comme...   0.000000  0.000000
#
#                                                          zoe  zomi      zone  \
# Ukraine war briefing: Nato foreign ministers to...  0.000000   0.0  0.000000
# Ukraine war briefing: Biden scrapes together $3...  0.000000   0.0  0.000000
# Ukraine war briefing: Russian forces occupying ...  0.000000   0.0  0.000000
# Ukraine war briefing: Russian fighter jet crash...  0.000000   0.0  0.000000
# Ukraine war briefing: Pope urges Ukraine to hav...  0.000000   0.0  0.000000
# ...                                                      ...   ...       ...
# Israel-Gaza war: US condemns ‘cynical’ Russia a...  0.000000   0.0  0.000000
# Collapse at regional mine – as it happened [202...  0.000000   0.0  0.000000
# Nowland family reach settlement – as it happene...  0.000000   0.0  0.000000
# King takes aim at Liberals over preselection of...  0.011551   0.0  0.006641
# Dutton claims PM ‘misrepresented’ earlier comme...  0.010498   0.0  0.000000
#
#                                                        zones       zoo  zuhri
# Ukraine war briefing: Nato foreign ministers to...  0.000000  0.000000    0.0
# Ukraine war briefing: Biden scrapes together $3...  0.000000  0.000000    0.0
# Ukraine war briefing: Russian forces occupying ...  0.000000  0.000000    0.0
# Ukraine war briefing: Russian fighter jet crash...  0.000000  0.000000    0.0
# Ukraine war briefing: Pope urges Ukraine to hav...  0.000000  0.000000    0.0
# ...                                                      ...       ...    ...
# Israel-Gaza war: US condemns ‘cynical’ Russia a...  0.005059  0.000000    0.0
# Collapse at regional mine – as it happened [202...  0.000000  0.000000    0.0
# Nowland family reach settlement – as it happene...  0.000000  0.000000    0.0
# King takes aim at Liberals over preselection of...  0.000000  0.000000    0.0
# Dutton claims PM ‘misrepresented’ earlier comme...  0.000000  0.012562    0.0
#
# [99 rows x 8655 columns]

# %%
for idx in terms_df.index:
    tfidf = dict(tfidf_df.loc[idx].sort_values(ascending=False).head(5))
    #print(counts)
    terms_df.at[idx,'tfidf'] = list(tfidf.keys()) 

terms_df
# Out:
#                                                                                              tfidf  \
# Ukraine war briefing: Nato foreign ministers to...         [adm, nato, russian, tuesday, refinery]
# Ukraine war briefing: Biden scrapes together $3...      [johnson, russian, kursk, tuesday, nizhny]
# Ukraine war briefing: Russian forces occupying ...   [friday, torture, russian, serbia, ukrainian]
# Ukraine war briefing: Russian fighter jet crash...  [polish, thursday, ukrainian, russian, poland]
# Ukraine war briefing: Pope urges Ukraine to hav...            [saturday, boy, ria, moscow, afraid]
# ...                                                                                            ...
# Israel-Gaza war: US condemns ‘cynical’ Russia a...        [gaza, israel, gmt, blinken, resolution]
# Collapse at regional mine – as it happened [202...  [gmt, updated, australia, funding, government]
# Nowland family reach settlement – as it happene...          [gmt, updated, super, women, parental]
# King takes aim at Liberals over preselection of...    [gmt, updated, labor, government, australia]
# Dutton claims PM ‘misrepresented’ earlier comme...     [gmt, updated, rudd, government, australia]
#
#                                                     nmf
# Ukraine war briefing: Nato foreign ministers to...  NaN
# Ukraine war briefing: Biden scrapes together $3...  NaN
# Ukraine war briefing: Russian forces occupying ...  NaN
# Ukraine war briefing: Russian fighter jet crash...  NaN
# Ukraine war briefing: Pope urges Ukraine to hav...  NaN
# ...                                                 ...
# Israel-Gaza war: US condemns ‘cynical’ Russia a...  NaN
# Collapse at regional mine – as it happened [202...  NaN
# Nowland family reach settlement – as it happene...  NaN
# King takes aim at Liberals over preselection of...  NaN
# Dutton claims PM ‘misrepresented’ earlier comme...  NaN
#
# [99 rows x 2 columns]

# %% [markdown]
# ### Topic modelling with Non-negative Matrix Factorisation (NMF)
#
#
# [NMF](https://en.wikipedia.org/wiki/Latent_Dirichlet_allocation) is a different algorithm for obtaining *topics* (a list of terms) from a document-term matrix. It also factorises the document-term matrix into 2 factor matrices: document-topic and topic-term.

# %%
# Set the number of topics
num_topics = 20

# Create the model
nmf_model = NMF(n_components=num_topics, max_iter=200, init='random', beta_loss='frobenius')

# Fit the model to the data and use it to transform the data
doc_topic_nmf = nmf_model.fit_transform(tfidf_dt_matrix)

topic_term_nmf = nmf_model.components_
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/decomposition/_nmf.py:1770: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn(

# %%
# Get the topics and their terms
nmf_topic_dict = {}
for index, topic in enumerate(topic_term_nmf):
    zipped = zip(feature_names, topic)
    top_terms=dict(sorted(zipped, key = lambda t: t[1], reverse=True)[:10])
    #print(top_terms)
    top_terms_list= {key : round(top_terms[key], 4) for key in top_terms.keys()}
    nmf_topic_dict[f"topic_{index}"] = top_terms_list

# Print the topics with their terms    
for k,v in nmf_topic_dict.items():
    print(k)
    print(v)
    print()
# Out:
# topic_0
# {'gmt': 3.3166, 'updated': 1.5042, 'government': 0.8724, 'labor': 0.5851, 'australia': 0.5505, 'minister': 0.4633, 'greens': 0.415, 'says': 0.4012, 'discrimination': 0.3888, 'religious': 0.3851}
#
# topic_1
# {'australia': 0.5136, 'crossword': 0.3282, 'notifications': 0.3282, 'sign': 0.2947, 'day': 0.2929, 'morning': 0.2768, 'world': 0.274, 'story': 0.2598, 'sydney': 0.2404, 'australian': 0.2172}
#
# topic_2
# {'russian': 1.3995, 'saturday': 1.3263, 'sunday': 1.01, 'german': 0.93, 'drone': 0.8888, 'odesa': 0.8645, 'recording': 0.8532, 'kara': 0.8329, 'murza': 0.8329, 'navalny': 0.8086}
#
# topic_3
# {'says': 1.3199, 'australia': 0.9891, 'jiang': 0.9395, 'visas': 0.8944, 'families': 0.7617, 'palestinians': 0.72, 'support': 0.7177, 'mh370': 0.7127, 'humanitarian': 0.6996, 'gaza': 0.6702}
#
# topic_4
# {'polish': 2.0955, 'russian': 1.6905, 'missile': 1.5784, 'poland': 1.5721, 'ukrainian': 1.4107, 'air': 1.3873, 'missiles': 1.3235, 'sunday': 1.3219, 'energy': 1.3138, 'lviv': 1.2572}
#
# topic_5
# {'australia': 2.4762, 'aukus': 2.0475, 'nuclear': 1.7163, 'australian': 1.3813, 'uk': 1.3302, 'cameron': 1.2169, 'submarines': 1.1886, 'asc': 1.118, 'submarine': 0.975, 'marles': 0.845}
#
# topic_6
# {'abc': 1.6537, 'film': 1.1509, 'documentary': 1.1247, 'langan': 0.8234, 'myroshnychenko': 0.8118, 'soldiers': 0.8012, 'corners': 0.6238, 'australian': 0.5918, 'ukrainian': 0.5712, 'editorial': 0.5621}
#
# topic_7
# {'russian': 2.4525, 'ukrainian': 1.9633, 'eu': 1.1668, 'zelenskiy': 1.0497, 'thursday': 0.936, 'friday': 0.8337, 'military': 0.7427, 'region': 0.682, 'kyiv': 0.6635, 'kharkiv': 0.6629}
#
# topic_8
# {'budget': 1.5917, 'surplus': 1.2579, 'forecast': 1.1222, 'revenue': 0.899, 'real': 0.7737, 'deficit': 0.6992, 'choices': 0.6432, 'spend': 0.5644, 'rail': 0.5381, 'economic': 0.5291}
#
# topic_9
# {'match': 0.6908, 'winning': 0.5669, 'best': 0.4235, 'like': 0.41, 'finals': 0.3913, 'semi': 0.3913, 'biennale': 0.3617, 'just': 0.333, 'thank': 0.3302, 'photos': 0.3135}
#
# topic_10
# {'inflation': 1.659, 'rate': 1.6572, 'growth': 1.2614, 'rates': 0.9834, 'rba': 0.8791, 'quarter': 0.7597, 'rise': 0.7192, 'bank': 0.6842, 'economy': 0.6691, 'japan': 0.6653}
#
# topic_11
# {'ukrainian': 1.5862, 'russian': 1.3526, 'refinery': 1.2397, 'region': 1.2287, 'oil': 0.9106, 'belgorod': 0.8543, 'drone': 0.7849, 'claimed': 0.7523, 'killed': 0.7385, 'attack': 0.6926}
#
# topic_12
# {'gaza': 2.8525, 'israel': 1.9343, 'hamas': 1.3754, 'israeli': 1.3117, 'aid': 1.2028, 'gmt': 0.9993, 'humanitarian': 0.9632, 'palestinian': 0.6976, 'unrwa': 0.5929, 'ceasefire': 0.5792}
#
# topic_13
# {'hall': 1.8971, 'attack': 1.8861, 'moscow': 1.6812, 'concert': 1.4655, 'crocus': 1.1793, 'russian': 1.1724, 'islamic': 1.0148, 'gmt': 0.8308, 'putin': 0.7812, 'terrorist': 0.7453}
#
# topic_14
# {'bst': 1.888, 'updated': 0.382, 'workers': 0.3603, 'aid': 0.3312, 'wck': 0.3196, 'israeli': 0.298, 'kitchen': 0.284, 'gaza': 0.2825, 'central': 0.2265, 'australia': 0.2264}
#
# topic_15
# {'china': 2.199, 'zealand': 1.8657, 'wong': 1.5587, 'pacific': 1.5561, 'australia': 1.4847, 'sanctions': 0.9808, 'wang': 0.8751, 'chinese': 0.821, 'yang': 0.7969, 'new': 0.7934}
#
# topic_16
# {'russian': 0.7063, 'defence': 0.4916, 'nato': 0.4223, 'military': 0.4019, 'sergei': 0.3851, 'germany': 0.3832, 'eu': 0.3479, 'taurus': 0.334, 'macron': 0.3274, 'tuesday': 0.326}
#
# topic_17
# {'word': 1.7059, 'biden': 1.6333, 'starter': 1.0907, 'time': 1.0036, 'batty': 0.9, 'festival': 0.7969, 'australia': 0.7729, 'transgender': 0.7502, 'post': 0.6862, 'casino': 0.6529}
#
# topic_18
# {'taiwan': 0.7016, 'elections': 0.6671, 'party': 0.5771, 'election': 0.4463, 'protests': 0.39, 'india': 0.3687, 'president': 0.3621, 'putin': 0.3592, 'kong': 0.3566, 'hong': 0.3566}
#
# topic_19
# {'technology': 0.7876, 'australian': 0.6001, 'defence': 0.58, 'aim': 0.5646, 'counter': 0.4255, 'challenges': 0.4199, 'drone': 0.4087, 'byrne': 0.3917, 'shoot': 0.3491, 'deployed': 0.3394}

# %% [markdown]
# #### Update the terms matrix

# %%
for idx,topic in enumerate(doc_topic_nmf):
    topic_num = topic.argmax()
    top_topic = nmf_topic_dict[f"topic_{topic_num}"]
    terms_df['nmf'].iloc[idx] = list(top_topic.keys())

terms_df
# Out:
# /tmp/ipykernel_1436/2397270878.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   terms_df['nmf'].iloc[idx] = list(top_topic.keys())
#                                                                                              tfidf  \
# Ukraine war briefing: Nato foreign ministers to...         [adm, nato, russian, tuesday, refinery]
# Ukraine war briefing: Biden scrapes together $3...      [johnson, russian, kursk, tuesday, nizhny]
# Ukraine war briefing: Russian forces occupying ...   [friday, torture, russian, serbia, ukrainian]
# Ukraine war briefing: Russian fighter jet crash...  [polish, thursday, ukrainian, russian, poland]
# Ukraine war briefing: Pope urges Ukraine to hav...            [saturday, boy, ria, moscow, afraid]
# ...                                                                                            ...
# Israel-Gaza war: US condemns ‘cynical’ Russia a...        [gaza, israel, gmt, blinken, resolution]
# Collapse at regional mine – as it happened [202...  [gmt, updated, australia, funding, government]
# Nowland family reach settlement – as it happene...          [gmt, updated, super, women, parental]
# King takes aim at Liberals over preselection of...    [gmt, updated, labor, government, australia]
# Dutton claims PM ‘misrepresented’ earlier comme...     [gmt, updated, rudd, government, australia]
#
#                                                                                                   nmf
# Ukraine war briefing: Nato foreign ministers to...  [russian, defence, nato, military, sergei, ger...
# Ukraine war briefing: Biden scrapes together $3...  [ukrainian, russian, refinery, region, oil, be...
# Ukraine war briefing: Russian forces occupying ...  [russian, ukrainian, eu, zelenskiy, thursday, ...
# Ukraine war briefing: Russian fighter jet crash...  [russian, ukrainian, eu, zelenskiy, thursday, ...
# Ukraine war briefing: Pope urges Ukraine to hav...  [russian, saturday, sunday, german, drone, ode...
# ...                                                                                               ...
# Israel-Gaza war: US condemns ‘cynical’ Russia a...  [gaza, israel, hamas, israeli, aid, gmt, human...
# Collapse at regional mine – as it happened [202...  [gmt, updated, government, labor, australia, m...
# Nowland family reach settlement – as it happene...  [gmt, updated, government, labor, australia, m...
# King takes aim at Liberals over preselection of...  [gmt, updated, government, labor, australia, m...
# Dutton claims PM ‘misrepresented’ earlier comme...  [gmt, updated, government, labor, australia, m...
#
# [99 rows x 2 columns]

# %% [markdown]
# ### Check against articles

# %%
# Sample 5 random articles
samples = random.sample(range(0,len(terms_df)),5)

for sample in samples:
    doc = terms_df.iloc[sample]
    print(f"[{sample}] {doc.name}")
    print("\t- TFIDF:\t",doc['tfidf'])
    print("\t- NMF:\t\t",doc['nmf'])
    print()
# Out:
# [66] Afternoon Update: Labor unveils fuel efficiency standard; Crown keeps Melbourne casino licence; and Diddy’s properties raided [2024-03-26T06:00:20Z]
# 	- TFIDF:	 ['festival', 'word', 'casino', 'crown', 'properties']
# 	- NMF:		 ['word', 'biden', 'starter', 'time', 'batty', 'festival', 'australia', 'transgender', 'post', 'casino']
#
# [69] Afternoon Update: Taiwan rocked by 7.7 magnitude quake; Sam Mostyn to be next governor general; and what’s behind Sydney’s cocaine coast [2024-04-03T06:04:02Z]
# 	- TFIDF:	 ['word', 'batty', 'japan', 'cruise', 'starter']
# 	- NMF:		 ['word', 'biden', 'starter', 'time', 'batty', 'festival', 'australia', 'transgender', 'post', 'casino']
#
# [28] Ukraine war briefing: Zelenskiy says Putin trying to falsely blame Kyiv for Moscow concert attack [2024-03-24T07:37:36Z]
# 	- TFIDF:	 ['lviv', 'air', 'saturday', 'attack', 'missiles']
# 	- NMF:		 ['polish', 'russian', 'missile', 'poland', 'ukrainian', 'air', 'missiles', 'sunday', 'energy', 'lviv']
#
# [84] Middle East crisis: scores injured as aid warehouse is hit, says Unrwa – as it happened [2024-03-13T15:08:31Z]
# 	- TFIDF:	 ['gaza', 'israeli', 'gmt', 'palestinian', 'aid']
# 	- NMF:		 ['gaza', 'israel', 'hamas', 'israeli', 'aid', 'gmt', 'humanitarian', 'palestinian', 'unrwa', 'ceasefire']
#
# [49] Amid air raids and electricity shortages, a Ukrainian artist paints the Russian invasion [2024-03-27T14:00:26Z]
# 	- TFIDF:	 ['biennale', 'paintings', 'artist', 'art', 'trauma']
# 	- NMF:		 ['match', 'winning', 'best', 'like', 'finals', 'semi', 'biennale', 'just', 'thank', 'photos']

# %% [markdown]
# ## Refine your analysis
#
# Once you have worked through the process. Try tweaking the parameters in the TF/IDF vectorizer and also in the NMF topic modelling to try and obtain better results for your data.
#
# #### Advanced
#
# You may obtain better results by doing the following:
#
# 1. Creating smaller documents (e.g. article paragraphs)
# 2. Pre-processing the text by Stemming or Lemmatizing, and by removing additional stop words.
